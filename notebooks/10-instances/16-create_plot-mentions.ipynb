# %% [markdown]
# # Création des resources RDF des mentions de parcelles

# %%
import json 
import pandas as pd
import numpy as np
import uuid
import re
from datetime import datetime
from rdflib import Graph, Literal, Namespace, RDF, URIRef, BNode
from rdflib.namespace import XSD, DCTERMS, PROV, SKOS, RDFS
from functions import *

# %% [markdown]
# ## 1. Lecture des données

# %% [markdown]
# ### Articles de classement

# %%
COMMUNE = 'Gentilly'
matrices_metada = {
    "MAT_1813": {
        "PLAN": "1811",
        "MATRICE_ID": "MAT_B_NB_1813",
        "MATRICE_START": "1813",
        "MATRICE_END": "1835"
    },
    "MAT_1836": {
        "PLAN": "1811",
        "MATRICE_ID": "MAT_NB_1836",
        "MATRICE_START": "1836",
        "MATRICE_END": "1847"
    },
    "MAT_1848": {
        "PLAN": "1845",
        "MATRICE_ID": "MAT_NB_1848",
        "MATRICE_START": "1848",
        "MATRICE_END": "1860"
    }
}

# %%
ROOT = "/workspaces/ontologie-peuplement/"  #/home/STual/KG-cadastre/

PATH = ROOT + "data/gentilly/MAT_1813.csv"
mat1813 = pd.read_csv(PATH,header=0)
PATH = ROOT + "data/gentilly/MAT_1836.csv"
mat1836 = pd.read_csv(PATH,header=0)
PATH = ROOT + "data/gentilly/MAT_1848.csv"
mat1848 = pd.read_csv(PATH,header=0)

OUTPUT_FOLDER_PATH = ROOT + "data/rdf"

# %%
mat1813['registre'] = 'MAT_1813'
mat1836['registre'] = 'MAT_1836'
mat1848['registre'] = 'MAT_1848'

matrices = pd.concat([mat1813, mat1836, mat1848])
matrices = matrices.reset_index(drop=True)
print(matrices.columns)
# Out:
# Index(['ID', 'UUID', 'Type_CF', 'Num_Folio', 'Alt_Num_CF', 'Groupe_CF',
#        'Ordre_de_lecture', 'Voie', 'Num_Voie', 'Image', 'Section_clean',
#        'Parcelle_clean', 'Lieu-dit_transcript', 'Lieu-dit_clean',
#        'Lieu-dit_treated', 'Lieu-dit_type', 'Propriétaires_transcript',
#        'Nature_transcript', 'Nature_clean', 'Nature_treated', 'Date entrée',
#        'Date entrée_treated', 'Date sortie', 'Date sortie_treated', 'Tiré de',
#        'Tiré de_treated', 'Porté à', 'Porté à_treated', 'Ligne barrée ?',
#        'CF rayé ?', 'Spécification', 'Commentaire', 'Cote liée', 'registre'],
#       dtype='object')

# %%
display(matrices)
# Out:
#       ID                                  UUID   Type_CF Num_Folio  \
# 0      1  7c13b9ec-506c-4675-b691-335b828bbe11      Bâti       108
# 1      2  649a3bb0-7483-44c8-ad90-96bfc1808fdd      Bâti       114
# 2      3  bf640773-d6ff-4ba8-be3b-ffdd199dd8a4      Bâti        82
# 3      4  fe2c20fe-237f-4da7-8c7d-1ae33e5e1b96      Bâti        82
# 4      5  a8d13691-1a81-4684-9db7-98ee1fbc354d      Bâti        64
# ..   ...                                   ...       ...       ...
# 437  219  da62bcf1-3993-420b-8aac-e7cd1d1b4cda  Non Bâti      1221
# 438  220  d0f7ae85-fd51-459b-a4b4-48a8335cf44a  Non Bâti      1221
# 439  221  e0d84f8b-4b9b-4b54-92f0-e1d36d5e6e45  Non Bâti      1222
# 440  222  af70cad2-55f9-4163-8c6b-ece562802b66  Non Bâti      1222
# 441  223  244a34a1-1a2f-4170-8564-77a1899f17fe  Non Bâti      1222
#
#      Alt_Num_CF  Groupe_CF  Ordre_de_lecture Voie Num_Voie  \
# 0           NaN          1                 1  NaN      NaN
# 1           NaN          1                 1  NaN      NaN
# 2           NaN          1                 1  NaN      NaN
# 3           NaN          1                 2  NaN      NaN
# 4           NaN          1                 1  NaN      NaN
# ..          ...        ...               ...  ...      ...
# 437         NaN          1                 6  NaN      NaN
# 438         NaN          1                 7  NaN      NaN
# 439         NaN          1                 1  NaN      NaN
# 440         NaN          1                 2  NaN      NaN
# 441         NaN          1                 3  NaN      NaN
#
#                          Image  ... Tiré de Tiré de_treated Porté à  \
# 0    FRAD094_3P_000255_01_0586  ...     NaN             NaN     NaN
# 1    FRAD094_3P_000255_01_0588  ...     NaN             NaN      82
# 2    FRAD094_3P_000255_01_0579  ...     114             114     NaN
# 3    FRAD094_3P_000255_01_0579  ...     NaN             NaN     NaN
# 4    FRAD094_3P_000255_01_0571  ...     NaN             NaN     NaN
# ..                         ...  ...     ...             ...     ...
# 437  FRAD094_3P_000264_01_0221  ...     NaN             NaN     NaN
# 438  FRAD094_3P_000264_01_0221  ...     NaN             NaN     NaN
# 439  FRAD094_3P_000264_01_0222  ...     NaN             NaN     NaN
# 440  FRAD094_3P_000264_01_0222  ...     NaN             NaN     NaN
# 441  FRAD094_3P_000264_01_0222  ...     NaN             NaN     NaN
#
#     Porté à_treated Ligne barrée ? CF rayé ?  \
# 0               NaN            Non       Non
# 1                82            Oui       Oui
# 2               NaN            Non       Non
# 3               NaN            Non       Non
# 4               NaN            Non       Non
# ..              ...            ...       ...
# 437             NaN            Non       Non
# 438             NaN            Non       Non
# 439             NaN            Non       Non
# 440             NaN            Non       Non
# 441             NaN            Non       Non
#
#                                          Spécification Commentaire Cote liée  \
# 0    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# 1    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# 2    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# 3    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# 4    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# ..                                                 ...         ...       ...
# 437                                                NaN         NaN       NaN
# 438                                                NaN         NaN       NaN
# 439                                                NaN         NaN       NaN
# 440                                                NaN         NaN       NaN
# 441                                                NaN         NaN       NaN
#
#      registre
# 0    MAT_1813
# 1    MAT_1813
# 2    MAT_1813
# 3    MAT_1813
# 4    MAT_1813
# ..        ...
# 437  MAT_1848
# 438  MAT_1848
# 439  MAT_1848
# 440  MAT_1848
# 441  MAT_1848
#
# [442 rows x 34 columns]

# %% [markdown]
# ### Propriétaires

# %%
#open three json files
with open(ROOT + "data/gentilly/output_structured_owners.json") as f:
    data_owners = json.load(f)

#read as df
owners_df = pd.DataFrame(data_owners)

# %%
oregistre = []
otype_folio = []
ofolio = []
o_groupe_cf = []
o_transcription = []

for row in owners_df.iterrows():
    cell_info = row[1]['cell']
    oregistre.append(cell_info['registre'])
    otype_folio.append(cell_info['type_folio'])
    ofolio.append(cell_info['folio'])
    o_groupe_cf.append(cell_info['groupe_cf'])
    o_transcription.append(cell_info['transcription'])

owners_df['registre'] = oregistre
owners_df['type_folio'] = otype_folio
owners_df['folio'] = ofolio
owners_df['groupe_cf'] = o_groupe_cf
owners_df['transcription'] = o_transcription

# %%
owners_df
# Out:
#                                                   cell  \
# 0    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 1    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 2    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 3    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 4    {'registre': 'MAT_1813', 'type_folio': 'Non Bâ...
# ..                                                 ...
# 185  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 186  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 187  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 188  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 189  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
#
#                                                 owners  \
# 0    [{'owner-id': 1, 'owner-lastname': 'Legendre',...
# 1    [{'owner-id': 1, 'owner-lastname': 'Louves', '...
# 2    [{'owner-id': 1, 'owner-lastname': 'Hardon', '...
# 3    [{'owner-id': 1, 'owner-lastname': 'Faipot', '...
# 4    [{'owner-id': 1, 'owner-lastname': 'Bacot', 'o...
# ..                                                 ...
# 185  [{'owner-id': 1, 'owner-lastname': 'Delon', 'i...
# 186  [{'owner-id': 1, 'owner-lastname': 'Delon', 'i...
# 187  [{'owner-id': 1, 'owner-lastname': 'Dufresne',...
# 188  [{'owner-id': 1, 'owner-lastname': 'Nicolle', ...
# 189  [{'owner-id': 1, 'owner-lastname': 'Lacroix', ...
#
#                                                changes  registre type_folio  \
# 0                                                   []  MAT_1813       Bâti
# 1                                                   []  MAT_1813       Bâti
# 2                                                   []  MAT_1813       Bâti
# 3                                                   []  MAT_1813       Bâti
# 4                                                   []  MAT_1813   Non Bâti
# ..                                                 ...       ...        ...
# 185  [{'change-order': 1, 'owner-before': 1, 'owner...  MAT_1848   Non Bâti
# 186                                                 []  MAT_1848   Non Bâti
# 187                                                 []  MAT_1848   Non Bâti
# 188                                                 []  MAT_1848   Non Bâti
# 189                                                 []  MAT_1848   Non Bâti
#
#     folio groupe_cf                                      transcription
# 0     108         1                   Legendre H↑re↓ de →Fontainebleau
# 1     114         1                                             Louves
# 2      82         1           Hardon, Bourgeois ~~nourisseur~~→à Paris
# 3      64         1  Faipot François→m↑d↓ de vin b↑re↓ de fontaineb...
# 4      11         1                 Bacot→(david) couverturier→à Paris
# ..    ...       ...                                                ...
# 185  1218         1  ~~Delon~~ 1858 Sevestre Clément boulanger Bar↑...
# 186  1219         1                                              Delon
# 187  1220         1                                           Dufresne
# 188  1221         1                           Nicolle J↑n↓ f↑ois↓ Paul
# 189  1222         1                                 Lacroix J↑n↓ Louis
#
# [190 rows x 8 columns]

# %% [markdown]
# ### 1.1. Création des pages
# - rdf:type rico:Instanciation : instance numérisée d'une page de registre
# - rdf:type rico:Record => concept de la page de registre, fait le lien avec le registre (concept, RecordSet)

# %%
#select distinct values in th colum Image
images = matrices[['registre','Image']].drop_duplicates().reset_index(drop=True)
images
# Out:
#      registre                      Image
# 0    MAT_1813  FRAD094_3P_000255_01_0586
# 1    MAT_1813  FRAD094_3P_000255_01_0588
# 2    MAT_1813  FRAD094_3P_000255_01_0579
# 3    MAT_1813  FRAD094_3P_000255_01_0571
# 4    MAT_1813  FRAD094_3P_000255_01_0015
# ..        ...                        ...
# 150  MAT_1848  FRAD094_3P_000264_01_0218
# 151  MAT_1848  FRAD094_3P_000264_01_0219
# 152  MAT_1848  FRAD094_3P_000264_01_0220
# 153  MAT_1848  FRAD094_3P_000264_01_0221
# 154  MAT_1848  FRAD094_3P_000264_01_0222
#
# [155 rows x 2 columns]

# %%
from namespaces import *

# Create a new RDF graph
g = Graph()

g.bind('cad', cad)
g.bind('add', add)
g.bind('source', srcuri)
g.bind('mlclasse', mlclasse)
g.bind('activity', activity)

g.bind('rico', rico)
g.bind('fpo', fpo)
g.bind('time',time)

for index, row in images.iterrows():
    img = row['Image']
    MATRICE_ID = matrices_metada[row['registre']]["MATRICE_ID"]
    json = parse_record_id(img)
    subject_uri = URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{img}")
    g.add((subject_uri, RDF.type, rico.Instanciation))
    g.add((subject_uri, rico.identifier, Literal(img)))
    folder_end = img.rfind('_')
    #Record (Page)
    subject_uri_record = URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{img}_page")
    g.add((subject_uri_record, RDF.type, rico.Record))
    g.add((subject_uri,rico.isOrWasDigitalInstanciationOf,subject_uri_record))
    #Record (Page) se trouve dans une matrice donnée (record)
    g.add((subject_uri_record, rico.isOrWasIncludedIn, URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{MATRICE_ID}")))

    # Activité 0001 : Classification des pages
    mlClasseNode = BNode()
    g.add((subject_uri, cad.hasClasse, mlClasseNode))
    g.add((mlClasseNode, cad.hasClasseValue, URIRef(mlclasse + f"MATMainTable")))
    g.add((mlClasseNode, PROV.wasGeneratedBy, URIRef(activity + f"0001")))
    g.add((URIRef(activity + "0001"), PROV.used, URIRef(subject_uri)))

    #Activité 0002 : Extraction des informations des pages
    g.add((URIRef(activity + "0002"), PROV.used, URIRef(subject_uri)))

print(g.serialize(format='turtle'))
g.serialize(destination=f"{OUTPUT_FOLDER_PATH}/{COMMUNE}_sources_pages.ttl", format='turtle')
# Out:
# @prefix activity: <http://data.ign.fr/id/codes/cadastre/activity/> .
# @prefix cad: <http://data.ign.fr/def/cadastre#> .
# @prefix mlclasse: <http://data.ign.fr/id/codes/cadastre/mlClasse/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rico: <https://www.ica.org/standards/RiC/ontology#> .
# @prefix source: <http://data.ign.fr/id/source/> .
#
# activity:0002 prov:used source:94_Gentilly_FRAD094_3P_000255_01_0015,
#         source:94_Gentilly_FRAD094_3P_000255_01_0032,
#         source:94_Gentilly_FRAD094_3P_000255_01_0044,
#         source:94_Gentilly_FRAD094_3P_000255_01_0057,
#         source:94_Gentilly_FRAD094_3P_000255_01_0125,
#         source:94_Gentilly_FRAD094_3P_000255_01_0146,
#         source:94_Gentilly_FRAD094_3P_000255_01_0148,
#         source:94_Gentilly_FRAD094_3P_000255_01_0165,
#         source:94_Gentilly_FRAD094_3P_000255_01_0186,
#         source:94_Gentilly_FRAD094_3P_000255_01_0196,
#         source:94_Gentilly_FRAD094_3P_000255_01_0199,
#         source:94_Gentilly_FRAD094_3P_000255_01_0224,
#         source:94_Gentilly_FRAD094_3P_000256_01_0494,
#         source:94_Gentilly_FRAD094_3P_000256_01_0495,
#         source:94_Gentilly_FRAD094_3P_000256_01_0496,
#         source:94_Gentilly_FRAD094_3P_000256_01_0497,
#         source:94_Gentilly_FRAD094_3P_000256_01_0498,
#         source:94_Gentilly_FRAD094_3P_000256_01_0499,
#         source:94_Gentilly_FRAD094_3P_000256_01_0500,
#         source:94_Gentilly_FRAD094_3P_000256_01_0501,
#         source:94_Gentilly_FRAD094_3P_000256_01_0502,
#         source:94_Gentilly_FRAD094_3P_000256_01_0503,
#         source:94_Gentilly_FRAD094_3P_000256_01_0504,
#         source:94_Gentilly_FRAD094_3P_000256_01_0505,
#         source:94_Gentilly_FRAD094_3P_000256_01_0506,
#         source:94_Gentilly_FRAD094_3P_000257_01_0137,
#         source:94_Gentilly_FRAD094_3P_000257_01_0189,
#         source:94_Gentilly_FRAD094_3P_000257_01_0227,
#         source:94_Gentilly_FRAD094_3P_000257_01_0228,
#         source:94_Gentilly_FRAD094_3P_000257_01_0295,
#         source:94_Gentilly_FRAD094_3P_000257_01_0308,
#         source:94_Gentilly_FRAD094_3P_000257_01_0488,
#         source:94_Gentilly_FRAD094_3P_000259_01_0445,
#         source:94_Gentilly_FRAD094_3P_000259_01_0446,
#         source:94_Gentilly_FRAD094_3P_000259_01_0447,
#         source:94_Gentilly_FRAD094_3P_000259_01_0448,
#         source:94_Gentilly_FRAD094_3P_000259_01_0449,
#         source:94_Gentilly_FRAD094_3P_000259_01_0450,
#         source:94_Gentilly_FRAD094_3P_000259_01_0451,
#         source:94_Gentilly_FRAD094_3P_000259_01_0452,
#         source:94_Gentilly_FRAD094_3P_000259_01_0453,
#         source:94_Gentilly_FRAD094_3P_000259_01_0454,
#         source:94_Gentilly_FRAD094_3P_000259_01_0455,
#         source:94_Gentilly_FRAD094_3P_000259_01_0456,
#         source:94_Gentilly_FRAD094_3P_000259_01_0518,
#         source:94_Gentilly_FRAD094_3P_000263_01_0013,
#         source:94_Gentilly_FRAD094_3P_000263_01_0329,
#         source:94_Gentilly_FRAD094_3P_000263_01_0330,
#         source:94_Gentilly_FRAD094_3P_000263_01_0331,
#         source:94_Gentilly_FRAD094_3P_000263_01_0332,
#         source:94_Gentilly_FRAD094_3P_000263_01_0333,
#         source:94_Gentilly_FRAD094_3P_000263_01_0334,
#         source:94_Gentilly_FRAD094_3P_000263_01_0335,
#         source:94_Gentilly_FRAD094_3P_000263_01_0336,
#         source:94_Gentilly_FRAD094_3P_000263_01_0338,
#         source:94_Gentilly_FRAD094_3P_000263_01_0339,
#         source:94_Gentilly_FRAD094_3P_000263_01_0345,
#         source:94_Gentilly_FRAD094_3P_000263_01_0346,
#         source:94_Gentilly_FRAD094_3P_000263_01_0347,
#         source:94_Gentilly_FRAD094_3P_000263_01_0348,
#         source:94_Gentilly_FRAD094_3P_000263_01_0349,
#         source:94_Gentilly_FRAD094_3P_000263_01_0350,
#         source:94_Gentilly_FRAD094_3P_000263_01_0351,

#
# source:94_Gentilly_FRAD094_3P_000264_01_0219 a rico:Instanciation ;
#     cad:hasClasse [ cad:hasClasseValue mlclasse:MATMainTable ;
#             prov:wasGeneratedBy activity:0001 ] ;
#     rico:identifier "FRAD094_3P_000264_01_0219" ;
#     rico:isOrWasDigitalInstanciationOf source:94_Gentilly_FRAD094_3P_000264_01_0219_page .
#
# source:94_Gentilly_FRAD094_3P_000264_01_0220 a rico:Instanciation ;
#     cad:hasClasse [ cad:hasClasseValue mlclasse:MATMainTable ;
#             prov:wasGeneratedBy activity:0001 ] ;
#     rico:identifier "FRAD094_3P_000264_01_0220" ;
#     rico:isOrWasDigitalInstanciationOf source:94_Gentilly_FRAD094_3P_000264_01_0220_page .
#
# source:94_Gentilly_FRAD094_3P_000264_01_0221 a rico:Instanciation ;
#     cad:hasClasse [ cad:hasClasseValue mlclasse:MATMainTable ;
#             prov:wasGeneratedBy activity:0001 ] ;
#     rico:identifier "FRAD094_3P_000264_01_0221" ;
#     rico:isOrWasDigitalInstanciationOf source:94_Gentilly_FRAD094_3P_000264_01_0221_page .
#
# source:94_Gentilly_FRAD094_3P_000264_01_0222 a rico:Instanciation ;
#     cad:hasClasse [ cad:hasClasseValue mlclasse:MATMainTable ;
#             prov:wasGeneratedBy activity:0001 ] ;
#     rico:identifier "FRAD094_3P_000264_01_0222" ;
#     rico:isOrWasDigitalInstanciationOf source:94_Gentilly_FRAD094_3P_000264_01_0222_page .
#
# activity:0001 prov:used source:94_Gentilly_FRAD094_3P_000255_01_0015,
#         source:94_Gentilly_FRAD094_3P_000255_01_0032,
#         source:94_Gentilly_FRAD094_3P_000255_01_0044,
#         source:94_Gentilly_FRAD094_3P_000255_01_0057,
#         source:94_Gentilly_FRAD094_3P_000255_01_0125,
#         source:94_Gentilly_FRAD094_3P_000255_01_0146,
#         source:94_Gentilly_FRAD094_3P_000255_01_0148,
#         source:94_Gentilly_FRAD094_3P_000255_01_0165,
#         source:94_Gentilly_FRAD094_3P_000255_01_0186,
#         source:94_Gentilly_FRAD094_3P_000255_01_0196,
#         source:94_Gentilly_FRAD094_3P_000255_01_0199,
#         source:94_Gentilly_FRAD094_3P_000255_01_0224,
#         source:94_Gentilly_FRAD094_3P_000255_01_0245,
#         source:94_Gentilly_FRAD094_3P_000255_01_0259,
#         source:94_Gentilly_FRAD094_3P_000255_01_0270,
#         source:94_Gentilly_FRAD094_3P_000255_01_0278,
#         source:94_Gentilly_FRAD094_3P_000255_01_0279,
#         source:94_Gentilly_FRAD094_3P_000255_01_0281,
#         source:94_Gentilly_FRAD094_3P_000255_01_0294,
#         source:94_Gentilly_FRAD094_3P_000255_01_0301,
#         source:94_Gentilly_FRAD094_3P_000255_01_0310,
#         source:94_Gentilly_FRAD094_3P_000255_01_0313,
#         source:94_Gentilly_FRAD094_3P_000255_01_0324,
#         source:94_Gentilly_FRAD094_3P_000255_01_0325,
#         source:94_Gentilly_FRAD094_3P_000255_01_0333,
#         source:94_Gentilly_FRAD094_3P_000255_01_0334,
#         source:94_Gentilly_FRAD094_3P_000255_01_0350,
#         source:94_Gentilly_FRAD094_3P_000255_01_0352,
#         source:94_Gentilly_FRAD094_3P_000255_01_0355,
#         source:94_Gentilly_FRAD094_3P_000255_01_0359,
#         source:94_Gentilly_FRAD094_3P_000255_01_0414,
#         source:94_Gentilly_FRAD094_3P_000255_01_0420,
#         source:94_Gentilly_FRAD094_3P_000255_01_0424,
#         source:94_Gentilly_FRAD094_3P_000255_01_0440,
#         source:94_Gentilly_FRAD094_3P_000255_01_0451,
#         source:94_Gentilly_FRAD094_3P_000255_01_0465,
#         source:94_Gentilly_FRAD094_3P_000255_01_0509,
#         source:94_Gentilly_FRAD094_3P_000255_01_0516,
#         source:94_Gentilly_FRAD094_3P_000255_01_0526,
#         source:94_Gentilly_FRAD094_3P_000255_01_0571,
#         source:94_Gentilly_FRAD094_3P_000255_01_0579,
#         source:94_Gentilly_FRAD094_3P_000255_01_0586,
#         source:94_Gentilly_FRAD094_3P_000264_01_0213,
#         source:94_Gentilly_FRAD094_3P_000264_01_0214,
#         source:94_Gentilly_FRAD094_3P_000264_01_0215,
#         source:94_Gentilly_FRAD094_3P_000264_01_0216,
#         source:94_Gentilly_FRAD094_3P_000264_01_0217,
#         source:94_Gentilly_FRAD094_3P_000264_01_0218,
#         source:94_Gentilly_FRAD094_3P_000264_01_0219,
#         source:94_Gentilly_FRAD094_3P_000264_01_0220,
#         source:94_Gentilly_FRAD094_3P_000264_01_0221,
#         source:94_Gentilly_FRAD094_3P_000264_01_0222 .
# <Graph identifier=N59f2b0ac9a4045c1b1460029c106859a (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### 1.2 Folios
# - Pré-traitement des colonnes *Num_Folio*, *Tiré de* et *Porté à*
# - Création des objets "Folios" à partir de la colonne *Num_Folio* et des colonnes *Tiré de* et *Porté à* (manquants)
# - Création des objets spéciaux mentionnés dans les colonnes destinées aux folios (reste, construction nouvelle, ruine etc)

# %% [markdown]
# #### Pré-traitement

# %%
from functions import parse_record_id, cleanNumFolio

#Clean columns Num_Folio, Tire_de, Porte_a
clean_folio, clean_tire_de, clean_porte_a = [], [], []
symbols = [",", "→", "."," ",";","&"]

for index, row in matrices.iterrows():
    clean_folio.append(cleanNumFolio(row["Num_Folio"],symbols))
    clean_tire_de.append(cleanNumFolio(row["Tiré de_treated"],symbols))
    clean_porte_a.append(cleanNumFolio(row["Porté à_treated"],symbols))

# Create new columns containing the cleaned values
matrices['Num_Folio_clean'] = clean_folio
matrices['Tire_de_clean'] = clean_tire_de
matrices['Porte_a_clean'] = clean_porte_a

matrices['Num_Folio_clean'] = matrices['Num_Folio_clean'].astype(str)
# Out:
# ['236↑4↓', '361', '258', '166', '235↑2↓', '138', '357', '440']
# ['248', 'additionconstructionsv']
# ['249', '249']
# ['288', '433']
# ['443', '443']
# ['450', '443', '453', '968']
# ['449', '968']
# ['968', '442']
# ['442', '449', '439', '450']
# ['836', '403']
# ['837', '403']
# ['403', '513↑25↓']
# ['837', 'additionconstructionsv']
# ['844', 'additionconstructionsv']
# ['844', 'additionconstructionsv']
# ['846↑2↓', 'additionconstructionsv']
# ['847↑2↓', 'additionconstructionsv']
# ['847↑2↓', 'additionconstructionsv']

# %%
print(clean_porte_a)
# Out:
# ['EMPTY', '82', 'EMPTY', 'EMPTY', 'EMPTY', '156', '156', '192bis', '280bis', 'EMPTY', 'EMPTY', '34ter', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '124bis', 'EMPTY', 'EMPTY', '192bis', '247ter', 'voiepubliquesv', 'EMPTY', 'EMPTY', '46bis', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '211bis', '107↑2↓', 'EMPTY', 'doubleemploisv', 'EMPTY', 'EMPTY', '269↑2↓', '138', '236ter', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '361', 'EMPTY', 'EMPTY', 'EMPTY', '236↑4↓;361;258;166;235↑2↓;138;357;440', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '249', 'EMPTY', 'EMPTY', '248', 'EMPTY', '249;249', 'EMPTY', 'EMPTY', '249↑16↓', '249↑16↓', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'demolitionsv', 'EMPTY', 'EMPTY', 'demolitionsv', '288;433', 'EMPTY', 'EMPTY', 'EMPTY', 'augmentationsv', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '289', '289', '433', 'c', 'EMPTY', 'EMPTY', 'EMPTY', '434', 'EMPTY', 'EMPTY', '435', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '440', '440', 'demolitionsv', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '442', 'additionconstructionsv', 'EMPTY', 'EMPTY', 'EMPTY', 'augmentationsv', 'augmentationsv', 'EMPTY', 'EMPTY', 'EMPTY', '443', 'demolitionsv', 'augmentationsv', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '443;443', 'EMPTY', 'EMPTY', 'EMPTY', '442', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'demolitionsv', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '449↑1↓', 'EMPTY', '449', '449', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '533', '533', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '450;443;453;968', '449;968', '968;442', '442;449;439;450', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'demolitionsv', 'EMPTY', 'EMPTY', 'EMPTY', 'demolitionsv', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '836;403', '837;403', 'demolitionsv', '403;513↑25↓', '837', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '844;additionconstructionsv', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '846', 'EMPTY', 'EMPTY', '847↑3↓', 'EMPTY', 'EMPTY', '848↑3↓', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '861', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '834', 'EMPTY', 'demolitionsv', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '833', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', '829↑20↓', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'EMP ...

# %%
#Using matrices, create new df named folios containing all lines of matrices where register = MAT_1836 and MAT_1848. For register=MAT_1813, remove the lines where type_CF = "Bâti"
folios = matrices[(matrices['registre'] == 'MAT_1836') | (matrices['registre'] == 'MAT_1848') | ((matrices['registre'] == 'MAT_1813') & (matrices['Type_CF'] != 'Bâti'))]
folios.reset_index(drop=True)
# Out:
#       ID                                  UUID   Type_CF Num_Folio  \
# 0      6  7008c4af-2b07-4630-8667-9c8783aced10  Non Bâti        11
# 1      7  ef348452-7650-41a5-ac99-61d2490800b5  Non Bâti        11
# 2      8  6e7b862a-4f66-461c-96d4-db9f2dc76e56  Non Bâti        11
# 3      9  96e406d5-0647-4889-954d-b821f15ba128  Non Bâti     23bis
# 4     10  3076b547-3147-4247-b503-74e9ead7af45  Non Bâti     34ter
# ..   ...                                   ...       ...       ...
# 432  219  da62bcf1-3993-420b-8aac-e7cd1d1b4cda  Non Bâti      1221
# 433  220  d0f7ae85-fd51-459b-a4b4-48a8335cf44a  Non Bâti      1221
# 434  221  e0d84f8b-4b9b-4b54-92f0-e1d36d5e6e45  Non Bâti      1222
# 435  222  af70cad2-55f9-4163-8c6b-ece562802b66  Non Bâti      1222
# 436  223  244a34a1-1a2f-4170-8564-77a1899f17fe  Non Bâti      1222
#
#      Alt_Num_CF  Groupe_CF  Ordre_de_lecture Voie Num_Voie  \
# 0           NaN          1                 1  NaN      NaN
# 1           NaN          1                 2  NaN      NaN
# 2           NaN          1                 3  NaN      NaN
# 3           NaN          1                 1  NaN      NaN
# 4           NaN          1                 1  NaN      NaN
# ..          ...        ...               ...  ...      ...
# 432         NaN          1                 6  NaN      NaN
# 433         NaN          1                 7  NaN      NaN
# 434         NaN          1                 1  NaN      NaN
# 435         NaN          1                 2  NaN      NaN
# 436         NaN          1                 3  NaN      NaN
#
#                          Image  ... Porté à_treated Ligne barrée ? CF rayé ?  \
# 0    FRAD094_3P_000255_01_0015  ...             156            Non       Oui
# 1    FRAD094_3P_000255_01_0015  ...             156            Non       Oui
# 2    FRAD094_3P_000255_01_0015  ...          192bis            Oui       Oui
# 3    FRAD094_3P_000255_01_0032  ...          280bis            Oui       Oui
# 4    FRAD094_3P_000255_01_0044  ...             NaN            Non       Oui
# ..                         ...  ...             ...            ...       ...
# 432  FRAD094_3P_000264_01_0221  ...             NaN            Non       Non
# 433  FRAD094_3P_000264_01_0221  ...             NaN            Non       Non
# 434  FRAD094_3P_000264_01_0222  ...             NaN            Non       Non
# 435  FRAD094_3P_000264_01_0222  ...             NaN            Non       Non
# 436  FRAD094_3P_000264_01_0222  ...             NaN            Non       Non
#
#     Spécification Commentaire Cote liée  registre Num_Folio_clean  \
# 0             NaN         NaN       NaN  MAT_1813              11
# 1             NaN         NaN       NaN  MAT_1813              11
# 2             NaN         NaN       NaN  MAT_1813              11
# 3             NaN         NaN       NaN  MAT_1813           23bis
# 4             NaN         NaN       NaN  MAT_1813           34ter
# ..            ...         ...       ...       ...             ...
# 432           NaN         NaN       NaN  MAT_1848            1221
# 433           NaN         NaN       NaN  MAT_1848            1221
# 434           NaN         NaN       NaN  MAT_1848            1222
# 435           NaN         NaN       NaN  MAT_1848            1222
# 436           NaN         NaN       NaN  MAT_1848            1222
#
#               Tire_de_clean Porte_a_clean
# 0                     EMPTY           156
# 1                     EMPTY           156
# 2                     EMPTY        192bis
# 3    constructionnouvellesv        280bis
# 4                     46ter         EMPTY
# ..                      ...           ...
# 432                   EMPTY         EMPTY
# 433                   EMPTY         EMPTY
# 434                   EMPTY         EMPTY
# 435                   EMPTY         EMPTY
# 436                   EMPTY         EMPTY
#
# [437 rows x 37 columns]

# %% [markdown]
# Il doit rester 437 lignes sur 442.

# %%
#Create a new dataframe from sources with columns "Num_Folio" and "Image" containing only distinct rows
folios_pages = folios[["Num_Folio","Num_Folio_clean","Alt_Num_CF","Image","registre"]].drop_duplicates(subset=["Num_Folio","Num_Folio_clean","Alt_Num_CF","Image","registre"]).reset_index(drop=True)
display(folios_pages)
# Out:
#     Num_Folio Num_Folio_clean  Alt_Num_CF                      Image  registre
# 0          11              11         NaN  FRAD094_3P_000255_01_0015  MAT_1813
# 1       23bis           23bis         NaN  FRAD094_3P_000255_01_0032  MAT_1813
# 2       34ter           34ter         NaN  FRAD094_3P_000255_01_0044  MAT_1813
# 3       46bis           46bis         NaN  FRAD094_3P_000255_01_0057  MAT_1813
# 4      107bis          107bis         NaN  FRAD094_3P_000255_01_0125  MAT_1813
# ..        ...             ...         ...                        ...       ...
# 148      1218            1218         NaN  FRAD094_3P_000264_01_0218  MAT_1848
# 149      1219            1219         NaN  FRAD094_3P_000264_01_0219  MAT_1848
# 150      1220            1220         NaN  FRAD094_3P_000264_01_0220  MAT_1848
# 151      1221            1221         NaN  FRAD094_3P_000264_01_0221  MAT_1848
# 152      1222            1222         NaN  FRAD094_3P_000264_01_0222  MAT_1848
#
# [153 rows x 5 columns]

# %%
from namespaces import *

# Create a new RDF graph
g = Graph()

g.bind('source', srcuri)
g.bind('srctype', srctype)
g.bind('cad', cad)
g.bind('add', add)
g.bind('rico', rico)
g.bind('fpo', fpo)
g.bind('time',time)

# Iterate over each row in the DataFrame
for index, row in folios_pages.iterrows():
    json = parse_record_id(row['Image'])
    MATRICE_ID = matrices_metada[row['registre']]["MATRICE_ID"]

    subject_uri = URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{MATRICE_ID}_{str(row['Num_Folio'])}")
    g.add((subject_uri, RDF.type, rico.RecordPart))
    g.add((subject_uri, cad.isSourceType, URIRef(srctype.Folio)))
    g.add((subject_uri, cad.hasNumFolio, Literal(row["Num_Folio_clean"],datatype=XSD.string)))
    g.add((subject_uri, rico.isOrWasConstituentOf,URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{row['Image']}_page")))

    if not pd.isna(row['Alt_Num_CF']):
        g.add((subject_uri, cad.hasAlternativeNumFolio, Literal(int(row["Alt_Num_CF"]),datatype=XSD.string)))

print(g.serialize(format='turtle'))
# Out:
# @prefix cad: <http://data.ign.fr/def/cadastre#> .
# @prefix rico: <https://www.ica.org/standards/RiC/ontology#> .
# @prefix source: <http://data.ign.fr/id/source/> .
# @prefix srctype: <http://data.ign.fr/id/codes/cadastre/sourceType/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# source:94_Gentilly_MAT_B_NB_1813_107bis a rico:RecordPart ;
#     cad:hasNumFolio "107bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0125_page .
#
# source:94_Gentilly_MAT_B_NB_1813_11 a rico:RecordPart ;
#     cad:hasNumFolio "11"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0015_page .
#
# source:94_Gentilly_MAT_B_NB_1813_122bis a rico:RecordPart ;
#     cad:hasNumFolio "122bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0146_page .
#
# source:94_Gentilly_MAT_B_NB_1813_124bis a rico:RecordPart ;
#     cad:hasNumFolio "124bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0148_page .
#
# source:94_Gentilly_MAT_B_NB_1813_138 a rico:RecordPart ;
#     cad:hasNumFolio "138"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0165_page .
#
# source:94_Gentilly_MAT_B_NB_1813_156 a rico:RecordPart ;
#     cad:hasNumFolio "156"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0186_page .
#
# source:94_Gentilly_MAT_B_NB_1813_163 a rico:RecordPart ;
#     cad:hasNumFolio "163"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0196_page .
#
# source:94_Gentilly_MAT_B_NB_1813_166 a rico:RecordPart ;
#     cad:hasNumFolio "166"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0199_page .
#
# source:94_Gentilly_MAT_B_NB_1813_192bis a rico:RecordPart ;
#     cad:hasNumFolio "192bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0224_page .
#
# source:94_Gentilly_MAT_B_NB_1813_211 a rico:RecordPart ;
#     cad:hasNumFolio "211"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0245_page .
#
# source:94_Gentilly_MAT_B_NB_1813_211bis a rico:RecordPart ;
#     cad:hasNumFolio "211bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0245_page .
#
# source:94_Gentilly_MAT_B_NB_1813_220 a rico:RecordPart ;
#     cad:hasNumFolio "220"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0259_page .
#
# source:94_Gentilly_MAT_B_NB_1813_228ter a rico:RecordPart ;
#     cad:hasNumFolio "228ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0270_page .
#
# source:94_Gentilly_MAT_B_NB_1813_235bis a rico:RecordPart ;
#     cad:hasNumFolio "235bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0278_page .
#
# source:94_Gentilly_MAT_B_NB_1813_236 a rico:RecordPart ;
#     cad:hasNumFolio "236"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0279_page .
#
# source:94_Gentilly_MAT_B_NB_1813_236ter a rico:RecordPart ;
#     cad:hasNumFolio "236ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0281_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_236↑4↓> a rico:RecordPart ;
#     cad:hasNumFolio "236↑4↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0281_page .
#
# source:94_Gentilly_MAT_B_NB_1813_23bis a rico:RecordPart ;
#     cad:hasNumFolio "23bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0032_page .
#
# source:94_Gentilly_MAT_B_NB_1813_247 a rico:RecordPart ;
#     cad:hasNumFolio "247"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0294_page .
#
# source:94_Gentilly_MAT_B_NB_1813_251bis a rico:RecordPart ;
#     cad:hasNumFolio "251bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0301_page .
#
# source:94_Gentilly_MAT_B_NB_1813_258 a rico:RecordPart ;
#     cad:hasNumFolio "258"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0310_page .
#
# source:94_Gentilly_MAT_B_NB_1813_260 a rico:RecordPart ;
#     cad:hasNumFolio "260"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0313_page .
#
# source:94_Gentilly_MAT_B_NB_1813_268 a rico:RecordPart ;
#     cad:hasNumFolio "268"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0324_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_269²> a rico:RecordPart ;
#     cad:hasNumFolio "269↑2↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0325_page .
#
# source:94_Gentilly_MAT_B_NB_1813_280bis a rico:RecordPart ;
#     cad:hasNumFolio "280bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0333_page .
#
# source:94_Gentilly_MAT_B_NB_1813_281 a rico:RecordPart ;
#     cad:hasNumFolio "281"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0334_page .
#
# source:94_Gentilly_MAT_B_NB_1813_293 a rico:RecordPart ;
#     cad:hasNumFolio "293"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0350_page .
#
# source:94_Gentilly_MAT_B_NB_1813_295 a rico:RecordPart ;
#     cad:hasNumFolio "295"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0352_page .
#
# source:94_Gentilly_MAT_B_NB_1813_298bis a rico:RecordPart ;
#     cad:hasNumFolio "298bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0355_page .
#
# source:94_Gentilly_MAT_B_NB_1813_302 a rico:RecordPart ;
#     cad:hasNumFolio "302"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0359_page .
#
# source:94_Gentilly_MAT_B_NB_1813_34ter a rico:RecordPart ;
#     cad:hasNumFolio "34ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0044_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_351↑4↓> a rico:RecordPart ;
#     cad:hasNumFolio "351↑4↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0414_page .
#
# source:94_Gentilly_MAT_B_NB_1813_357 a rico:RecordPart ;
#     cad:hasNumFolio "357"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0420_page .
#
# source:94_Gentilly_MAT_B_NB_1813_361 a rico:RecordPart ;
#     cad:hasNumFolio "361"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0424_page .
#
# source:94_Gentilly_MAT_B_NB_1813_373bis a rico:RecordPart ;
#     cad:hasNumFolio "373bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0440_page .
#
# source:94_Gentilly_MAT_B_NB_1813_383 a rico:RecordPart ;
#     cad:hasNumFolio "383"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0451_page .
#
# source:94_Gentilly_MAT_B_NB_1813_397ter a rico:RecordPart ;
#     cad:hasNumFolio "397ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0465_page .
#
# source:94_Gentilly_MAT_B_NB_1813_440 a rico:RecordPart ;
#     cad:hasNumFolio "440"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0509_page .
#
# source:94_Gentilly_MAT_B_NB_1813_446 a rico:RecordPart ;
#     cad:hasNumFolio "446"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0516_page .
#
# source:94_Gentilly_MAT_B_NB_1813_455 a rico:RecordPart ;
#     cad:hasNumFolio "455"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0526_page .
#
# source:94_Gentilly_MAT_B_NB_1813_46bis a rico:RecordPart ;
#     cad:hasNumFolio "46bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0057_page .
#
# source:94_Gentilly_MAT_NB_1836_240 a rico:RecordPart ;
#     cad:hasNumFolio "240"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0293_page .
#
# source:94_Gentilly_MAT_NB_1836_247 a rico:RecordPart ;
#     cad:hasNumFolio "247"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0300_page .
#
# source:94_Gentilly_MAT_NB_1836_248 a rico:RecordPart ;
#     cad:hasNumFolio "248"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0301_page .
#
# source:94_Gentilly_MAT_NB_1836_249 a rico:RecordPart ;
#     cad:hasNumFolio "249"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0302_page .
#
# source:94_Gentilly_MAT_NB_1836_250 a rico:RecordPart ;
#     cad:hasNumFolio "250"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0303_page .
#
# source:94_Gentilly_MAT_NB_1836_286 a rico:RecordPart ;
#     cad:hasNumFolio "286"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0339_page .
#
# source:94_Gentilly_MAT_NB_1836_287 a rico:RecordPart ;
#     cad:hasNumFolio "287"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0340_page .
#
# source:94_Gentilly_MAT_NB_1836_288 a rico:RecordPart ;
#     cad:hasNumFolio "288"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0341_page .
#
# source:94_Gentilly_MAT_NB_1836_289 a rico:RecordPart ;
#     cad:hasNumFolio "289"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0342_page .
#
# source:94_Gentilly_MAT_NB_1836_290 a rico:RecordPart ;
#     cad:hasNumFolio "290"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0343_page .
#
# source:94_Gentilly_MAT_NB_1836_291 a rico:RecordPart ;
#     cad:hasNumFolio "291"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0344_page .
#
# source:94_Gentilly_MAT_NB_1836_292 a rico:RecordPart ;
#     cad:hasNumFolio "292"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0345_page .
#
# source:94_Gentilly_MAT_NB_1836_319 a rico:RecordPart ;
#     cad:hasNumFolio "319"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0372_page .
#
# source:94_Gentilly_MAT_NB_1836_432 a rico:RecordPart ;
#     cad:hasNumFolio "432"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0485_page .
#
# source:94_Gentilly_MAT_NB_1836_433 a rico:RecordPart ;
#     cad:hasNumFolio "433"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0486_page .
#
# source:94_Gentilly_MAT_NB_1836_434 a rico:RecordPart ;
#     cad:hasNumFolio "434"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0487_page .
#
# source:94_Gentilly_MAT_NB_1836_435 a rico:RecordPart ;
#     cad:hasNumFolio "435"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0488_page .
#
# source:94_Gentilly_MAT_NB_1836_436 a rico:RecordPart ;
#     cad:hasNumFolio "436"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0489_page .
#
# source:94_Gentilly_MAT_NB_1836_437 a rico:RecordPart ;
#     cad:hasNumFolio "437"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0490_page .
#
# source:94_Gentilly_MAT_NB_1836_439 a rico:RecordPart ;
#     cad:hasNumFolio "439"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0492_page .
#
# source:94_Gentilly_MAT_NB_1836_440 a rico:RecordPart ;
#     cad:hasNumFolio "440"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0493_page .
#
# source:94_Gentilly_MAT_NB_1836_441 a rico:RecordPart ;
#     cad:hasNumFolio "441"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0494_page .
#
# source:94_Gentilly_MAT_NB_1836_442 a rico:RecordPart ;
#     cad:hasNumFolio "442"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0495_page .
#
# source:94_Gentilly_MAT_NB_1836_443 a rico:RecordPart ;
#     cad:hasNumFolio "443"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0496_page .
#
# source:94_Gentilly_MAT_NB_1836_444 a rico:RecordPart ;
#     cad:hasNumFolio "444"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0497_page .
#
# source:94_Gentilly_MAT_NB_1836_445 a rico:RecordPart ;
#     cad:hasNumFolio "445"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0498_page .
#
# source:94_Gentilly_MAT_NB_1836_446 a rico:RecordPart ;
#     cad:hasNumFolio "446"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0499_page .
#
# source:94_Gentilly_MAT_NB_1836_447 a rico:RecordPart ;
#     cad:hasNumFolio "447"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0500_page .
#
# source:94_Gentilly_MAT_NB_1836_448 a rico:RecordPart ;
#     cad:hasNumFolio "448"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0501_page .
#
# source:94_Gentilly_MAT_NB_1836_449 a rico:RecordPart ;
#     cad:hasNumFolio "449"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0502_page .
#
# source:94_Gentilly_MAT_NB_1836_450 a rico:RecordPart ;
#     cad:hasNumFolio "450"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0503_page .
#
# source:94_Gentilly_MAT_NB_1836_451 a rico:RecordPart ;
#     cad:hasNumFolio "451"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0504_page .
#
# source:94_Gentilly_MAT_NB_1836_452 a rico:RecordPart ;
#     cad:hasNumFolio "452"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0505_page .
#
# source:94_Gentilly_MAT_NB_1836_453 a rico:RecordPart ;
#     cad:hasNumFolio "453"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0506_page .
#
# source:94_Gentilly_MAT_NB_1836_617 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "77"^^xsd:string ;
#     cad:hasNumFolio "617"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0137_page .
#
# source:94_Gentilly_MAT_NB_1836_669 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "129"^^xsd:string ;
#     cad:hasNumFolio "669"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0189_page .
#
# source:94_Gentilly_MAT_NB_1836_707 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "167"^^xsd:string ;
#     cad:hasNumFolio "707"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0227_page .
#
# source:94_Gentilly_MAT_NB_1836_708 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "168"^^xsd:string ;
#     cad:hasNumFolio "708"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0228_page .
#
# source:94_Gentilly_MAT_NB_1836_777 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "235"^^xsd:string ;
#     cad:hasNumFolio "777"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0295_page .
#
# source:94_Gentilly_MAT_NB_1836_788 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "248"^^xsd:string ;
#     cad:hasNumFolio "788"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0308_page .
#
# source:94_Gentilly_MAT_NB_1836_968 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "428"^^xsd:string ;
#     cad:hasNumFolio "968"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0488_page .
#
# source:94_Gentilly_MAT_NB_1848_1213 a rico:RecordPart ;
#     cad:hasNumFolio "1213"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0213_page .
#
# source:94_Gentilly_MAT_NB_1848_1214 a rico:RecordPart ;
#     cad:hasNumFolio "1214"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0214_page .
#
# source:94_Gentilly_MAT_NB_1848_1215 a rico:RecordPart ;
#     cad:hasNumFolio "1215"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0215_page .
#
# source:94_Gentilly_MAT_NB_1848_1216 a rico:RecordPart ;
#     cad:hasNumFolio "1216"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0216_page .
#
# source:94_Gentilly_MAT_NB_1848_1217 a rico:RecordPart ;
#     cad:hasNumFolio "1217"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0217_page .
#
# source:94_Gentilly_MAT_NB_1848_1218 a rico:RecordPart ;
#     cad:hasNumFolio "1218"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0218_page .
#
# source:94_Gentilly_MAT_NB_1848_1219 a rico:RecordPart ;
#     cad:hasNumFolio "1219"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0219_page .
#
# source:94_Gentilly_MAT_NB_1848_1220 a rico:RecordPart ;
#     cad:hasNumFolio "1220"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0220_page .
#
# source:94_Gentilly_MAT_NB_1848_1221 a rico:RecordPart ;
#     cad:hasNumFolio "1221"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0221_page .
#
# source:94_Gentilly_MAT_NB_1848_1222 a rico:RecordPart ;
#     cad:hasNumFolio "1222"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0222_page .
#
# source:94_Gentilly_MAT_NB_1848_392 a rico:RecordPart ;
#     cad:hasNumFolio "392"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0445_page .
#
# source:94_Gentilly_MAT_NB_1848_393 a rico:RecordPart ;
#     cad:hasNumFolio "393"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0446_page .
#
# source:94_Gentilly_MAT_NB_1848_394 a rico:RecordPart ;
#     cad:hasNumFolio "394"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0447_page .
#
# source:94_Gentilly_MAT_NB_1848_395 a rico:RecordPart ;
#     cad:hasNumFolio "395"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0448_page .
#
# source:94_Gentilly_MAT_NB_1848_396 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "496"^^xsd:string ;
#     cad:hasNumFolio "396"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0449_page .
#
# source:94_Gentilly_MAT_NB_1848_397 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "497"^^xsd:string ;
#     cad:hasNumFolio "397"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0450_page .
#
# source:94_Gentilly_MAT_NB_1848_398 a rico:RecordPart ;
#     cad:hasNumFolio "398"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0451_page .
#
# source:94_Gentilly_MAT_NB_1848_399 a rico:RecordPart ;
#     cad:hasNumFolio "399"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0452_page .
#
# source:94_Gentilly_MAT_NB_1848_400 a rico:RecordPart ;
#     cad:hasNumFolio "400"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0453_page .
#
# source:94_Gentilly_MAT_NB_1848_401 a rico:RecordPart ;
#     cad:hasNumFolio "401"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0454_page .
#
# source:94_Gentilly_MAT_NB_1848_402 a rico:RecordPart ;
#     cad:hasNumFolio "402"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0455_page .
#
# source:94_Gentilly_MAT_NB_1848_403 a rico:RecordPart ;
#     cad:hasNumFolio "403"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0456_page .
#
# source:94_Gentilly_MAT_NB_1848_465 a rico:RecordPart ;
#     cad:hasNumFolio "465"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0518_page .
#
# source:94_Gentilly_MAT_NB_1848_513 a rico:RecordPart ;
#     cad:hasNumFolio "513"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0013_page .
#
# source:94_Gentilly_MAT_NB_1848_827 a rico:RecordPart ;
#     cad:hasNumFolio "827"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0329_page .
#
# source:94_Gentilly_MAT_NB_1848_828 a rico:RecordPart ;
#     cad:hasNumFolio "828"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0330_page .
#
# source:94_Gentilly_MAT_NB_1848_829 a rico:RecordPart ;
#     cad:hasNumFolio "829"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0331_page .
#
# source:94_Gentilly_MAT_NB_1848_830 a rico:RecordPart ;
#     cad:hasNumFolio "830"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0332_page .
#
# source:94_Gentilly_MAT_NB_1848_831 a rico:RecordPart ;
#     cad:hasNumFolio "831"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0333_page .
#
# source:94_Gentilly_MAT_NB_1848_832 a rico:RecordPart ;
#     cad:hasNumFolio "832"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0334_page .
#
# source:94_Gentilly_MAT_NB_1848_833 a rico:RecordPart ;
#     cad:hasNumFolio "833"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0335_page .
#
# source:94_Gentilly_MAT_NB_1848_834 a rico:RecordPart ;
#     cad:hasNumFolio "834"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0336_page .
#
# source:94_Gentilly_MAT_NB_1848_836 a rico:RecordPart ;
#     cad:hasNumFolio "836"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0338_page .
#
# source:94_Gentilly_MAT_NB_1848_837 a rico:RecordPart ;
#     cad:hasNumFolio "837"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0339_page .
#
# source:94_Gentilly_MAT_NB_1848_843 a rico:RecordPart ;
#     cad:hasNumFolio "843"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0345_page .
#
# source:94_Gentilly_MAT_NB_1848_844 a rico:RecordPart ;
#     cad:hasNumFolio "844"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0346_page .
#
# source:94_Gentilly_MAT_NB_1848_845 a rico:RecordPart ;
#     cad:hasNumFolio "845"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0347_page .
#
# source:94_Gentilly_MAT_NB_1848_846 a rico:RecordPart ;
#     cad:hasNumFolio "846"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0348_page .
#
# source:94_Gentilly_MAT_NB_1848_847 a rico:RecordPart ;
#     cad:hasNumFolio "847"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0349_page .
#
# source:94_Gentilly_MAT_NB_1848_848 a rico:RecordPart ;
#     cad:hasNumFolio "848"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0350_page .
#
# source:94_Gentilly_MAT_NB_1848_849 a rico:RecordPart ;
#     cad:hasNumFolio "849"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0351_page .
#
# source:94_Gentilly_MAT_NB_1848_851 a rico:RecordPart ;
#     cad:hasNumFolio "851"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0353_page .
#
# source:94_Gentilly_MAT_NB_1848_852 a rico:RecordPart ;
#     cad:hasNumFolio "852"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0354_page .
#
# source:94_Gentilly_MAT_NB_1848_853 a rico:RecordPart ;
#     cad:hasNumFolio "853"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0355_page .
#
# source:94_Gentilly_MAT_NB_1848_854 a rico:RecordPart ;
#     cad:hasNumFolio "854"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0356_page .
#
# source:94_Gentilly_MAT_NB_1848_855 a rico:RecordPart ;
#     cad:hasNumFolio "855"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0357_page .
#
# source:94_Gentilly_MAT_NB_1848_856 a rico:RecordPart ;
#     cad:hasNumFolio "856"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0358_page .
#
# source:94_Gentilly_MAT_NB_1848_857 a rico:RecordPart ;
#     cad:hasNumFolio "857"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0359_page .
#
# source:94_Gentilly_MAT_NB_1848_858 a rico:RecordPart ;
#     cad:hasNumFolio "858"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0360_page .
#
# source:94_Gentilly_MAT_NB_1848_859 a rico:RecordPart ;
#     cad:hasNumFolio "859"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0361_page .
#
# source:94_Gentilly_MAT_NB_1848_860 a rico:RecordPart ;
#     cad:hasNumFolio "860"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0362_page .
#
# source:94_Gentilly_MAT_NB_1848_861 a rico:RecordPart ;
#     cad:hasNumFolio "861"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0363_page .
#
# source:94_Gentilly_MAT_NB_1848_862 a rico:RecordPart ;
#     cad:hasNumFolio "862"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0364_page .
#
# source:94_Gentilly_MAT_NB_1848_863 a rico:RecordPart ;
#     cad:hasNumFolio "863"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0365_page .
#
# source:94_Gentilly_MAT_NB_1848_864 a rico:RecordPart ;
#     cad:hasNumFolio "864"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0366_page .
#
# source:94_Gentilly_MAT_NB_1848_865 a rico:RecordPart ;
#     cad:hasNumFolio "865"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0367_page .
#
# source:94_Gentilly_MAT_NB_1848_866 a rico:RecordPart ;
#     cad:hasNumFolio "866"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0368_page .
#
# source:94_Gentilly_MAT_NB_1848_867 a rico:RecordPart ;
#     cad:hasNumFolio "867"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0369_page .
#
# source:94_Gentilly_MAT_NB_1848_868 a rico:RecordPart ;
#     cad:hasNumFolio "868"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0370_page .
#
# source:94_Gentilly_MAT_NB_1848_869 a rico:RecordPart ;
#     cad:hasNumFolio "869"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0371_page .
#
# source:94_Gentilly_MAT_NB_1848_870 a rico:RecordPart ;
#     cad:hasNumFolio "870"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0372_page .
#
# source:94_Gentilly_MAT_NB_1848_871 a rico:RecordPart ;
#     cad:hasNumFolio "871"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0373_page .
#
# source:94_Gentilly_MAT_NB_1848_872 a rico:RecordPart ;
#     cad:hasNumFolio "872"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0374_page .
#
# source:94_Gentilly_MAT_NB_1848_873 a rico:RecordPart ;
#     cad:hasNumFolio "873"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0375_page .
#
# source:94_Gentilly_MAT_NB_1848_874 a rico:RecordPart ;
#     cad:hasNumFolio "874"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0376_page .
#
# source:94_Gentilly_MAT_NB_1848_875 a rico:RecordPart ;
#     cad:hasNumFolio "875"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0377_page .
#
# source:94_Gentilly_MAT_NB_1848_876 a rico:RecordPart ;
#     cad:hasNumFolio "876"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0378_page .
#
# source:94_Gentilly_MAT_NB_1848_877 a rico:RecordPart ;
#     cad:hasNumFolio "877"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0379_page .
#
# source:94_Gentilly_MAT_NB_1848_878 a rico:RecordPart ;
#     cad:hasNumFolio "878"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0380_page .
#
# source:94_Gentilly_MAT_NB_1848_879 a rico:RecordPart ;
#     cad:hasNumFolio "879"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0381_page .
#
# source:94_Gentilly_MAT_NB_1848_880 a rico:RecordPart ;
#     cad:hasNumFolio "880"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0382_page .

# %% [markdown]
# #### Création des folios issus de "Tiré de" et "Porté à" qui ne sont pas dans la colonne 'Num_Folios'

# %%
# Iterate over each row in the DataFrame
for index, row in folios.iterrows():
    if row['Tire_de_clean'] != 'EMPTY':
        ls = row['Tire_de_clean'].split(";")
        for l in ls:
            if any(num.isdigit() for num in l) and 'mission' not in l:
                MATRICE_ID = matrices_metada[row['registre']]["MATRICE_ID"]

                subject_uri = URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{MATRICE_ID}_{str(l)}")
                g.add((subject_uri, RDF.type, rico.RecordPart))
                g.add((subject_uri, cad.isSourceType, URIRef(srctype.Folio)))
                g.add((subject_uri, cad.hasNumFolio, Literal(l,datatype=XSD.string)))

# %%
# Iterate over each row in the DataFrame
for index, row in folios.iterrows():
    if row['Porte_a_clean'] != 'EMPTY':
        ls = row['Porte_a_clean'].split(";")
        for l in ls:
            #test if str has digit
            if any(num.isdigit() for num in l) and 'mission' not in l:
                MATRICE_ID = matrices_metada[row['registre']]["MATRICE_ID"]

                subject_uri = URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{MATRICE_ID}_{str(l)}")
                g.add((subject_uri, RDF.type, rico.RecordPart))
                g.add((subject_uri, cad.isSourceType, URIRef(srctype.Folio)))
                g.add((subject_uri, cad.hasNumFolio, Literal(l,datatype=XSD.string)))

# %%
print(g.serialize(format='turtle'))
g.serialize(destination=f"{OUTPUT_FOLDER_PATH}/{COMMUNE}_sources_folios.ttl", format='turtle')
# Out:
# @prefix cad: <http://data.ign.fr/def/cadastre#> .
# @prefix rico: <https://www.ica.org/standards/RiC/ontology#> .
# @prefix source: <http://data.ign.fr/id/source/> .
# @prefix srctype: <http://data.ign.fr/id/codes/cadastre/sourceType/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# source:94_Gentilly_MAT_B_NB_1813_107bis a rico:RecordPart ;
#     cad:hasNumFolio "107bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0125_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_107↑2↓> a rico:RecordPart ;
#     cad:hasNumFolio "107↑2↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_B_NB_1813_11 a rico:RecordPart ;
#     cad:hasNumFolio "11"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0015_page .
#
# source:94_Gentilly_MAT_B_NB_1813_122bis a rico:RecordPart ;
#     cad:hasNumFolio "122bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0146_page .
#
# source:94_Gentilly_MAT_B_NB_1813_124bis a rico:RecordPart ;
#     cad:hasNumFolio "124bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0148_page .
#
# source:94_Gentilly_MAT_B_NB_1813_138 a rico:RecordPart ;
#     cad:hasNumFolio "138"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0165_page .
#
# source:94_Gentilly_MAT_B_NB_1813_156 a rico:RecordPart ;
#     cad:hasNumFolio "156"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0186_page .
#
# source:94_Gentilly_MAT_B_NB_1813_163 a rico:RecordPart ;
#     cad:hasNumFolio "163"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0196_page .
#
# source:94_Gentilly_MAT_B_NB_1813_166 a rico:RecordPart ;
#     cad:hasNumFolio "166"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0199_page .
#
# source:94_Gentilly_MAT_B_NB_1813_192bis a rico:RecordPart ;
#     cad:hasNumFolio "192bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0224_page .
#
# source:94_Gentilly_MAT_B_NB_1813_211 a rico:RecordPart ;
#     cad:hasNumFolio "211"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0245_page .
#
# source:94_Gentilly_MAT_B_NB_1813_211bis a rico:RecordPart ;
#     cad:hasNumFolio "211bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0245_page .
#
# source:94_Gentilly_MAT_B_NB_1813_220 a rico:RecordPart ;
#     cad:hasNumFolio "220"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0259_page .
#
# source:94_Gentilly_MAT_B_NB_1813_228 a rico:RecordPart ;
#     cad:hasNumFolio "228"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_B_NB_1813_228ter a rico:RecordPart ;
#     cad:hasNumFolio "228ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0270_page .
#
# source:94_Gentilly_MAT_B_NB_1813_235bis a rico:RecordPart ;
#     cad:hasNumFolio "235bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0278_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_235↑2↓> a rico:RecordPart ;
#     cad:hasNumFolio "235↑2↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_B_NB_1813_236 a rico:RecordPart ;
#     cad:hasNumFolio "236"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0279_page .
#
# source:94_Gentilly_MAT_B_NB_1813_236ter a rico:RecordPart ;
#     cad:hasNumFolio "236ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0281_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_236↑4↓> a rico:RecordPart ;
#     cad:hasNumFolio "236↑4↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0281_page .
#
# source:94_Gentilly_MAT_B_NB_1813_238 a rico:RecordPart ;
#     cad:hasNumFolio "238"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_B_NB_1813_23bis a rico:RecordPart ;
#     cad:hasNumFolio "23bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0032_page .
#
# source:94_Gentilly_MAT_B_NB_1813_247 a rico:RecordPart ;
#     cad:hasNumFolio "247"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0294_page .
#
# source:94_Gentilly_MAT_B_NB_1813_247ter a rico:RecordPart ;
#     cad:hasNumFolio "247ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_B_NB_1813_251bis a rico:RecordPart ;
#     cad:hasNumFolio "251bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0301_page .
#
# source:94_Gentilly_MAT_B_NB_1813_258 a rico:RecordPart ;
#     cad:hasNumFolio "258"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0310_page .
#
# source:94_Gentilly_MAT_B_NB_1813_260 a rico:RecordPart ;
#     cad:hasNumFolio "260"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0313_page .
#
# source:94_Gentilly_MAT_B_NB_1813_268 a rico:RecordPart ;
#     cad:hasNumFolio "268"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0324_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_269²> a rico:RecordPart ;
#     cad:hasNumFolio "269↑2↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0325_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_269↑2↓> a rico:RecordPart ;
#     cad:hasNumFolio "269↑2↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_274↑2↓> a rico:RecordPart ;
#     cad:hasNumFolio "274↑2↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_B_NB_1813_280bis a rico:RecordPart ;
#     cad:hasNumFolio "280bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0333_page .
#
# source:94_Gentilly_MAT_B_NB_1813_281 a rico:RecordPart ;
#     cad:hasNumFolio "281"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0334_page .
#
# source:94_Gentilly_MAT_B_NB_1813_293 a rico:RecordPart ;
#     cad:hasNumFolio "293"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0350_page .
#
# source:94_Gentilly_MAT_B_NB_1813_295 a rico:RecordPart ;
#     cad:hasNumFolio "295"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0352_page .
#
# source:94_Gentilly_MAT_B_NB_1813_298bis a rico:RecordPart ;
#     cad:hasNumFolio "298bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0355_page .
#
# source:94_Gentilly_MAT_B_NB_1813_302 a rico:RecordPart ;
#     cad:hasNumFolio "302"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0359_page .
#
# source:94_Gentilly_MAT_B_NB_1813_34ter a rico:RecordPart ;
#     cad:hasNumFolio "34ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0044_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_B_NB_1813_351↑4↓> a rico:RecordPart ;
#     cad:hasNumFolio "351↑4↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0414_page .
#
# source:94_Gentilly_MAT_B_NB_1813_357 a rico:RecordPart ;
#     cad:hasNumFolio "357"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0420_page .
#
# source:94_Gentilly_MAT_B_NB_1813_361 a rico:RecordPart ;
#     cad:hasNumFolio "361"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0424_page .
#
# source:94_Gentilly_MAT_B_NB_1813_373bis a rico:RecordPart ;
#     cad:hasNumFolio "373bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0440_page .
#
# source:94_Gentilly_MAT_B_NB_1813_383 a rico:RecordPart ;
#     cad:hasNumFolio "383"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0451_page .
#
# source:94_Gentilly_MAT_B_NB_1813_397ter a rico:RecordPart ;
#     cad:hasNumFolio "397ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0465_page .
#
# source:94_Gentilly_MAT_B_NB_1813_440 a rico:RecordPart ;
#     cad:hasNumFolio "440"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0509_page .
#
# source:94_Gentilly_MAT_B_NB_1813_446 a rico:RecordPart ;
#     cad:hasNumFolio "446"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0516_page .
#
# source:94_Gentilly_MAT_B_NB_1813_455 a rico:RecordPart ;
#     cad:hasNumFolio "455"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0526_page .
#
# source:94_Gentilly_MAT_B_NB_1813_46bis a rico:RecordPart ;
#     cad:hasNumFolio "46bis"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000255_01_0057_page .
#
# source:94_Gentilly_MAT_B_NB_1813_46ter a rico:RecordPart ;
#     cad:hasNumFolio "46ter"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1836_126 a rico:RecordPart ;
#     cad:hasNumFolio "126"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1836_240 a rico:RecordPart ;
#     cad:hasNumFolio "240"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0293_page .
#
# source:94_Gentilly_MAT_NB_1836_247 a rico:RecordPart ;
#     cad:hasNumFolio "247"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0300_page .
#
# source:94_Gentilly_MAT_NB_1836_248 a rico:RecordPart ;
#     cad:hasNumFolio "248"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0301_page .
#
# source:94_Gentilly_MAT_NB_1836_249 a rico:RecordPart ;
#     cad:hasNumFolio "249"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0302_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_NB_1836_249↑16↓> a rico:RecordPart ;
#     cad:hasNumFolio "249↑16↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1836_250 a rico:RecordPart ;
#     cad:hasNumFolio "250"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0303_page .
#
# source:94_Gentilly_MAT_NB_1836_286 a rico:RecordPart ;
#     cad:hasNumFolio "286"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0339_page .
#
# source:94_Gentilly_MAT_NB_1836_287 a rico:RecordPart ;
#     cad:hasNumFolio "287"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0340_page .
#
# source:94_Gentilly_MAT_NB_1836_288 a rico:RecordPart ;
#     cad:hasNumFolio "288"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0341_page .
#
# source:94_Gentilly_MAT_NB_1836_289 a rico:RecordPart ;
#     cad:hasNumFolio "289"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0342_page .
#
# source:94_Gentilly_MAT_NB_1836_290 a rico:RecordPart ;
#     cad:hasNumFolio "290"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0343_page .
#
# source:94_Gentilly_MAT_NB_1836_291 a rico:RecordPart ;
#     cad:hasNumFolio "291"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0344_page .
#
# source:94_Gentilly_MAT_NB_1836_292 a rico:RecordPart ;
#     cad:hasNumFolio "292"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0345_page .
#
# source:94_Gentilly_MAT_NB_1836_319 a rico:RecordPart ;
#     cad:hasNumFolio "319"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0372_page .
#
# source:94_Gentilly_MAT_NB_1836_432 a rico:RecordPart ;
#     cad:hasNumFolio "432"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0485_page .
#
# source:94_Gentilly_MAT_NB_1836_433 a rico:RecordPart ;
#     cad:hasNumFolio "433"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0486_page .
#
# source:94_Gentilly_MAT_NB_1836_434 a rico:RecordPart ;
#     cad:hasNumFolio "434"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0487_page .
#
# source:94_Gentilly_MAT_NB_1836_435 a rico:RecordPart ;
#     cad:hasNumFolio "435"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0488_page .
#
# source:94_Gentilly_MAT_NB_1836_436 a rico:RecordPart ;
#     cad:hasNumFolio "436"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0489_page .
#
# source:94_Gentilly_MAT_NB_1836_437 a rico:RecordPart ;
#     cad:hasNumFolio "437"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0490_page .
#
# source:94_Gentilly_MAT_NB_1836_439 a rico:RecordPart ;
#     cad:hasNumFolio "439"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0492_page .
#
# source:94_Gentilly_MAT_NB_1836_440 a rico:RecordPart ;
#     cad:hasNumFolio "440"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0493_page .
#
# source:94_Gentilly_MAT_NB_1836_441 a rico:RecordPart ;
#     cad:hasNumFolio "441"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0494_page .
#
# source:94_Gentilly_MAT_NB_1836_442 a rico:RecordPart ;
#     cad:hasNumFolio "442"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0495_page .
#
# source:94_Gentilly_MAT_NB_1836_443 a rico:RecordPart ;
#     cad:hasNumFolio "443"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0496_page .
#
# source:94_Gentilly_MAT_NB_1836_444 a rico:RecordPart ;
#     cad:hasNumFolio "444"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0497_page .
#
# source:94_Gentilly_MAT_NB_1836_445 a rico:RecordPart ;
#     cad:hasNumFolio "445"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0498_page .
#
# source:94_Gentilly_MAT_NB_1836_446 a rico:RecordPart ;
#     cad:hasNumFolio "446"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0499_page .
#
# source:94_Gentilly_MAT_NB_1836_447 a rico:RecordPart ;
#     cad:hasNumFolio "447"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0500_page .
#
# source:94_Gentilly_MAT_NB_1836_448 a rico:RecordPart ;
#     cad:hasNumFolio "448"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0501_page .
#
# source:94_Gentilly_MAT_NB_1836_449 a rico:RecordPart ;
#     cad:hasNumFolio "449"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0502_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_NB_1836_449↑1↓> a rico:RecordPart ;
#     cad:hasNumFolio "449↑1↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1836_450 a rico:RecordPart ;
#     cad:hasNumFolio "450"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0503_page .
#
# source:94_Gentilly_MAT_NB_1836_451 a rico:RecordPart ;
#     cad:hasNumFolio "451"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0504_page .
#
# source:94_Gentilly_MAT_NB_1836_452 a rico:RecordPart ;
#     cad:hasNumFolio "452"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0505_page .
#
# source:94_Gentilly_MAT_NB_1836_453 a rico:RecordPart ;
#     cad:hasNumFolio "453"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000256_01_0506_page .
#
# source:94_Gentilly_MAT_NB_1836_533 a rico:RecordPart ;
#     cad:hasNumFolio "533"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1836_617 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "77"^^xsd:string ;
#     cad:hasNumFolio "617"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0137_page .
#
# source:94_Gentilly_MAT_NB_1836_669 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "129"^^xsd:string ;
#     cad:hasNumFolio "669"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0189_page .
#
# source:94_Gentilly_MAT_NB_1836_707 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "167"^^xsd:string ;
#     cad:hasNumFolio "707"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0227_page .
#
# source:94_Gentilly_MAT_NB_1836_708 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "168"^^xsd:string ;
#     cad:hasNumFolio "708"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0228_page .
#
# source:94_Gentilly_MAT_NB_1836_777 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "235"^^xsd:string ;
#     cad:hasNumFolio "777"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0295_page .
#
# source:94_Gentilly_MAT_NB_1836_788 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "248"^^xsd:string ;
#     cad:hasNumFolio "788"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0308_page .
#
# source:94_Gentilly_MAT_NB_1836_968 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "428"^^xsd:string ;
#     cad:hasNumFolio "968"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000257_01_0488_page .
#
# source:94_Gentilly_MAT_NB_1848_1213 a rico:RecordPart ;
#     cad:hasNumFolio "1213"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0213_page .
#
# source:94_Gentilly_MAT_NB_1848_1214 a rico:RecordPart ;
#     cad:hasNumFolio "1214"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0214_page .
#
# source:94_Gentilly_MAT_NB_1848_1215 a rico:RecordPart ;
#     cad:hasNumFolio "1215"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0215_page .
#
# source:94_Gentilly_MAT_NB_1848_1216 a rico:RecordPart ;
#     cad:hasNumFolio "1216"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0216_page .
#
# source:94_Gentilly_MAT_NB_1848_1217 a rico:RecordPart ;
#     cad:hasNumFolio "1217"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0217_page .
#
# source:94_Gentilly_MAT_NB_1848_1218 a rico:RecordPart ;
#     cad:hasNumFolio "1218"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0218_page .
#
# source:94_Gentilly_MAT_NB_1848_1219 a rico:RecordPart ;
#     cad:hasNumFolio "1219"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0219_page .
#
# source:94_Gentilly_MAT_NB_1848_1220 a rico:RecordPart ;
#     cad:hasNumFolio "1220"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0220_page .
#
# source:94_Gentilly_MAT_NB_1848_1221 a rico:RecordPart ;
#     cad:hasNumFolio "1221"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0221_page .
#
# source:94_Gentilly_MAT_NB_1848_1222 a rico:RecordPart ;
#     cad:hasNumFolio "1222"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000264_01_0222_page .
#
# source:94_Gentilly_MAT_NB_1848_2115 a rico:RecordPart ;
#     cad:hasNumFolio "2115"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1848_2430 a rico:RecordPart ;
#     cad:hasNumFolio "2430"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1848_392 a rico:RecordPart ;
#     cad:hasNumFolio "392"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0445_page .
#
# source:94_Gentilly_MAT_NB_1848_393 a rico:RecordPart ;
#     cad:hasNumFolio "393"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0446_page .
#
# source:94_Gentilly_MAT_NB_1848_394 a rico:RecordPart ;
#     cad:hasNumFolio "394"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0447_page .
#
# source:94_Gentilly_MAT_NB_1848_395 a rico:RecordPart ;
#     cad:hasNumFolio "395"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0448_page .
#
# source:94_Gentilly_MAT_NB_1848_396 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "496"^^xsd:string ;
#     cad:hasNumFolio "396"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0449_page .
#
# source:94_Gentilly_MAT_NB_1848_397 a rico:RecordPart ;
#     cad:hasAlternativeNumFolio "497"^^xsd:string ;
#     cad:hasNumFolio "397"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0450_page .
#
# source:94_Gentilly_MAT_NB_1848_398 a rico:RecordPart ;
#     cad:hasNumFolio "398"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0451_page .
#
# source:94_Gentilly_MAT_NB_1848_399 a rico:RecordPart ;
#     cad:hasNumFolio "399"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0452_page .
#
# source:94_Gentilly_MAT_NB_1848_400 a rico:RecordPart ;
#     cad:hasNumFolio "400"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0453_page .
#
# source:94_Gentilly_MAT_NB_1848_401 a rico:RecordPart ;
#     cad:hasNumFolio "401"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0454_page .
#
# source:94_Gentilly_MAT_NB_1848_402 a rico:RecordPart ;
#     cad:hasNumFolio "402"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0455_page .
#
# source:94_Gentilly_MAT_NB_1848_403 a rico:RecordPart ;
#     cad:hasNumFolio "403"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0456_page .
#
# source:94_Gentilly_MAT_NB_1848_465 a rico:RecordPart ;
#     cad:hasNumFolio "465"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000259_01_0518_page .
#
# source:94_Gentilly_MAT_NB_1848_513 a rico:RecordPart ;
#     cad:hasNumFolio "513"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0013_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_NB_1848_513↑25↓> a rico:RecordPart ;
#     cad:hasNumFolio "513↑25↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1848_827 a rico:RecordPart ;
#     cad:hasNumFolio "827"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0329_page .
#
# source:94_Gentilly_MAT_NB_1848_828 a rico:RecordPart ;
#     cad:hasNumFolio "828"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0330_page .
#
# source:94_Gentilly_MAT_NB_1848_829 a rico:RecordPart ;
#     cad:hasNumFolio "829"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0331_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_NB_1848_829↑20↓> a rico:RecordPart ;
#     cad:hasNumFolio "829↑20↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1848_830 a rico:RecordPart ;
#     cad:hasNumFolio "830"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0332_page .
#
# source:94_Gentilly_MAT_NB_1848_831 a rico:RecordPart ;
#     cad:hasNumFolio "831"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0333_page .
#
# source:94_Gentilly_MAT_NB_1848_832 a rico:RecordPart ;
#     cad:hasNumFolio "832"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0334_page .
#
# source:94_Gentilly_MAT_NB_1848_833 a rico:RecordPart ;
#     cad:hasNumFolio "833"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0335_page .
#
# source:94_Gentilly_MAT_NB_1848_834 a rico:RecordPart ;
#     cad:hasNumFolio "834"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0336_page .
#
# source:94_Gentilly_MAT_NB_1848_836 a rico:RecordPart ;
#     cad:hasNumFolio "836"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0338_page .
#
# source:94_Gentilly_MAT_NB_1848_837 a rico:RecordPart ;
#     cad:hasNumFolio "837"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0339_page .
#
# source:94_Gentilly_MAT_NB_1848_843 a rico:RecordPart ;
#     cad:hasNumFolio "843"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0345_page .
#
# source:94_Gentilly_MAT_NB_1848_844 a rico:RecordPart ;
#     cad:hasNumFolio "844"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0346_page .
#
# source:94_Gentilly_MAT_NB_1848_845 a rico:RecordPart ;
#     cad:hasNumFolio "845"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0347_page .
#
# source:94_Gentilly_MAT_NB_1848_846 a rico:RecordPart ;
#     cad:hasNumFolio "846"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0348_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_NB_1848_846↑2↓> a rico:RecordPart ;
#     cad:hasNumFolio "846↑2↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1848_847 a rico:RecordPart ;
#     cad:hasNumFolio "847"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0349_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_NB_1848_847↑2↓> a rico:RecordPart ;
#     cad:hasNumFolio "847↑2↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_NB_1848_847↑3↓> a rico:RecordPart ;
#     cad:hasNumFolio "847↑3↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1848_848 a rico:RecordPart ;
#     cad:hasNumFolio "848"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0350_page .
#
# <http://data.ign.fr/id/source/94_Gentilly_MAT_NB_1848_848↑3↓> a rico:RecordPart ;
#     cad:hasNumFolio "848↑3↓"^^xsd:string ;
#     cad:isSourceType srctype:Folio .
#
# source:94_Gentilly_MAT_NB_1848_849 a rico:RecordPart ;
#     cad:hasNumFolio "849"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0351_page .
#
# source:94_Gentilly_MAT_NB_1848_851 a rico:RecordPart ;
#     cad:hasNumFolio "851"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0353_page .
#
# source:94_Gentilly_MAT_NB_1848_852 a rico:RecordPart ;
#     cad:hasNumFolio "852"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0354_page .
#
# source:94_Gentilly_MAT_NB_1848_853 a rico:RecordPart ;
#     cad:hasNumFolio "853"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0355_page .
#
# source:94_Gentilly_MAT_NB_1848_854 a rico:RecordPart ;
#     cad:hasNumFolio "854"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0356_page .
#
# source:94_Gentilly_MAT_NB_1848_855 a rico:RecordPart ;
#     cad:hasNumFolio "855"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0357_page .
#
# source:94_Gentilly_MAT_NB_1848_856 a rico:RecordPart ;
#     cad:hasNumFolio "856"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0358_page .
#
# source:94_Gentilly_MAT_NB_1848_857 a rico:RecordPart ;
#     cad:hasNumFolio "857"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0359_page .
#
# source:94_Gentilly_MAT_NB_1848_858 a rico:RecordPart ;
#     cad:hasNumFolio "858"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0360_page .
#
# source:94_Gentilly_MAT_NB_1848_859 a rico:RecordPart ;
#     cad:hasNumFolio "859"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0361_page .
#
# source:94_Gentilly_MAT_NB_1848_860 a rico:RecordPart ;
#     cad:hasNumFolio "860"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0362_page .
#
# source:94_Gentilly_MAT_NB_1848_861 a rico:RecordPart ;
#     cad:hasNumFolio "861"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0363_page .
#
# source:94_Gentilly_MAT_NB_1848_862 a rico:RecordPart ;
#     cad:hasNumFolio "862"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0364_page .
#
# source:94_Gentilly_MAT_NB_1848_863 a rico:RecordPart ;
#     cad:hasNumFolio "863"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0365_page .
#
# source:94_Gentilly_MAT_NB_1848_864 a rico:RecordPart ;
#     cad:hasNumFolio "864"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0366_page .
#
# source:94_Gentilly_MAT_NB_1848_865 a rico:RecordPart ;
#     cad:hasNumFolio "865"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0367_page .
#
# source:94_Gentilly_MAT_NB_1848_866 a rico:RecordPart ;
#     cad:hasNumFolio "866"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0368_page .
#
# source:94_Gentilly_MAT_NB_1848_867 a rico:RecordPart ;
#     cad:hasNumFolio "867"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0369_page .
#
# source:94_Gentilly_MAT_NB_1848_868 a rico:RecordPart ;
#     cad:hasNumFolio "868"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0370_page .
#
# source:94_Gentilly_MAT_NB_1848_869 a rico:RecordPart ;
#     cad:hasNumFolio "869"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0371_page .
#
# source:94_Gentilly_MAT_NB_1848_870 a rico:RecordPart ;
#     cad:hasNumFolio "870"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0372_page .
#
# source:94_Gentilly_MAT_NB_1848_871 a rico:RecordPart ;
#     cad:hasNumFolio "871"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0373_page .
#
# source:94_Gentilly_MAT_NB_1848_872 a rico:RecordPart ;
#     cad:hasNumFolio "872"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0374_page .
#
# source:94_Gentilly_MAT_NB_1848_873 a rico:RecordPart ;
#     cad:hasNumFolio "873"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0375_page .
#
# source:94_Gentilly_MAT_NB_1848_874 a rico:RecordPart ;
#     cad:hasNumFolio "874"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0376_page .
#
# source:94_Gentilly_MAT_NB_1848_875 a rico:RecordPart ;
#     cad:hasNumFolio "875"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0377_page .
#
# source:94_Gentilly_MAT_NB_1848_876 a rico:RecordPart ;
#     cad:hasNumFolio "876"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0378_page .
#
# source:94_Gentilly_MAT_NB_1848_877 a rico:RecordPart ;
#     cad:hasNumFolio "877"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0379_page .
#
# source:94_Gentilly_MAT_NB_1848_878 a rico:RecordPart ;
#     cad:hasNumFolio "878"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0380_page .
#
# source:94_Gentilly_MAT_NB_1848_879 a rico:RecordPart ;
#     cad:hasNumFolio "879"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0381_page .
#
# source:94_Gentilly_MAT_NB_1848_880 a rico:RecordPart ;
#     cad:hasNumFolio "880"^^xsd:string ;
#     cad:isSourceType srctype:Folio ;
#     rico:isOrWasConstituentOf source:94_Gentilly_FRAD094_3P_000263_01_0382_page .
# <Graph identifier=N47276db9985949daa56d99a0657033b8 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### 1.3 Adresses

# %%
# Select the column as a new DataFrame
addresses = matrices[['registre','Lieu-dit_treated','Lieu-dit_type']].copy().drop_duplicates().reset_index(drop=True)
addresses
# Out:
#      registre        Lieu-dit_treated Lieu-dit_type
# 0    MAT_1813                     NaN           NaN
# 1    MAT_1813          Les Girantiers      District
# 2    MAT_1813              Rue Thiers  Thoroughfare
# 3    MAT_1813           Les Girantins      District
# 4    MAT_1813           Rue Thiers;10       Address
# ..        ...                     ...           ...
# 130  MAT_1848  Barrière d'Italie;8↑B↓       Address
# 131  MAT_1848  Barrière d'Italie;8↑A↓       Address
# 132  MAT_1848     Barrière d'Italie;6       Address
# 133  MAT_1848     Barrière d'Italie;4       Address
# 134  MAT_1848     Barrière d'Italie;2       Address
#
# [135 rows x 3 columns]

# %%
multipart_addresses_street = []
multipart_addresses_street_number = []
multipart_addresses_street_type = []
multipart_addresses_street_number_type = []


for index, row in addresses.iterrows():
    tag = str(row["Lieu-dit_treated"])
    if ';' in tag:
        add = tag.split(";")
        add_street_or_district = add[0]
        add_num_or_part = add[1]

        multipart_addresses_street.append(add_street_or_district)
        multipart_addresses_street_number.append(add_num_or_part)

        #test if digit
        if any(num.isdigit() for num in add_num_or_part):
            multipart_addresses_street_type.append('Thoroughfare')
            multipart_addresses_street_number_type.append('StreetNumber')
        else:
            multipart_addresses_street_type.append('District')
            multipart_addresses_street_number_type.append('Undefined')

    else:
        multipart_addresses_street.append('')
        multipart_addresses_street_number.append('')
        multipart_addresses_street_type.append('')
        multipart_addresses_street_number_type.append('')

addresses['part_street_district'] = multipart_addresses_street
addresses['part_street_number'] = multipart_addresses_street_number
addresses['part_street_district_type'] = multipart_addresses_street_type
addresses['part_street_number_type'] = multipart_addresses_street_number_type

#assign a distinct uuid for each group of rows with same values in Lieu-dit_treated and registre
addresses['address_uuid'] = [uuid.uuid4() for _ in range(len(addresses))]

addresses
# Out:
#      registre        Lieu-dit_treated Lieu-dit_type part_street_district  \
# 0    MAT_1813                     NaN           NaN
# 1    MAT_1813          Les Girantiers      District
# 2    MAT_1813              Rue Thiers  Thoroughfare
# 3    MAT_1813           Les Girantins      District
# 4    MAT_1813           Rue Thiers;10       Address           Rue Thiers
# ..        ...                     ...           ...                  ...
# 130  MAT_1848  Barrière d'Italie;8↑B↓       Address    Barrière d'Italie
# 131  MAT_1848  Barrière d'Italie;8↑A↓       Address    Barrière d'Italie
# 132  MAT_1848     Barrière d'Italie;6       Address    Barrière d'Italie
# 133  MAT_1848     Barrière d'Italie;4       Address    Barrière d'Italie
# 134  MAT_1848     Barrière d'Italie;2       Address    Barrière d'Italie
#
#     part_street_number part_street_district_type part_street_number_type  \
# 0
# 1
# 2
# 3
# 4                   10              Thoroughfare            StreetNumber
# ..                 ...                       ...                     ...
# 130               8↑B↓              Thoroughfare            StreetNumber
# 131               8↑A↓              Thoroughfare            StreetNumber
# 132                  6              Thoroughfare            StreetNumber
# 133                  4              Thoroughfare            StreetNumber
# 134                  2              Thoroughfare            StreetNumber
#
#                              address_uuid
# 0    6c4685f5-44ec-4bb6-8a0e-857baa441dbe
# 1    e2f36335-76fe-4a6f-9b2d-c4d4f29f3aeb
# 2    d4b95ace-206a-4b79-a864-31925ed0f615
# 3    e033fc6a-5108-428e-b78d-5bc054ba9c7a
# 4    7fcaa298-6916-40c2-ae54-e9de7a34be99
# ..                                    ...
# 130  b7685ae0-e0f2-4ee7-a43d-05e08b08920f
# 131  b64ea83c-0ab8-48b3-9a1b-8ebe769088cc
# 132  5528e930-5b1c-47c7-9f4c-8702374f09ef
# 133  82096970-aa8a-4451-ae0d-de0a7c1b201d
# 134  a0161fe8-05cd-42f9-b94a-f14162ade38c
#
# [135 rows x 8 columns]

# %%
import pandas as pd
import uuid

# Create a new column 'part_street_district_uuid'
addresses['part_street_district_uuid'] = None

# Create a dictionary to store the uuid for each unique part_street_district
uuid_dict = {}

# Iterate over the DataFrame
for i, row in addresses.iterrows():
    if row['part_street_district'] != '':
        # Check if the part_street_district value is equal to one of the Lieu-dit_treated values
        if row['part_street_district'] in addresses['Lieu-dit_treated'].values:
            # If yes, set the part_street_district_uuid to the uuid of the retrieved Lieu-dit_treated
            addresses.loc[i, 'part_street_district_uuid'] = addresses.loc[addresses['Lieu-dit_treated'] == row['part_street_district'], 'address_uuid'].values[0]
        else:
            # If no, check if the part_street_district value has other occurrences in the part_street_district column
            if row['part_street_district'] in addresses['part_street_district'].values:
                # If yes, check if the part_street_district value is already in the uuid_dict
                if row['part_street_district'] in uuid_dict:
                    # If yes, assign the same uuid
                    addresses.loc[i, 'part_street_district_uuid'] = uuid_dict[row['part_street_district']]
                else:
                    # If no, create a new uuid and add it to the uuid_dict
                    new_uuid = uuid.uuid4()
                    uuid_dict[row['part_street_district']] = new_uuid
                    addresses.loc[i, 'part_street_district_uuid'] = new_uuid
            else:
                # If no, create a new uuid
                addresses.loc[i, 'part_street_district_uuid'] = uuid.uuid4()

# %%
uuid_dict
# Out:
# {'Rue Mazagran': UUID('90343130-1fa3-4649-bbcc-f21d54d08387')}

# %%
from namespaces import *

# Create a new RDF graph
g = Graph()

g.bind('landmark', landmarkuri)
g.bind('source', srcuri)

g.bind('cad', cad)
g.bind('add', add)
g.bind('rico', rico)
g.bind('fpo', fpo)
g.bind('time',time)

g.bind("ltype", ltype)
g.bind("lrtype", lrtype)
g.bind("atype", atype)
g.bind('cad_ltype', cad_ltype)

for index, row in addresses.iterrows():
    add_uri = URIRef(landmarkuri + f"{row['address_uuid']}")
    g.add((add_uri, RDF.type, add.Landmark))
    if pd.notnull(addresses.loc[index, 'Lieu-dit_type']):
        if ';' in row['Lieu-dit_treated']:
            name = row['Lieu-dit_treated'].split(";")

            g.add((add_uri, add.isLandmarkType, URIRef(ltype + row['part_street_number_type'])))

            if any(num.isdigit() for num in name[1]):
                g.add((add_uri, SKOS.prefLabel, Literal(name[1] + ' (' + name[0] + ', ' + COMMUNE + ')', datatype=XSD.string)))
                g.add((add_uri, SKOS.altLabel, Literal(name[1] + ' ' + name[0], datatype=XSD.string)))
                g.add((add_uri,SKOS.hiddenLabel,Literal(name[1],datatype=XSD.string))) #Street number from transcription
                relationode = BNode()
                g.add((URIRef(relationode.n3()), add.isLandmarkRelationType, lrtype.Along))
            else:
                g.add((add_uri, SKOS.prefLabel, Literal(name[0] + ' (' + name[1] + ', ' + COMMUNE + ')', datatype=XSD.string)))
                g.add((add_uri, SKOS.altLabel, Literal(name[0], datatype=XSD.string)))
                relationode = BNode()
                g.add((URIRef(relationode.n3()), add.isLandmarkRelationType, lrtype.Undefined))

            g.add((URIRef(relationode.n3()), RDF.type, add.LandmarkRelation))
            g.add((URIRef(relationode.n3()), add.locatum, add_uri))
            g.add((URIRef(relationode.n3()), add.relatum, URIRef(landmarkuri + str(row['part_street_district_uuid']))))

            #Street or district relation with section
            sectionNode = BNode()
            g.add((URIRef(sectionNode.n3()), RDF.type, add.LandmarkRelation))
            g.add((URIRef(sectionNode.n3()), add.isLandmarkRelationType, lrtype.Within))
            g.add((URIRef(sectionNode.n3()), add.locatum, URIRef(landmarkuri + str(row['part_street_district_uuid']))))
            if row['registre'] != 'MAT_1848':
                g.add((URIRef(sectionNode.n3()), add.relatum, URIRef(landmarkuri + 'da6a5c2c-e86d-43bb-8950-7169bd0df60a'))) #Section D Cadastre 1848
            else:
                g.add((URIRef(sectionNode.n3()), add.relatum, URIRef(landmarkuri + '87d7c2f6-306b-45a1-a833-5e17821c3102'))) #Section B Cadastre 1811

        else:
            g.add((add_uri, add.isLandmarkType, URIRef(ltype + f"{row['Lieu-dit_type']}")))
            g.add((add_uri, SKOS.prefLabel, Literal(row['Lieu-dit_treated'] + ', ' + COMMUNE, datatype=XSD.string)))
            g.add((add_uri, SKOS.altLabel, Literal(row['Lieu-dit_treated'], datatype=XSD.string)))

            relationode = BNode()
            g.add((URIRef(relationode.n3()), add.isLandmarkRelationType, lrtype.Within))
            g.add((URIRef(relationode.n3()), add.locatum, add_uri))

            sectionNode = BNode()
            g.add((URIRef(sectionNode.n3()), RDF.type, add.LandmarkRelation))
            g.add((URIRef(sectionNode.n3()), add.isLandmarkRelationType, lrtype.Within))
            g.add((URIRef(sectionNode.n3()), add.locatum, add_uri))
;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nc0eec9f203494bfc83a0fe1eea59a31b> add:isLandmarkRelationType lrtype:Within ;
#     add:locatum landmark:473cbe33-f954-4dc1-9c57-b449ec77d2dd .
#
# <_:Nc3c21b436d8e47659c11aadb395da67f> a add:LandmarkRelation ;
#     add:isLandmarkRelationType lrtype:Within ;
#     add:locatum landmark:7c5a1891-c80d-4859-84bf-f5985dce0196 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# ...
#     skos:hiddenLabel "5"^^xsd:string ;
#     skos:prefLabel "5 (Rue Tiers, Gentilly)"^^xsd:string .
#
# landmark:b64ea83c-0ab8-48b3-9a1b-8ebe769088cc a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "8↑A↓ Barrière d'Italie"^^xsd:string ;
#     skos:hiddenLabel "8↑A↓"^^xsd:string ;
#     skos:prefLabel "8↑A↓ (Barrière d'Italie, Gentilly)"^^xsd:string .
#
# landmark:b6c69c95-5f3a-4148-8cc6-3e7f57097d88 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "14 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "14"^^xsd:string ;
#     skos:prefLabel "14 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:b7685ae0-e0f2-4ee7-a43d-05e08b08920f a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "8↑B↓ Barrière d'Italie"^^xsd:string ;
#     skos:hiddenLabel "8↑B↓"^^xsd:string ;
#     skos:prefLabel "8↑B↓ (Barrière d'Italie, Gentilly)"^^xsd:string .
#
# landmark:ba4f3ae6-d214-42cc-81c2-9f1687b63612 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "15 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "15"^^xsd:string ;
#     skos:prefLabel "15 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:bb0abed1-b3a9-45b2-9318-4788bb082903 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "2bis Rue Gérard"^^xsd:string ;
#     skos:hiddenLabel "2bis"^^xsd:string ;
#     skos:prefLabel "2bis (Rue Gérard, Gentilly)"^^xsd:string .
#
# landmark:bf03a373-7b78-430f-ae57-1c1e79aa193c a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "8 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "8"^^xsd:string ;
#     skos:prefLabel "8 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:bfb7da10-6a5e-45f0-9783-14fc560dfef4 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "15 Rue Gérard"^^xsd:string ;
#     skos:hiddenLabel "15"^^xsd:string ;
#     skos:prefLabel "15 (Rue Gérard, Gentilly)"^^xsd:string .
#
# landmark:bfe02cb5-270f-4b5b-8966-6ee5a7432e04 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "16 Rue Gérard"^^xsd:string ;
#     skos:hiddenLabel "16"^^xsd:string ;
#     skos:prefLabel "16 (Rue Gérard, Gentilly)"^^xsd:string .
#
# landmark:bffc9081-7ba5-4edd-9e96-e555d84c383d a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "18bis Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "18bis"^^xsd:string ;
#     skos:prefLabel "18bis (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:c0c28655-d24e-4ae5-bd29-5614e0ac49bb a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "18 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "18"^^xsd:string ;
#     skos:prefLabel "18 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:c34d31cc-7497-4aec-ba4d-72507cd6de3f a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "1/3 Rue Gérard"^^xsd:string ;
#     skos:hiddenLabel "1/3"^^xsd:string ;
#     skos:prefLabel "1/3 (Rue Gérard, Gentilly)"^^xsd:string .
#
# landmark:c53ad97d-157b-440d-b1b6-d01e4a58be22 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "20 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "20"^^xsd:string ;
#     skos:prefLabel "20 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:c58a7fd7-9bf9-4b67-8e68-f203483e2e7c a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "9 Boulevard d'Italie"^^xsd:string ;
#     skos:hiddenLabel "9"^^xsd:string ;
#     skos:prefLabel "9 (Boulevard d'Italie, Gentilly)"^^xsd:string .
#
# landmark:c7717f8d-6dd1-48d4-b065-d8c9535b8e25 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "26 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "26"^^xsd:string ;
#     skos:prefLabel "26 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:c8428e98-0783-4668-8359-03f4797bc803 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "19 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "19"^^xsd:string ;
#     skos:prefLabel "19 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:ca747329-eb88-4996-a0d0-0db92c889f62 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "24 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "24"^^xsd:string ;
#     skos:prefLabel "24 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:cc2387a2-8b8a-4067-bae2-d0e0b5b21c6a a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "10 Barrière de Fontainebleau"^^xsd:string ;
#     skos:hiddenLabel "10"^^xsd:string ;
#     skos:prefLabel "10 (Barrière de Fontainebleau, Gentilly)"^^xsd:string .
#
# landmark:d07dc4c6-d67b-4713-9bb7-3c9815bdf468 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "5 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "5"^^xsd:string ;
#     skos:prefLabel "5 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:dedbeca4-3d51-41cb-8f9a-fb555d63b269 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "27 Boulevard d'Italie"^^xsd:string ;
#     skos:hiddenLabel "27"^^xsd:string ;
#     skos:prefLabel "27 (Boulevard d'Italie, Gentilly)"^^xsd:string .
#
# landmark:e370d7ae-9d68-4525-83af-8d328f16f5c4 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "17 Barrière d'Italie"^^xsd:string ;
#     skos:hiddenLabel "17"^^xsd:string ;
#     skos:prefLabel "17 (Barrière d'Italie, Gentilly)"^^xsd:string .
#
# landmark:e48db04e-e591-4046-a82d-cae2080562b7 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "13↑a↓ Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "13↑a↓"^^xsd:string ;
#     skos:prefLabel "13↑a↓ (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:e57eaee5-1626-4c3c-9f6c-10354c34d58b a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "3 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "3"^^xsd:string ;
#     skos:prefLabel "3 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:e7102c0d-caac-458c-854f-06e6fa95b8a3 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "9 Rue Gérard"^^xsd:string ;
#     skos:hiddenLabel "9"^^xsd:string ;
#     skos:prefLabel "9 (Rue Gérard, Gentilly)"^^xsd:string .
#
# landmark:ea693243-96c2-41dd-b178-36869de82936 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Undefined ;
#     skos:altLabel "Les Girantins"^^xsd:string ;
#     skos:prefLabel "Les Girantins (Partie, Gentilly)"^^xsd:string .
#
# landmark:f26b8229-b6c4-4513-a9ef-edd9974a6760 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "17 Boulevard d'Italie"^^xsd:string ;
#     skos:hiddenLabel "17"^^xsd:string ;
#     skos:prefLabel "17 (Boulevard d'Italie, Gentilly)"^^xsd:string .
#
# landmark:f68e3235-48ab-4626-8d21-ee623c7a1f1e a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "3 Rue Gérard"^^xsd:string ;
#     skos:hiddenLabel "3"^^xsd:string ;
#     skos:prefLabel "3 (Rue Gérard, Gentilly)"^^xsd:string .
#
# landmark:f8d2d6a5-20fa-4cf8-9eeb-f7ec6dae219d a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "27 Rue Gérard"^^xsd:string ;
#     skos:hiddenLabel "27"^^xsd:string ;
#     skos:prefLabel "27 (Rue Gérard, Gentilly)"^^xsd:string .
#
# landmark:f987f826-f331-452f-9ac8-1a791f5cd320 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "22 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "22"^^xsd:string ;
#     skos:prefLabel "22 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:fc0e64dd-fd1d-4978-b501-3f0082d52f51 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "7 Rue Gérard"^^xsd:string ;
#     skos:hiddenLabel "7"^^xsd:string ;
#     skos:prefLabel "7 (Rue Gérard, Gentilly)"^^xsd:string .
#
# landmark:fc1db6a8-c327-49f7-95c1-40c6eb1c0298 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "29 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "29"^^xsd:string ;
#     skos:prefLabel "29 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:fd674132-487e-4042-a8c4-773538d5ca8c a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:StreetNumber ;
#     skos:altLabel "7 Rue Thiers"^^xsd:string ;
#     skos:hiddenLabel "7"^^xsd:string ;
#     skos:prefLabel "7 (Rue Thiers, Gentilly)"^^xsd:string .
#
# landmark:0c12c4de-b92c-48ca-ab24-eb009932f215 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Boulevard Extérieur"^^xsd:string ;
#     skos:prefLabel "Boulevard Extérieur, Gentilly"^^xsd:string .
#
# landmark:473cbe33-f954-4dc1-9c57-b449ec77d2dd a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Rue Thiers"^^xsd:string ;
#     skos:prefLabel "Rue Thiers, Gentilly"^^xsd:string .
#
# landmark:4b02fe77-ab9b-4b3b-9664-04ae02cb5744 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Rue Thiers"^^xsd:string ;
#     skos:prefLabel "Rue Thiers, Gentilly"^^xsd:string .
#
# landmark:4e6fe677-6afc-4f78-b6fb-622ceac06234 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Barrière de Fontainebleau"^^xsd:string ;
#     skos:prefLabel "Barrière de Fontainebleau, Gentilly"^^xsd:string .
#
# landmark:80a5b89f-3a99-43f6-94b5-0b2ce513970b a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:District ;
#     skos:altLabel "Les Girandins"^^xsd:string ;
#     skos:prefLabel "Les Girandins, Gentilly"^^xsd:string .
#
# landmark:824e7e84-0e5c-4ee1-a410-557a9f98251e a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1813 ;
#     add:isLandmarkType ltype:Undefined ;
#     skos:altLabel "Lauteis"^^xsd:string ;
#     skos:prefLabel "Lauteis, Gentilly"^^xsd:string .
#
# landmark:82c828d1-52d8-4fc7-aef2-fdcc432612a3 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:District ;
#     skos:altLabel "Les Girantins"^^xsd:string ;
#     skos:prefLabel "Les Girantins, Gentilly"^^xsd:string .
#
# landmark:8e52234f-0bc1-48e2-85fc-244c23851052 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1813 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Route de Paris"^^xsd:string ;
#     skos:prefLabel "Route de Paris, Gentilly"^^xsd:string .
#
# landmark:9c415cf4-0fb4-45d9-860b-278eca35c0d9 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Boulevard d'Italie"^^xsd:string ;
#     skos:prefLabel "Boulevard d'Italie, Gentilly"^^xsd:string .
#
# landmark:aefca716-5796-400c-81ff-1538b77d2e9b a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Chemin de la butte aux cailles"^^xsd:string ;
#     skos:prefLabel "Chemin de la butte aux cailles, Gentilly"^^xsd:string .
#
# landmark:e2f36335-76fe-4a6f-9b2d-c4d4f29f3aeb a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1813 ;
#     add:isLandmarkType ltype:District ;
#     skos:altLabel "Les Girantiers"^^xsd:string ;
#     skos:prefLabel "Les Girantiers, Gentilly"^^xsd:string .
#
# landmark:ef15ada8-86b6-46d7-aace-08bd19569927 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:District ;
#     skos:altLabel "Butte aux cailles"^^xsd:string ;
#     skos:prefLabel "Butte aux cailles, Gentilly"^^xsd:string .
#
# landmark:f1d0659b-bb3c-4fa7-a7f8-f8f2701bc537 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Chemin de Gentilly"^^xsd:string ;
#     skos:prefLabel "Chemin de Gentilly, Gentilly"^^xsd:string .
#
# landmark:f6e330f9-1125-40b3-8285-8bdc3ddf1b00 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:District ;
#     skos:altLabel "Butte aux cailles"^^xsd:string ;
#     skos:prefLabel "Butte aux cailles, Gentilly"^^xsd:string .
#
# landmark:fe450ce5-86f8-4e51-b451-4b2aaa4347ae a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Address ;
#     skos:altLabel "Boulevard d'Italie,7"^^xsd:string ;
#     skos:prefLabel "Boulevard d'Italie,7, Gentilly"^^xsd:string .
#
# landmark:6400d727-5ad4-45be-9f3a-b344ae48161f a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Boulevard extérieur"^^xsd:string ;
#     skos:prefLabel "Boulevard extérieur, Gentilly"^^xsd:string .
#
# landmark:e033fc6a-5108-428e-b78d-5bc054ba9c7a a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1813 ;
#     add:isLandmarkType ltype:District ;
#     skos:altLabel "Les Girantins"^^xsd:string ;
#     skos:prefLabel "Les Girantins, Gentilly"^^xsd:string .
#
# landmark:ef69632c-a2ec-405f-91c9-b03bdffec69e a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1813 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Barrière de Fontainebleau"^^xsd:string ;
#     skos:prefLabel "Barrière de Fontainebleau, Gentilly"^^xsd:string .
#
# landmark:a94ce6f8-bdc9-437b-9529-7efb61700860 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Rue Tiers"^^xsd:string ;
#     skos:prefLabel "Rue Tiers, Gentilly"^^xsd:string .
#
# landmark:2ceeaf2b-a02c-405b-adee-84a3dcb9ad6d a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Barrière d'Italie"^^xsd:string ;
#     skos:prefLabel "Barrière d'Italie, Gentilly"^^xsd:string .
#
# landmark:7082bc99-aadf-4673-85f8-6b8d33d86f91 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1836 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Boulevard d'Italie"^^xsd:string ;
#     skos:prefLabel "Boulevard d'Italie, Gentilly"^^xsd:string .
#
# landmark:7c5a1891-c80d-4859-84bf-f5985dce0196 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1848 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Rue Gérard"^^xsd:string ;
#     skos:prefLabel "Rue Gérard, Gentilly"^^xsd:string .
#
# landmark:d4b95ace-206a-4b79-a864-31925ed0f615 a add:Landmark ;
#     cad:sourcedFrom source:94_Gentilly_MAT_1813 ;
#     add:isLandmarkType ltype:Thoroughfare ;
#     skos:altLabel "Rue Thiers"^^xsd:string ;
#     skos:prefLabel "Rue Thiers, Gentilly"^^xsd:string .
# <Graph identifier=N40d1950bc510445e8cc933c73bfe551d (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### 1.5 Propriétaires

# %%
from pandasql import sqldf
import pandas as pd

# %%
matrices_ = matrices[['registre','Num_Folio','Type_CF','Groupe_CF','Image','UUID','Ordre_de_lecture']].copy()

# %%
#add column with rows index
owners_df['row_index'] = owners_df.index
owners_df2 = owners_df[['registre','type_folio','folio','groupe_cf','row_index']]
owners_df2.dtypes
# Out:
# registre      object
# type_folio    object
# folio         object
# groupe_cf     object
# row_index      int64
# dtype: object

# %%
query = '''SELECT M.registre AS m_registre, M.Type_CF AS m_type_folio, M.Num_Folio AS m_num_folio, M.Groupe_CF AS m_groupe_cf, M.Image AS m_image, M.UUID AS m_uuid, m.Ordre_de_lecture AS m_row_num_in_cf, O.row_index AS o_row_index
        FROM matrices_ AS M
        LEFT JOIN owners_df2 AS O
        ON (M.Num_Folio = O.folio AND M.registre = O.registre AND M.Groupe_CF = O.groupe_cf AND M.Type_CF = O.type_folio)
        '''

testDF = sqldf(query)
#testDF.to_csv(ROOT + 'test.csv',index=False)
#pd.set_option("display.max_rows", None)
display(sqldf(query))
# Out:
#     m_registre m_type_folio m_num_folio  m_groupe_cf  \
# 0     MAT_1813         Bâti         108            1
# 1     MAT_1813         Bâti         114            1
# 2     MAT_1813         Bâti          82            1
# 3     MAT_1813         Bâti          82            1
# 4     MAT_1813         Bâti          64            1
# ..         ...          ...         ...          ...
# 440   MAT_1848     Non Bâti        1221            1
# 441   MAT_1848     Non Bâti        1221            1
# 442   MAT_1848     Non Bâti        1222            1
# 443   MAT_1848     Non Bâti        1222            1
# 444   MAT_1848     Non Bâti        1222            1
#
#                        m_image                                m_uuid  \
# 0    FRAD094_3P_000255_01_0586  7c13b9ec-506c-4675-b691-335b828bbe11
# 1    FRAD094_3P_000255_01_0588  649a3bb0-7483-44c8-ad90-96bfc1808fdd
# 2    FRAD094_3P_000255_01_0579  bf640773-d6ff-4ba8-be3b-ffdd199dd8a4
# 3    FRAD094_3P_000255_01_0579  fe2c20fe-237f-4da7-8c7d-1ae33e5e1b96
# 4    FRAD094_3P_000255_01_0571  a8d13691-1a81-4684-9db7-98ee1fbc354d
# ..                         ...                                   ...
# 440  FRAD094_3P_000264_01_0221  da62bcf1-3993-420b-8aac-e7cd1d1b4cda
# 441  FRAD094_3P_000264_01_0221  d0f7ae85-fd51-459b-a4b4-48a8335cf44a
# 442  FRAD094_3P_000264_01_0222  e0d84f8b-4b9b-4b54-92f0-e1d36d5e6e45
# 443  FRAD094_3P_000264_01_0222  af70cad2-55f9-4163-8c6b-ece562802b66
# 444  FRAD094_3P_000264_01_0222  244a34a1-1a2f-4170-8564-77a1899f17fe
#
#      m_row_num_in_cf  o_row_index
# 0                  1            0
# 1                  1            1
# 2                  1            2
# 3                  2            2
# 4                  1            3
# ..               ...          ...
# 440                6          188
# 441                7          188
# 442                1          189
# 443                2          189
# 444                3          189
#
# [445 rows x 8 columns]

# %%
owners_matrices = pd.merge(owners_df, testDF, how='left', left_on=['row_index'], right_on=['o_row_index'])
#add a uuid to each distinct group of line with same values in registre, type_folio, folio and groupe_cf
#owners_matrices.to_csv(ROOT + 'owners_matrices.csv',index=False)
owners_matrices
# Out:
#                                                   cell  \
# 0    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 1    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 2    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 3    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 4    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# ..                                                 ...
# 440  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 441  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 442  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 443  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 444  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
#
#                                                 owners changes  registre  \
# 0    [{'owner-id': 1, 'owner-lastname': 'Legendre',...      []  MAT_1813
# 1    [{'owner-id': 1, 'owner-lastname': 'Louves', '...      []  MAT_1813
# 2    [{'owner-id': 1, 'owner-lastname': 'Hardon', '...      []  MAT_1813
# 3    [{'owner-id': 1, 'owner-lastname': 'Hardon', '...      []  MAT_1813
# 4    [{'owner-id': 1, 'owner-lastname': 'Faipot', '...      []  MAT_1813
# ..                                                 ...     ...       ...
# 440  [{'owner-id': 1, 'owner-lastname': 'Nicolle', ...      []  MAT_1848
# 441  [{'owner-id': 1, 'owner-lastname': 'Nicolle', ...      []  MAT_1848
# 442  [{'owner-id': 1, 'owner-lastname': 'Lacroix', ...      []  MAT_1848
# 443  [{'owner-id': 1, 'owner-lastname': 'Lacroix', ...      []  MAT_1848
# 444  [{'owner-id': 1, 'owner-lastname': 'Lacroix', ...      []  MAT_1848
#
#     type_folio folio groupe_cf  \
# 0         Bâti   108         1
# 1         Bâti   114         1
# 2         Bâti    82         1
# 3         Bâti    82         1
# 4         Bâti    64         1
# ..         ...   ...       ...
# 440   Non Bâti  1221         1
# 441   Non Bâti  1221         1
# 442   Non Bâti  1222         1
# 443   Non Bâti  1222         1
# 444   Non Bâti  1222         1
#
#                                          transcription  row_index m_registre  \
# 0                     Legendre H↑re↓ de →Fontainebleau          0   MAT_1813
# 1                                               Louves          1   MAT_1813
# 2             Hardon, Bourgeois ~~nourisseur~~→à Paris          2   MAT_1813
# 3             Hardon, Bourgeois ~~nourisseur~~→à Paris          2   MAT_1813
# 4    Faipot François→m↑d↓ de vin b↑re↓ de fontaineb...          3   MAT_1813
# ..                                                 ...        ...        ...
# 440                           Nicolle J↑n↓ f↑ois↓ Paul        188   MAT_1848
# 441                           Nicolle J↑n↓ f↑ois↓ Paul        188   MAT_1848
# 442                                 Lacroix J↑n↓ Louis        189   MAT_1848
# 443                                 Lacroix J↑n↓ Louis        189   MAT_1848
# 444                                 Lacroix J↑n↓ Louis        189   MAT_1848
#
#     m_type_folio m_num_folio  m_groupe_cf                    m_image  \
# 0           Bâti         108            1  FRAD094_3P_000255_01_0586
# 1           Bâti         114            1  FRAD094_3P_000255_01_0588
# 2           Bâti          82            1  FRAD094_3P_000255_01_0579
# 3           Bâti          82            1  FRAD094_3P_000255_01_0579
# 4           Bâti          64            1  FRAD094_3P_000255_01_0571
# ..           ...         ...          ...                        ...
# 440     Non Bâti        1221            1  FRAD094_3P_000264_01_0221
# 441     Non Bâti        1221            1  FRAD094_3P_000264_01_0221
# 442     Non Bâti        1222            1  FRAD094_3P_000264_01_0222
# 443     Non Bâti        1222            1  FRAD094_3P_000264_01_0222
# 444     Non Bâti        1222            1  FRAD094_3P_000264_01_0222
#
#                                    m_uuid  m_row_num_in_cf  o_row_index
# 0    7c13b9ec-506c-4675-b691-335b828bbe11                1            0
# 1    649a3bb0-7483-44c8-ad90-96bfc1808fdd                1            1
# 2    bf640773-d6ff-4ba8-be3b-ffdd199dd8a4                1            2
# 3    fe2c20fe-237f-4da7-8c7d-1ae33e5e1b96                2            2
# 4    a8d13691-1a81-4684-9db7-98ee1fbc354d                1            3
# ..                                    ...              ...          ...
# 440  da62bcf1-3993-420b-8aac-e7cd1d1b4cda                6          188
# 441  d0f7ae85-fd51-459b-a4b4-48a8335cf44a                7          188
# 442  e0d84f8b-4b9b-4b54-92f0-e1d36d5e6e45                1          189
# 443  af70cad2-55f9-4163-8c6b-ece562802b66                2          189
# 444  244a34a1-1a2f-4170-8564-77a1899f17fe                3          189
#
# [445 rows x 17 columns]

# %%
#I want to create a dict with o_row_index as key and uuids as values
from datascroller import scroll

cf_uuid_dict = {}
sees = []
for index, row in owners_matrices.iterrows():
    if row['o_row_index'] not in sees:
        cf_uuid_dict[row['o_row_index']] = uuid.uuid4()
        sees.append(cf_uuid_dict[row['o_row_index']])

#pd.set_option("display.max_rows", None)
display(owners_matrices)
# Out:
#                                                   cell  \
# 0    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 1    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 2    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 3    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# 4    {'registre': 'MAT_1813', 'type_folio': 'Bâti',...
# ..                                                 ...
# 440  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 441  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 442  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 443  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
# 444  {'registre': 'MAT_1848', 'type_folio': 'Non Bâ...
#
#                                                 owners changes  registre  \
# 0    [{'owner-id': 1, 'owner-lastname': 'Legendre',...      []  MAT_1813
# 1    [{'owner-id': 1, 'owner-lastname': 'Louves', '...      []  MAT_1813
# 2    [{'owner-id': 1, 'owner-lastname': 'Hardon', '...      []  MAT_1813
# 3    [{'owner-id': 1, 'owner-lastname': 'Hardon', '...      []  MAT_1813
# 4    [{'owner-id': 1, 'owner-lastname': 'Faipot', '...      []  MAT_1813
# ..                                                 ...     ...       ...
# 440  [{'owner-id': 1, 'owner-lastname': 'Nicolle', ...      []  MAT_1848
# 441  [{'owner-id': 1, 'owner-lastname': 'Nicolle', ...      []  MAT_1848
# 442  [{'owner-id': 1, 'owner-lastname': 'Lacroix', ...      []  MAT_1848
# 443  [{'owner-id': 1, 'owner-lastname': 'Lacroix', ...      []  MAT_1848
# 444  [{'owner-id': 1, 'owner-lastname': 'Lacroix', ...      []  MAT_1848
#
#     type_folio folio groupe_cf  \
# 0         Bâti   108         1
# 1         Bâti   114         1
# 2         Bâti    82         1
# 3         Bâti    82         1
# 4         Bâti    64         1
# ..         ...   ...       ...
# 440   Non Bâti  1221         1
# 441   Non Bâti  1221         1
# 442   Non Bâti  1222         1
# 443   Non Bâti  1222         1
# 444   Non Bâti  1222         1
#
#                                          transcription  row_index m_registre  \
# 0                     Legendre H↑re↓ de →Fontainebleau          0   MAT_1813
# 1                                               Louves          1   MAT_1813
# 2             Hardon, Bourgeois ~~nourisseur~~→à Paris          2   MAT_1813
# 3             Hardon, Bourgeois ~~nourisseur~~→à Paris          2   MAT_1813
# 4    Faipot François→m↑d↓ de vin b↑re↓ de fontaineb...          3   MAT_1813
# ..                                                 ...        ...        ...
# 440                           Nicolle J↑n↓ f↑ois↓ Paul        188   MAT_1848
# 441                           Nicolle J↑n↓ f↑ois↓ Paul        188   MAT_1848
# 442                                 Lacroix J↑n↓ Louis        189   MAT_1848
# 443                                 Lacroix J↑n↓ Louis        189   MAT_1848
# 444                                 Lacroix J↑n↓ Louis        189   MAT_1848
#
#     m_type_folio m_num_folio  m_groupe_cf                    m_image  \
# 0           Bâti         108            1  FRAD094_3P_000255_01_0586
# 1           Bâti         114            1  FRAD094_3P_000255_01_0588
# 2           Bâti          82            1  FRAD094_3P_000255_01_0579
# 3           Bâti          82            1  FRAD094_3P_000255_01_0579
# 4           Bâti          64            1  FRAD094_3P_000255_01_0571
# ..           ...         ...          ...                        ...
# 440     Non Bâti        1221            1  FRAD094_3P_000264_01_0221
# 441     Non Bâti        1221            1  FRAD094_3P_000264_01_0221
# 442     Non Bâti        1222            1  FRAD094_3P_000264_01_0222
# 443     Non Bâti        1222            1  FRAD094_3P_000264_01_0222
# 444     Non Bâti        1222            1  FRAD094_3P_000264_01_0222
#
#                                    m_uuid  m_row_num_in_cf  o_row_index
# 0    7c13b9ec-506c-4675-b691-335b828bbe11                1            0
# 1    649a3bb0-7483-44c8-ad90-96bfc1808fdd                1            1
# 2    bf640773-d6ff-4ba8-be3b-ffdd199dd8a4                1            2
# 3    fe2c20fe-237f-4da7-8c7d-1ae33e5e1b96                2            2
# 4    a8d13691-1a81-4684-9db7-98ee1fbc354d                1            3
# ..                                    ...              ...          ...
# 440  da62bcf1-3993-420b-8aac-e7cd1d1b4cda                6          188
# 441  d0f7ae85-fd51-459b-a4b4-48a8335cf44a                7          188
# 442  e0d84f8b-4b9b-4b54-92f0-e1d36d5e6e45                1          189
# 443  af70cad2-55f9-4163-8c6b-ece562802b66                2          189
# 444  244a34a1-1a2f-4170-8564-77a1899f17fe                3          189
#
# [445 rows x 17 columns]

# %% [markdown]
# * Créer les comptes fonciers
# * Associer à chaque compte foncier ses propriétaires (ordonnés dans le temps)
# * Associer à chaque compte foncier le landmark (état) qu'il mentionne

# %% [markdown]
# * ```o_row_index``` : id de l'article de mutation (et du compte foncier => 1..1)
# donc
#     * ArticleDeMutation : uuid_mutation
#     * CompteFoncier : uuid
#     * Owner : uuid_taxpayer = owner_id
#
# * ```m_uuid``` : id de l'article de classement
# donc
#     * ArticleDeClassement : uuid

# %% [markdown]
#     #Source
#     #rowSource = BNode()
#     #g.add((subject_uri, cad.sourcedFrom, rowSource))
#     #g.add((rowSource, RDF.type, fpo.SourceCitation))
#     #g.add((rowSource, fpo.fromSource, URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{MATRICE_ID}")))
#     #g.add((rowSource, rico.isComponentOfTransitive, URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{row['Image']}")))
#     #g.add((rowSource, PROV.wasGeneratedBy, URIRef(cad_atype + "0002")))
#     #g.add((URIRef(cad_atype + "0002"), PROV.used, URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{row['Image']}")))
#     #g.add((rowSource, rico.isOrWasDigitalInstanciation,URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{row['Image']}_{lineuuid_}_area")))
#     #g.add((rowSource, cad.lineOrderInArea, Literal(row['Ordre_de_lecture'], datatype=XSD.integer)))

# %%
from namespaces import *

# Create a new RDF graph
g = Graph()

g.bind('landmark', landmarkuri)
g.bind('source', srcuri)
g.bind('taxpayer', owneruri)
g.bind('event', eventuri)

g.bind('cad_ltype', cad_ltype)
g.bind('cad_atype', cad_atype)
g.bind('cad_etype', cad_etype)
g.bind('ctype', ctype)
g.bind('srctype', srctype)
g.bind('mlclasse', mlclasse)
g.bind('rico', rico)
g.bind('add', add)
g.bind('cad', cad)

created_cf = []

for index, row in owners_matrices.iterrows():
    #Infos de l'image

    json = parse_record_id(row["m_image"])
    MATRICE_ID = matrices_metada[row['registre']]["MATRICE_ID"]

    #UUID du compte foncier
    cfuuid_ = str(cf_uuid_dict[row['o_row_index']])
    subject_uri = URIRef(srcuri + f"{cfuuid_}")
    #UUID de l'instanciation
    Icfuri = URIRef(subject_uri + "instanciation")
    g.add((Icfuri, RDF.type, rico.Instanciation))
    g.add((Icfuri, rico.isOrWasDigitalInstanciation, subject_uri))
    g.add((Icfuri, PROV.wasGeneratedBy, URIRef(activity + "0002")))

    #URI de l'article de classement
    articleclassementuri = URIRef(srcuri + f"{row['m_uuid']}_classement")
    g.add((articleclassementuri, RDF.type, rico.RecordPart))
    g.add((articleclassementuri, cad.isSourceType, URIRef(srctype.ArticleDeClassement)))
    g.add((articleclassementuri, DCTERMS.identifier, Literal(row['m_row_num_in_cf'],datatype=XSD.integer))) #Numéro d'ordre de l'article de classement dans le compte foncier
    #UUID de l'instanciation
    Iarticleclassementuri = URIRef(srcuri + f"{row['m_uuid']}_classement_instanciation")
    g.add((Iarticleclassementuri, RDF.type, rico.Instanciation))
    g.add((Iarticleclassementuri, rico.isOrWasDigitalInstanciation, articleclassementuri))
    g.add((Iarticleclassementuri, PROV.wasGeneratedBy, URIRef(activity + "0002")))

    #CF contient ArticleDeClassement
    g.add((subject_uri, rico.hasOrHadConstituent, articleclassementuri)) 

    if cfuuid_ not in created_cf:
        created_cf.append(cfuuid_)
        #Compte foncier
        g.add((subject_uri, RDF.type, rico.RecordPart))
        g.add((subject_uri, cad.isSourceType, URIRef(srctype.CompteFoncier)))
        g.add((subject_uri, rico.hasOrHadConstituent, URIRef(srcuri + f"{cfuuid_}_mutation"))) #CF contient ArticleDeMutation
        g.add((subject_uri, rico.isOrWasConstituentOf, URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{MATRICE_ID}_{str(row['m_num_folio'])}"))) #CF est contenu dans Folio
        g.add((subject_uri, DCTERMS.identifier, Literal(row['groupe_cf'],datatype=XSD.integer))) #Numéro d'ordre du compte foncier dans un folio

        #URI de l'article de mutation
        articlemutationuri = URIRef(srcuri + f"{cfuuid_}_mutation")
        g.add((articlemutationuri, RDF.type, rico.RecordPart))
        g.add((articlemutationuri, cad.isSourceType, srctype.ArticleDeMutation))
        #UUID de l'
        Iarticlemutationuri = URIRef(srcuri + f"{cfuuid_}_mutation_instanciation")
        g.add((Iarticlemutationuri, RDF.type, rico.Instanciation))
        g.add((Iarticlemutationuri, rico.isOrWasDigitalInstanciation, articlemutationuri))
        g.add((Iarticlemutationuri, PROV.wasGeneratedBy, URIRef(activity + "0002")))

        ## Taxpayers contenu dans ArticleDeMutation
        ownersattribute = BNode()
        g.add((ownersattribute, RDF.type, add.Attribute))
        g.add((articlemutationuri, cad.hasCadastreAttribute, ownersattribute))
        g.add((ownersattribute, add.isAttributeType, cad_atype.PlotTaxpayer))

        owners_and_versions = {}
        for owner in row['owners']:
            ownersattributeversion = BNode()
            g.add((ownersattributeversion,RDF.type,add.AttributeVersion))
            g.add((ownersattribute, add.hasAttributeVersion, ownersattributeversion))
            owneruriinstance = URIRef(owneruri + f"{cfuuid_}_taxpayer_{owner['owner-id']}")
            g.add((owneruriinstance, RDF.type, cad.Taxpayer))
            g.add((ownersattributeversion, cad.hasTaxpayer, owneruriinstance))
            olabel = ''
            #test if json has a certain key
            if 'owner-lastname' in owner:
                g.add((owneruriinstance, cad.taxpayerLabel, Literal(owner['owner-lastname'],datatype=XSD.string)))
                olabel += owner['owner-lastname']
            if 'owner-firstname' in owner:
                g.add((owneruriinstance, cad.taxpayerFirstName, Literal(owner['owner-firstname'],datatype=XSD.string)))
                olabel += ' ' + owner['owner-firstname']
            if 'owner-status' in owner:
                g.add((owneruriinstance, cad.taxpayerStatus, Literal(owner['owner-status'],datatype=XSD.string)))
                olabel += ' (' + owner['owner-status'] + ')'
            if 'owner-activity' in owner:
                g.add((owneruriinstance, cad.taxpayerActivity, Literal(owner['owner-activity'],datatype=XSD.string)))
            if 'owner-address' in owner:
                g.add((owneruriinstance, cad.taxpayerAddress, Literal(owner['owner-address'],datatype=XSD.string)))
            #Create owner label
            g.add((owneruriinstance, RDFS.label, Literal(olabel,datatype=XSD.string)))
            g.add((owneruriinstance,cad.fromSource,articlemutationuri))
            owners_and_versions[owner['owner-id']] = ownersattributeversion

        if len(row) > 0:
            for change in row['changes']:
                changenode = BNode()
                g.add((URIRef(changenode.n3()), RDF.type, add.Change))
                g.add((URIRef(changenode.n3()), add.appliedTo, ownersattribute))
                g.add((URIRef(changenode.n3()), add.outdates, owners_and_versions[change['owner-before']]))
                g.add((URIRef(changenode.n3()), add.makesEffective, owners_and_versions[change['owner-after']]))
                g.add((URIRef(changenode.n3()),add.isChangeType,ctype.AttributeVersionTransition))
                event_uuid = uuid.uuid4()
                event_uri = URIRef(eventuri + f"{event_uuid}")
                g.add((URIRef(changenode.n3()), add.dependsOn, event_uri))
                if 'date' in change:
                    g.add((event_uri, RDF.type, add.Event))
                    time_ = BNode()
                    g.add((event_uri, add.hasTime, time_))
                    g.add((event_uri, cad.isEventType, cad_etype.TaxpayerMutation))
                    g.add((time_, RDF.type, add.TimeInstant))
                    g.add((time_, add.timeCalendar, time.Gregorian))
                    g.add((time_, add.Precision, time.Year))
                    g.add((time_, add.timeStamp, Literal(datetime.strptime(str(int(change['date'])) + '-12-31', '%Y-%m-%d'),datatype=XSD.dateTimeStamp)))
        #Create initial change
        initchangenode = BNode()
        g.add((URIRef(initchangenode.n3()), RDF.type, add.Change))
        g.add((URIRef(initchangenode.n3()), add.appliedTo, ownersattribute))
        g.add((URIRef(initchangenode.n3()), add.makesEffective, owners_and_versions[1]))
        g.add((URIRef(initchangenode.n3()), add.isChangeType, ctype.AttributeVersionAppearance))
        event_uuid = uuid.uuid4()
        event_uri = URIRef(eventuri + f"{event_uuid}")
        g.add((URIRef(initchangenode.n3()), add.dependsOn, event_uri))

        #Create final change
        finalchangenode = BNode()
        g.add((URIRef(finalchangenode.n3()), RDF.type, add.Change))
        g.add((URIRef(finalchangenode.n3()), add.appliedTo, ownersattribute))
        g.add((URIRef(finalchangenode.n3()), add.outdates, owners_and_versions[len(owners_and_versions)]))
        g.add((URIRef(finalchangenode.n3()), add.isChangeType, ctype.AttributeVersionDisappearance))
        event_uuid = uuid.uuid4()
        event_uri = URIRef(eventuri + f"{event_uuid}")
        g.add((URIRef(finalchangenode.n3()), add.dependsOn, event_uri))

print(g.serialize(format='turtle'))
g.serialize(destination=f"{OUTPUT_FOLDER_PATH}/{COMMUNE}_owners_cf_clas_mut.ttl", format='turtle')
# Out:
# @prefix add: <http://rdf.geohistoricaldata.org/def/address#> .
# @prefix cad: <http://data.ign.fr/def/cadastre#> .
# @prefix cad_atype: <http://data.ign.fr/id/codes/cadastre/attributeType/> .
# @prefix cad_etype: <http://data.ign.fr/id/codes/cadastre/eventType/> .
# @prefix ctype: <http://rdf.geohistoricaldata.org/id/codes/address/changeType/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix event: <http://data.ign.fr/id/event/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix rico: <https://www.ica.org/standards/RiC/ontology#> .
# @prefix source: <http://data.ign.fr/id/source/> .
# @prefix srctype: <http://data.ign.fr/id/codes/cadastre/sourceType/> .
# @prefix taxpayer: <http://data.ign.fr/id/taxpayer/> .
# @prefix time: <http://www.w3.org/2006/time#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <_:N00b2a711e7e94621b0b204ae9f944001> a add:Change ;
#     add:appliedTo _:N7b5e5819b7ef41e297c6127d4960a4e3 ;
#     add:dependsOn event:639bb65e-a95a-41bd-b34f-a1400af7090e ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N16b09d079d0041e48b7d9cfdc9cdd596 ;
#     add:outdates _:N210d33d8c52c4f79a82edb30fe52847c .
#
# <_:N01cdf3b0ba7347f6a4b05f88b86ec152> a add:Change ;
#     add:appliedTo _:Nc7170e71cd3c4da1a0042ffa7d2d37b6 ;
#     add:dependsOn event:51e62e7a-348b-49b7-bcd1-7dddfbbe230f ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N1b88e1f204874d91a2fc61f418336c00 ;
#     add:outdates _:Nf84f770f5718419ca644783a5d7fba7a .
#
# <_:N01d026f8015845c1965cb981d9ae9ec5> a add:Change ;
#     add:appliedTo _:N9f5acf15871649cba8c9a897bef6f014 ;
#     add:dependsOn event:b5a0591f-1aea-4887-95f2-86bdafe0b83a ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N467c35d5e51c498da760701e8f66280f .
#
# <_:N027e93d7d36542ae83a52e0e8fa4b687> a add:Change ;
#     add:appliedTo _:N0a9fd92351cd41fc9fffaad006f0d4cd ;
#     add:dependsOn event:d109528a-eb3b-47fa-9e21-377b92340c10 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N07a5bc303a2146d7b233329cc7015a96 .
#
# <_:N027f04ac5162421198ffbccc97a5b98e> a add:Change ;
#     add:appliedTo _:N3ba824892660481ebfbfe300660542ba ;
#     add:dependsOn event:14df67ef-0c9e-47ab-9e4a-87023235d98c ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N0513920db2c648a4aa96608291411ec4 .
#
# <_:N0365bd0e514c4bbcac6780210014dabd> a add:Change ;
#     add:appliedTo _:N4b1381dbc11b4a3ea3f822d7ffab38be ;
#     add:dependsOn event:99c35b2f-9da7-4058-99fa-1313d2957cf8 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nd08e25f7e9054076baede83331d9682a .
#
# <_:N037d01d478f448c9a6f74d4505a3c0cc> a add:Change ;
#     add:appliedTo _:Ndb5deef2326a4ec397e49da4cacaa82b ;
#     add:dependsOn event:b28032b6-cad2-4c71-a155-76274d9d5bca ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N89105ed6fe414905ae278cedf70db1ff .
#
# <_:N03b552e3eee54dc4ba51e29dcd32407a> a add:Change ;
#     add:appliedTo _:N38795ae431a840578c15755b77ba5101 ;
#     add:dependsOn event:865f0e02-340c-4616-8066-73666c457524 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Neffc790f759245df985d0ec65f3042aa .
#
# <_:N03bdfc9d3fc0454999643604a56726fe> a add:Change ;
#     add:appliedTo _:N8c98123c8d92450c8a0fcd47fc0e45b2 ;
#     add:dependsOn event:82cbaa2d-4b81-4156-a32d-f6bee058678b ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N2a9e7fbb94f24f7680465bee5fbe7e7d .
#
# <_:N04e80d6dab9b4ad8b9c104f5c9e105f0> a add:Change ;
#     add:appliedTo _:N1ba34cb51ecd4602be8c1561cddc35a4 ;
#     add:dependsOn event:43181136-57d6-4d83-ac82-085fa7ae99da ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Neec16f2604c64e18bdd58910a5ba482e .
#
# <_:N077b4505b14e477ca76e04a5c481a5c0> a add:Change ;
#     add:appliedTo _:N0cab5a64632b4429bf41b81926b2b271 ;
#     add:dependsOn event:1adfe3ba-9bce-4599-bfa8-2b1813fd7178 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N7b243f90962840359dc9e598e86f2ed2 .
#
# <_:N07b73affe28443fbbcca1034713bdcf1> a add:Change ;
#     add:appliedTo _:Nfdb97d936bd64a8bbd50205e520bcee5 ;
#     add:dependsOn event:74bdca50-0c3e-4b7c-8342-47f10232f484 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Nfe2ddf2493714a1b8629c55ad7ebe7cd ;
#     add:outdates _:N3356842e6b524366a5c77cff33dc701c .
#
# <_:N08d988bf131747f6ad9ee9e657722fde> a add:Change ;
#     add:appliedTo _:N277e590083244c88abbede441ea7d99e ;
#     add:dependsOn event:5aaaf119-982d-4537-9970-2bfd39809eed ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nfba6420e4cf94d91b317e3d91db61d26 .
#
# <_:N08f11aee7ce24eba89bee80e37023a6f> a add:Change ;
#     add:appliedTo _:N97013edd34e14cef8989da725b795c80 ;
#     add:dependsOn event:b068444f-5836-4ae7-a4dc-631cf3aae9f7 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nf7831863c6244cf4a86e195e099867db .
#
# <_:N09929b4ac9d64c8abbe3492a8b8bdc90> a add:Change ;
#     add:appliedTo _:N4c8cca62c2044fbf818d3d4a0d3353dc ;
#     add:dependsOn event:d46c9264-75a3-45ed-b8b6-2be725cfe436 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N4258c205229540d594e6528bc18beada .
#
# <_:N0997e820c21e40da95b0d16a54f9a36d> a add:Change ;
#     add:appliedTo _:N3db4321681754533936ba2df2742a935 ;
#     add:dependsOn event:daff7f1f-8201-4fe2-8d2d-fdb70bc32c62 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nd320231ea1fa4915b31a337e2cce6534 .
#
# <_:N0a871212b04946b8afddfcedb8d84a70> a add:Change ;
#     add:appliedTo _:N963889cda40b4659a221801315414390 ;
#     add:dependsOn event:7c209250-bddd-4543-a57a-fb0efcc2edf0 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Ncba7b594d0b24694b4ab382bcb2a8f4b ;
#     add:outdates _:N6d01cbb433a94db28fb5d6c52254b92a .
#
# <_:N0abcd09987224bffa1f98955dcd85b20> a add:Change ;
#     add:appliedTo _:N61e6fe0f51134776aa9df6b12c2f3d00 ;
#     add:dependsOn event:03fa201d-6b85-42f6-8333-35e8011c6019 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Nef9f06c51353488283c95cc5e5898c98 ;
#     add:outdates _:N8c5711e9f53b4fe59b92c2080e721cfb .
#
# <_:N0ba77889357d416da65e53ae5f588a3e> a add:Change ;
#     add:appliedTo _:N90694a8598574fd5951b7ca70b732260 ;
#     add:dependsOn event:4263dd45-7935-4ab7-a420-efae14777fd4 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N37d18c87dca740b4a20004f2b1e128ed ;
#     add:outdates _:N6694f01e9a4b46b4a07d4213e276b07e .
#
# <_:N0e9203fc482c47e5baa1c77b5af0a458> a add:Change ;
#     add:appliedTo _:N4a48a68109da4dc984aa0e1991bf0239 ;
#     add:dependsOn event:3d63d3be-1a55-42ec-8603-c0e65a0b95cd ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N25d206f60fe447d5a1361ac761923a53 ;
#     add:outdates _:Nfe105278f7e14b7f89f07ae019a009a8 .
#
# <_:N0f0ae30640254355bd53629470efaf93> a add:Change ;
#     add:appliedTo _:N97892e90fb7c4fb5afa5ed77c10ef2be ;
#     add:dependsOn event:ee28c223-4186-48a2-ba33-d02fa4c45125 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N1eb704aacbc448dfa360b031b686becd .
#
# <_:N106fcbf1574945df95eb04ca86758251> a add:Change ;
#     add:appliedTo _:Nb403b364d8f64a88b2c459e4a72dfc35 ;
#     add:dependsOn event:8f59c420-5f3a-4031-b328-f032cd1ed07a ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N1b534e8bb9f04a048b85fac78a728ad0 ;
#     add:outdates _:N6e750d7e60a5478a93d339995cd4f093 .
#
# <_:N108a363662a84948bf8a54d629a6ce21> a add:Change ;
#     add:appliedTo _:Nf01029b10ab24609a1cc7bcfb191eb4b ;
#     add:dependsOn event:e0ee8d34-919e-428c-9a7c-dec5d1347726 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Na71370549dd24a178891c230b79685f3 .
#
# <_:N10bd741437404fbe82c1d0a5a9f9c232> a add:Change ;
#     add:appliedTo _:Nd8eb5b3080014215a1b1ee198dc10bb4 ;
#     add:dependsOn event:a68f245f-0901-4a23-a5c3-e47fc268e1f1 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N5cd95085e21649568840d5296fa38440 .
#
# <_:N1234ec6862114654afae6e0912160717> a add:Change ;
#     add:appliedTo _:N8c090b2d1b9241cdb63c90f3422439b1 ;
#     add:dependsOn event:82850f28-e157-48b1-8773-c27fa744b9a0 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nbf9a61ce2b5749c68825f240925f4f1b .
#
# <_:N12f68c5234ff4bb0807ec48c23e6ce10> a add:Change ;
#     add:appliedTo _:N1f566ee0e9524644afeeb19cac81a29c ;
#     add:dependsOn event:597d9e44-a5da-47ab-9a78-4c3b6b81d56c ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N61df2494623b46929272e606d270e148 ;
#     add:outdates _:N26be5b0baccf4d5ea113abced4c4c1e2 .
#
# <_:N133809ac7f264eee82a2ecd7d158035d> a add:Change ;
#     add:appliedTo _:N2df08b1845fd4089ba1f0c583464efe7 ;
#     add:dependsOn event:cbd4330a-3d5d-4bb5-8c31-4ef5a08e409e ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N0ef2d4f62ac04691b1ec6a2d1fff4a56 ;
#     add:outdates _:N4216e895db8b4da2a09e783868ba5263 .
#
# <_:N13574076e5bc42c188036337d34f1cd5> a add:Change ;
#     add:appliedTo _:N26a1927e8cf347218f0b1e92adfbccb5 ;
#     add:dependsOn event:fc0e8372-61dd-49c2-b316-4032d58c6c45 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N5e0acb245332413ebc65635f2c7b533d ;
#     add:outdates _:N5f552649b9fd411c87584b1b5c60156f .
#
# <_:N155ef26ef5b54c2b85acbe4ce6b29a33> a add:Change ;
#     add:appliedTo _:N648b90d3ccad4fb1b11845b9dc49a5be ;
#     add:dependsOn event:bca9c510-4f7b-4012-96ff-aa7b3da26506 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N0f51fde6e0c3417c852680af73be675d .
#
# <_:N15ad61b6ec924241a0ec3631c15f4f24> a add:Change ;
#     add:appliedTo _:Na3339e7ce73149089008c52ee3c33208 ;
#     add:dependsOn event:2dd5fe06-9f85-4967-abce-7253720ee4b3 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nc012355bea484267946707291462c5da .
#
# <_:N15c42aad77d4426e87efc85696282216> a add:Change ;
#     add:appliedTo _:N1c5e86f8cb194b0f84a785acaa1ddc9f ;
#     add:dependsOn event:6795b56b-da3d-42f7-9c53-d278da99a79e ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Nb524ebf2252341cc834927fa210024ad ;
#     add:outdates _:N3a09971591864dc09549899641273d64 .
#
# <_:N15ec8c7c04be488da8b546e5a21fcb7d> a add:Change ;
#     add:appliedTo _:N8990f30752b44cfbb16efdd78ba4bb53 ;
#     add:dependsOn event:20a9801c-8400-4e94-8506-2c9882c880f3 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N9cec0090ea58480cb76c6a8008a6bd22 .
#
# <_:N167b4056c4b54efd85cfb555fa52a850> a add:Change ;
#     add:appliedTo _:Nc614de17d27a4702bedad7ea7c5bf147 ;
#     add:dependsOn event:f20d9873-a114-4bee-9bae-a6b4e320f3d2 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Ndeb6ef43acfc4b6ba3fbbe12b163ddfb ;
#     add:outdates _:N0b4ce60bb7144c3d94b0aa425f00924c .
#
# <_:N16e37d5f4d774abcbf8940e99c4711fc> a add:Change ;
#     add:appliedTo _:N4ba537274b744e6483d399f8d1901f68 ;
#     add:dependsOn event:e9ab557b-f742-4e2f-9b30-c98412eec839 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Na04611c323704330a47b1718709324d1 .
#
# <_:N17d3eeb269554fd9af51be67b4700c0b> a add:Change ;
#     add:appliedTo _:Nb2b6bf574e534d2c967d89cbbc01b35e ;
#     add:dependsOn event:cb2392b8-10c2-469d-92b4-bf93d957814f ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nd0812c8fec094d878c0e21c172f7b9d7 .
#
# <_:N17d6ded57a5c4dd19619c44b4a925f57> a add:Change ;
#     add:appliedTo _:N697814f80a94411d89c5bb31a741fc1b ;
#     add:dependsOn event:976a0d1d-b632-4e7b-9f9e-7df3c8732c28 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N37dc9603b0b24d3fbe0bd82492907682 .
#
# <_:N183f462981e7480aafa7ad542403e961> a add:Change ;
#     add:appliedTo _:Nf01029b10ab24609a1cc7bcfb191eb4b ;
#     add:dependsOn event:6475476a-be22-4343-b163-bd855f55f267 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Na71370549dd24a178891c230b79685f3 ;
#     add:outdates _:Nb1d747cb63b14ad98e2cad1b71d33323 .
#
# <_:N1aefc5bbcb14421790dd42f98b5e1d5d> a add:Change ;
#     add:appliedTo _:Nf01029b10ab24609a1cc7bcfb191eb4b ;
#     add:dependsOn event:d5e2f7be-7cf1-4658-a188-46ee851e9cfd ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nb1d747cb63b14ad98e2cad1b71d33323 .
#
# <_:N1b6010f9a96b4f40856318d2535bf822> a add:Change ;
#     add:appliedTo _:N6e67ec4f38734942b0f15787afa045e3 ;
#     add:dependsOn event:1e93a9d2-4d3e-4bfc-958b-783e3d308c1b ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N5bbf054d84464332a18414cfccb8647a .
#
# <_:N1b978080e99942249694fc34fe272e6e> a add:Change ;
#     add:appliedTo _:Nf8d96e1e710b41798ad71c505e0f7e7b ;
#     add:dependsOn event:1ed26abb-1916-4c86-9521-1457d08a6d8a ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Nfc88d1893bf64fc8918132ae8308f503 ;
#     add:outdates _:N7bc153ded9f0476f9d409bfe8c948d79 .
#
# <_:N1c3d938a20304643b547ee6339fab8d9> a add:Change ;
#     add:appliedTo _:N7f9cd33563ac41b79b476a9ff6907f08 ;
#     add:dependsOn event:3a392ed9-7af7-4f37-b5d4-389c814ffbd1 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N717da011a2b4441bb6b391b1361dc86d .
#
# <_:N1c9327280da642e1ae70db0a208ab979> a add:Change ;
#     add:appliedTo _:N277e590083244c88abbede441ea7d99e ;
#     add:dependsOn event:50a881dd-bb63-45db-a112-e5171ba4e1d5 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N1687cb6d224441488b40714516d4a0ff .
#
# <_:N1c9bc259ceb244c6bda26f33d67447e1> a add:Change ;
#     add:appliedTo _:N3acefdb73898495c9a05d385db80247b ;
#     add:dependsOn event:2be2adad-57f7-40ba-a2dc-7c76f6f3ba94 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N1f1c56424ad24fcaaf05c78bc0745200 .
#
# <_:N1d0812fd6f31428abcfb517aaccd6fea> a add:Change ;
#     add:appliedTo _:N38795ae431a840578c15755b77ba5101 ;
#     add:dependsOn event:211796d1-bb1b-448f-b6c6-cc8fcf297d85 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Neffc790f759245df985d0ec65f3042aa .
#
# <_:N1d8642550d0448b3b566cb37c3d30fb4> a add:Change ;
#     add:appliedTo _:N6b927b7814484d1d9b5b35882f67746c ;
#     add:dependsOn event:7963ff4e-7a2f-4e28-9f1e-6a9421198902 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Naf5cb211bed94c0e91bd36e3674ac25b .
#
# <_:N1e9dc8246f764fbfb7e5c9b6dc8ffae7> a add:Change ;
#     add:appliedTo _:Na13d4291ac06453a844e028d0fcf9d7a ;
#     add:dependsOn event:1ae76bc6-2650-416a-b232-dfb5647afe59 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nde14f4b3206c445e9e5e5bc7e82c602f .
#
# <_:N1f038429f553415f9a06b5b875915016> a add:Change ;
#     add:appliedTo _:Ne87384e641f341a8abee923ee1cb3131 ;
#     add:dependsOn event:26aba371-7c1c-429e-8ce3-806c32a5ac09 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nc639d9ce71dd4708943dd2160237e70c .
#
# <_:N1f41feb7b83f4edcb163c6a13d9e754c> a add:Change ;
#     add:appliedTo _:N2df08b1845fd4089ba1f0c583464efe7 ;
#     add:dependsOn event:38a7b887-451f-4930-8cf6-884b6d8d8556 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N4216e895db8b4da2a09e783868ba5263 ;
#     add:outdates _:N00b6a78347194f959dc331c7566742dc .
#
# <_:N1f507a95b5c143d8b2e14515d6a084e9> a add:Change ;
#     add:appliedTo _:N55a7d06343b145539332113d493d3a7c ;
#     add:dependsOn event:54d6cadd-86e0-4ccd-86f6-6755a1843874 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N6c418ce10e924d1883d8885129451019 .
#
# <_:N20de3f2b22d84a55af154847fbc8a98e> a add:Change ;
#     add:appliedTo _:Na71a0769e7b342759ff897c8932da41e ;
#     add:dependsOn event:0148b71e-92fe-4f4a-8de1-4209b4720500 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nbb89a23223224cb2a3ebf65a95eca390 .
#
# <_:N20f419317c1c49238300b66a518b92b7> a add:Change ;
#     add:appliedTo _:Ne6f82f770c334be68a124362fb7445f2 ;
#     add:dependsOn event:c831b0db-6e33-4085-8908-977653959672 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Na05343edd9a040d98aeb4eaf6610b5e1 .
#
# <_:N2181586a50d4494c8530300304965151> a add:Change ;
#     add:appliedTo _:N667719dcb5044f0095c85b5cd29e3233 ;
#     add:dependsOn event:519cc522-4405-4493-98dd-fc3c2d9e1dbc ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Nf62ab7ac0d95438b81848b56a8dd7e75 ;
#     add:outdates _:Nbea8cfdfe5254d218b0d2e7d06905e30 .
#
# <_:N21d5973e13e841ccac87c5e54059421c> a add:Change ;
#     add:appliedTo _:N4f8ea6dd81a6474b8095714db1231de7 ;
#     add:dependsOn event:2ef3413a-5b9d-4673-b9b3-7196496550a2 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Nb454e75c1e9e4ff1b667accdee6d8b46 ;
#     add:outdates _:N4f8c6c4e9da54611a0e04a2f8b0c9ad3 .
#
# <_:N22cbb0dbf21d413aacc72cf64f1144df> a add:Change ;
#     add:appliedTo _:N7b5e5819b7ef41e297c6127d4960a4e3 ;
#     add:dependsOn event:7e48ec0a-1496-43ab-befe-73ba621fb7c0 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N210d33d8c52c4f79a82edb30fe52847c .
#
# <_:N24fd070a6a8447fd82505e5e9a776f57> a add:Change ;
#     add:appliedTo _:Nf8d96e1e710b41798ad71c505e0f7e7b ;
#     add:dependsOn event:057b1d3b-127c-4d20-a614-40da64e126f7 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N7bc153ded9f0476f9d409bfe8c948d79 .
#
# <_:N253ed45e67954c2ba604e81b8800e5e3> a add:Change ;
#     add:appliedTo _:Nfdb97d936bd64a8bbd50205e520bcee5 ;
#     add:dependsOn event:22d05465-057c-4ebc-9fbd-788c0611931e ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N5add67feee2a479eb64bfae26ce5032d .
#
# <_:N25a87aeb3ce4483fad4864175c62e069> a add:Change ;
#     add:appliedTo _:Nea8a586575874c71a67c15b63726971a ;
#     add:dependsOn event:4ee821c6-3ecf-4103-aa35-ecbfcc2f75e3 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N18aca61625fa408883fcfece69c704c5 .
#
# <_:N26a654f447c04be8b5eecdcd508e06b1> a add:Change ;
#     add:appliedTo _:N6d4a94efd575436cbc6d1847f1878a85 ;
#     add:dependsOn event:075cc061-9b3a-4ea5-9811-b6616824ce1e ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nd9e007203c4d4b07a3d11211579c4e2a .
#
# <_:N26f590768a14441cb4f148c827cd837b> a add:Change ;
#     add:appliedTo _:Nf0f9b999944344ecb53b4ca9ffb14529 ;
#     add:dependsOn event:6354c296-33bb-47cc-bcdd-6c8714f0eef8 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nb36b4f546944486ea8ef6ae94ebe9b02 .
#
# <_:N2751bd083d9b45fd874d3c80c4eeba63> a add:Change ;
#     add:appliedTo _:N1ba34cb51ecd4602be8c1561cddc35a4 ;
#     add:dependsOn event:68570078-24fa-47ee-8a23-d1427683a43b ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Neec16f2604c64e18bdd58910a5ba482e .
#
# <_:N27906e83c28e4e40b86d85c11b537d2f> a add:Change ;
#     add:appliedTo _:N667719dcb5044f0095c85b5cd29e3233 ;
#     add:dependsOn event:d2715c68-183e-4f90-a587-31a762943121 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nbea8cfdfe5254d218b0d2e7d06905e30 .
#
# <_:N27aeaa78c3bc44769576ba8a0b89ec02> a add:Change ;
#     add:appliedTo _:Neabe872d75664251897cb923ae9e73a1 ;
#     add:dependsOn event:9b9496fa-4138-4470-823d-e293af2dff6c ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Na141c24b0efd4a73ac46ca2e1a9fba9f .
#
# <_:N27bc077d1eb34ff384b4c008326fb44f> a add:Change ;
#     add:appliedTo _:N8c68c90f11e942238d2623647c0340a8 ;
#     add:dependsOn event:b03d4041-2d9d-43a2-9a7d-ee780f722a4f ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nc4ddea2ed5c847c5888cbbf84992dac6 .
#
# <_:N2859e30dfc1141babef9560dd1b81f0f> a add:Change ;
#     add:appliedTo _:N44252d3703674b31b59939271ec38578 ;
#     add:dependsOn event:56fb2af0-b624-4d8d-8ed4-65e4dd917919 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Nb18094d0d09b48089279f2c778f7bc00 ;
#     add:outdates _:N662c999b506444b48d2124d536293578 .
#
# <_:N288e6c169f1940159782ce880a5bad4f> a add:Change ;
#     add:appliedTo _:N2332c44044684d32a4a6923e1c2a0261 ;
#     add:dependsOn event:3743093e-fcda-49fe-a082-6508ee60c159 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nf1f0aa1831c444789a5b023a055aca98 .
#
# <_:N28c0218e84ec4d9194ee53d2f47a4fb6> a add:Change ;
#     add:appliedTo _:N9dfc7269c3a8427892436a5415fd626b ;
#     add:dependsOn event:289336b2-c488-4e3a-8f50-5145251deea5 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N80ff0e1d8f0340d18fc611a07712e542 .
#
# <_:N29b2ca490709497b86bcdf5865818259> a add:Change ;
#     add:appliedTo _:N0991a04518a34745bd3b5c8979533dce ;
#     add:dependsOn event:48cadab4-8c8d-43cd-b88e-2dbdd58f8dc8 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N8dc6bcb49adc4640b3d32ba4cc4a993b .
#
# <_:N29c859ddd2c54744bfdcfbd37cefd3e8> a add:Change ;
#     add:appliedTo _:N0991a04518a34745bd3b5c8979533dce ;
#     add:dependsOn event:2f539f08-8097-4c5d-80dd-febaf4bb73b3 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N8dc6bcb49adc4640b3d32ba4cc4a993b .
#
# <_:N2a2d249736a44c4b943e9902d1eb95f9> a add:Change ;
#     add:appliedTo _:Nb13e11f8f52c4d8fbf5548cf19e08529 ;
#     add:dependsOn event:0d1a7dcd-3b7f-4f69-b3d2-34a29b477f4d ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N9da3a13ae6ae445b8cf70fd301d7ba23 .
#
# <_:N2a3c8b777b16455594688e2ebbd424a6> a add:Change ;
#     add:appliedTo _:N2b34511eebfa471f8083fe9560948ee7 ;
#     add:dependsOn event:27ef4dcf-8aa0-461c-9c70-d6fb17d77f9e ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N0e865ab090b54b7b9ce3b25a70165f6a .
#
# <_:N2b6320355e274b1695b41219ff23ff3a> a add:Change ;
#     add:appliedTo _:Nf3b4ab37e26c46ffbeccd2b18544fb77 ;
#     add:dependsOn event:e825c9d2-c533-4e02-951f-6488912e8509 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N4100d7328191440399027360c4e45629 .
#
# <_:N2b6b1a99d5c240ef989cb4d9ef75379b> a add:Change ;
#     add:appliedTo _:Nd86e09e8349a415ebee2cc5cc77f2fed ;
#     add:dependsOn event:963ffee3-1ca7-4371-bd1f-5176e38e455b ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N8f18478c15654dd4bf5ecd461dc608e2 .
#
# <_:N2bc26b159bb44f3297fdca3c0e167039> a add:Change ;
#     add:appliedTo _:N92f21e5dd300472fa8db0b04a9a19af1 ;
#     add:dependsOn event:2570af00-e03e-45fc-92e8-333e09123b5e ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nd71d96ee72f74871908a94d235acf96e .
#
# <_:N2bcf27c4a61c4f0784d0b153dda6f04c> a add:Change ;
#     add:appliedTo _:N195b0b5aefa946048d088356396be74b ;
#     add:dependsOn event:6361df5a-c7e2-4358-a554-00747be70c60 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N2da6c5f426254e6f908b96ba9f533e47 ;
#     add:outdates _:N6754eaaab722475f912ba3c7e7d7d4ab .
#
# <_:N2bcf28c9cae543b59d50b191c9d60d72> a add:Change ;
#     add:appliedTo _:N780b789e82c74015beeeffbab954a2f3 ;
#     add:dependsOn event:c016caac-f120-4857-8937-10d93e8b0c85 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N4a059b94e7704ffd95e4cd9a34f647f7 .
#
# <_:N2cf48ed950414db5ae2667a31f186d5a> a add:Change ;
#     add:appliedTo _:N963889cda40b4659a221801315414390 ;
#     add:dependsOn event:b0434d1e-9b6c-4edb-aa16-9c82fcf176c4 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N6d01cbb433a94db28fb5d6c52254b92a .
#
# <_:N2db3bd9c8ae041c99f1dea51d27804f2> a add:Change ;
#     add:appliedTo _:N6e67ec4f38734942b0f15787afa045e3 ;
#     add:dependsOn event:26086f23-e92a-48bf-9a02-9e4c721211e4 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N5bbf054d84464332a18414cfccb8647a ;
#     add:outdates _:N3a1decbcbb4844f4a96a8602eaedab18 .
#
# <_:N2e06b2c104844f48bd7c84905871837f> a add:Change ;
#     add:appliedTo _:N1e66eabac34044f9bfe99ece564f1f30 ;
#     add:dependsOn event:5433004c-2c94-4740-8f99-40d88e9855e9 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N0cc7b71f7c8e4c52b88df7c7ca63eefd .
#
# <_:N2eabbe7b625341679f8af4f322cae2a6> a add:Change ;
#     add:appliedTo _:N1b24e66fe7ae44f6bdfc4be058384c7c ;
#     add:dependsOn event:a7dc3470-2307-4ba8-af06-dd746ce25bc2 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nf191353b9be14b3e9dcb2eb173e7ca09 .
#
# <_:N2ecf59563f9f4739a043828245152732> a add:Change ;
#     add:appliedTo _:Nae1a27de1d084646bed3df60cfc38379 ;
#     add:dependsOn event:850bc9fa-08c7-4a92-9423-f85496ec8f69 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N86bbd51ac1f94bfe9ba6796e558cd2f8 .
#
# <_:N2ef690aef29141edaf7c0cd30f88b35b> a add:Change ;
#     add:appliedTo _:Ndb5deef2326a4ec397e49da4cacaa82b ;
#     add:dependsOn event:1498547a-d5b6-459b-ab29-0142a15c5669 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N89105ed6fe414905ae278cedf70db1ff .
#
# <_:N2f873c4bc50f4906be03de098566ad06> a add:Change ;
#     add:appliedTo _:Nd3239ad98c55470ca517dff114bc7f18 ;
#     add:dependsOn event:933bed33-a591-4f76-b956-463e05a9fa4d ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N839a6d187c3d41c680b17d535515130b .
#
# <_:N2fa51b21720848088a683fa481b8aed1> a add:Change ;
#     add:appliedTo _:N18255571301446c9b43e1cb28d9220ff ;
#     add:dependsOn event:05ffc1ff-1909-4b58-a7b2-e332d0653aab ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nac47154baa204991b43bb1dc65e847a9 .
#
# <_:N3001297f0770467c9694208a2f5314b1> a add:Change ;
#     add:appliedTo _:Nc284194afab3405890df97c34c00fac5 ;
#     add:dependsOn event:ab17a4d2-cee0-473d-9e34-070312c8fc93 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Na1b500a6272b4369aaec697ce4b4956b ;
#     add:outdates _:N4f7decad9b2f4cc79867bb4801aa2ba0 .
#
# <_:N3032352afc9c4d9c82b063c22d6e3500> a add:Change ;
#     add:appliedTo _:Nb9274063a90d47a3870c0da693f3376d ;
#     add:dependsOn event:312c7d2f-36a6-49cb-b60b-99d309ddf99d ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N8865c8c64f844540b6665579c8c5b7de .
#
# <_:N30408a4667074c6787c6900937e2fb69> a add:Change ;
#     add:appliedTo _:N0aee0c4932a34ce0ae836e7ee7fa4f39 ;
#     add:dependsOn event:fe6d6e10-0fe5-4adc-92d9-2944cac4c0e0 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N19b6d6df15694416a162fd80b18b7580 ;
#     add:outdates _:N4bc1f2a1074146edad86dd0aab28c9f2 .
#
# <_:N30bf51b7870d433eb84330b6dca8cbb0> a add:Change ;
#     add:appliedTo _:Naf1db9e681af4bc9a72aba0dbc1e0e06 ;
#     add:dependsOn event:9cb95abd-2a92-4ccb-8e29-553181445d18 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N803e11db10f041899a88c18ce2159b8c .
#
# <_:N31619a68b37d44ac9c23d5c1bb272d9f> a add:Change ;
#     add:appliedTo _:N18aceec2d5fc41ac998000e7e121705c ;
#     add:dependsOn event:6193d291-2cd7-4a65-aa21-4e50bd8f836d ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Ne4e39d8cf0514f3f9012ed2f31a3704b ;
#     add:outdates _:N009f306f1ba344b9aae2e225c632034a .
#
# <_:N3184c213af7c4576a06e6a107cb85a44> a add:Change ;
#     add:appliedTo _:N9dfc7269c3a8427892436a5415fd626b ;
#     add:dependsOn event:99ea0521-5c89-497c-b3eb-ecb700179e45 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N11e08e125dc24c7da652ab1efc5e3748 ;
#     add:outdates _:N80ff0e1d8f0340d18fc611a07712e542 .
#
# <_:N31a97a8227f84dc5b191f3ef0a331026> a add:Change ;
#     add:appliedTo _:Nb3c6c9c6ce0a49deba35781818265912 ;
#     add:dependsOn event:49fe0326-135c-4c13-abb0-2506651c2643 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Ndd4e6f57ad974e9a83a14575fd1f119e .
#
# <_:N329a3f3cfd8d4502a3ce38e62583f404> a add:Change ;
#     add:appliedTo _:Nd3239ad98c55470ca517dff114bc7f18 ;
#     add:dependsOn event:762a792f-52e5-4b79-add8-599f909c2f20 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N839a6d187c3d41c680b17d535515130b .
#
# <_:N33056606a59b4502a5bcffac3623f9a6> a add:Change ;
#     add:appliedTo _:N7d722bb4076448108496ba1223af3b6f ;
#     add:dependsOn event:86854d47-996e-4c33-b86a-e9496c28dba2 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N7ab2cd5c4e414bd6b4e02163e6fdfdc8 .
#
# <_:N3372d37883a34aae827f5d95d4cdcbd2> a add:Change ;
#     add:appliedTo _:N11a0dfba9f344e159941c8c5f064264d ;
#     add:dependsOn event:299fac9b-dc7c-47de-91a7-5726299fa236 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N3e21c9a3bd7f4dd18f77781694fdd76d .
#
# <_:N33b8749733124f448d539e82fbfe533d> a add:Change ;
#     add:appliedTo _:N5d0cc483ce3c4219a4c615efac4372d7 ;
#     add:dependsOn event:e20f93e0-dff1-4a8b-bd3a-52befcc10206 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N68963d60f39c44ab8d4364c56a27a72c .
#
# <_:N33e8226fe74d4e4dbe1bd5ec860e2c36> a add:Change ;
#     add:appliedTo _:Ncf78cab64fcf46b987904efc4257ef67 ;
#     add:dependsOn event:4d4f7d9e-011e-4fb7-b80e-da6781e512a7 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N38dc209e9fda48ffbadcf3a70762e3fe .
#
# <_:N3476deb2f32449969211880b5f4a63d2> a add:Change ;
#     add:appliedTo _:Ncc2cacd96d134341bb9a6b8e39368daf ;
#     add:dependsOn event:a126c615-25d8-4b5c-9c71-55ccfe922374 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N8bd0fd0935c5413ea97c46193e60e998 .
#
# <_:N361361e318be43ecb18fa40823e3477f> a add:Change ;
#     add:appliedTo _:N277e590083244c88abbede441ea7d99e ;
#     add:dependsOn event:ee489813-db42-456c-b426-10f403e949be ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N1687cb6d224441488b40714516d4a0ff ;
#     add:outdates _:N0c42c23d245e48e9b3e2a582636f774f .
#
# <_:N36a43293f10c4a47a334e78e55e12092> a add:Change ;
#     add:appliedTo _:N920eb5c633234f61a8681a7f2c764a75 ;
#     add:dependsOn event:2d174dc6-07a2-42d9-8848-7ed4c3bdbcc9 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Necc69649c6c74850acd12b312d0d17e8 .
#
# <_:N3783d5fcf2fe47e4b21ad2d79b610867> a add:Change ;
#     add:appliedTo _:N818011b333364fd38d4256e1c43771b7 ;
#     add:dependsOn event:f1419e73-b8f8-4175-b291-ab792b315c1d ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N11fd1246b3464e9c9ffbfea315210c45 ;
#     add:outdates _:N3fea1e39365940d89d3e58f5d5a50304 .
#
# <_:N37a84f561c8e484f81d1399aa4a1b18f> a add:Change ;
#     add:appliedTo _:Nb25386dc74044849ab257626f02d1858 ;
#     add:dependsOn event:0dea51ff-91e3-418f-9a5a-059b34e17dc1 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N01649790cb314fe39165a93560e561de .
#
# <_:N398422da59b74612943f90da26764bf3> a add:Change ;
#     add:appliedTo _:N2f46dc31ac7a44c69a1891fea8adaac6 ;
#     add:dependsOn event:3a682959-f79a-484b-8d9d-52b9e7fe455f ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nf4fa69bb8d6041099270c6ebd540b2ea .
#
# <_:N3a3fe988eafd4686b526f1dd3ded3962> a add:Change ;
#     add:appliedTo _:Nfdedcb3f13284e3e85df1d35858072e0 ;
#     add:dependsOn event:31dfbfdc-d569-44d6-b800-2cb66bf64827 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nf721f1c8c35840eb94719065dd885d33 .
#
# <_:N3a6d9c01f20344d28b8411820d0aeaa2> a add:Change ;
#     add:appliedTo _:Nb403b364d8f64a88b2c459e4a72dfc35 ;
#     add:dependsOn event:dc75f4c8-0ff2-4c02-85d2-6a4aa7b668f7 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N1b534e8bb9f04a048b85fac78a728ad0 .
#
# <_:N3bc13b83321c4b6ab746ebb91363e0fc> a add:Change ;
#     add:appliedTo _:Nbbbe911af68f4caa8fa2c1b8cbb87c79 ;
#     add:dependsOn event:d75d15cb-edae-4469-88ab-198f96684bee ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N1c93b263e1ac4700947391f3ff6b363c .
#
# <_:N3e59f5f6bee746efb8f88840e121270a> a add:Change ;
#     add:appliedTo _:N89f6d0a5b78b4c9a9428e28eca70fa0f ;
#     add:dependsOn event:d134a06c-2fbd-47f2-9274-5574a0636295 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N9d6390a1edbf400e9bd26d2d2648d12f .
#
# <_:N3faaff50e72449a4bd1f31690f01270e> a add:Change ;
#     add:appliedTo _:Ne6f82f770c334be68a124362fb7445f2 ;
#     add:dependsOn event:fd3409ff-6e5b-47a1-899e-9c3a34fd22f9 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N38a5e15e342049d6b2c28106e0487fae .
#
# <_:N404875f3a4d44bc3bbf3bec90bf1e679> a add:Change ;
#     add:appliedTo _:N44252d3703674b31b59939271ec38578 ;
#     add:dependsOn event:ca0c263a-5f97-401e-84e8-811314d49cb7 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nb18094d0d09b48089279f2c778f7bc00 .
#
# <_:N4076434f6057412fbf85594308d12967> a add:Change ;
#     add:appliedTo _:N18aceec2d5fc41ac998000e7e121705c ;
#     add:dependsOn event:84a7e95e-39fa-4b68-b36f-70ee81de4a0e ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N009f306f1ba344b9aae2e225c632034a .
#
# <_:N40c71605c7a9483e9dc904828e8f0b12> a add:Change ;
#     add:appliedTo _:N195b0b5aefa946048d088356396be74b ;
#     add:dependsOn event:5b74f068-0019-48b0-808d-634564ff4896 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N6754eaaab722475f912ba3c7e7d7d4ab .
#
# <_:N41a28bfefbac4862b914d322fa149027> a add:Change ;
#     add:appliedTo _:N297507aa0d3c40e4a4fa60fcec18be37 ;
#     add:dependsOn event:598d3d73-7878-4e4c-89c4-7e2a8b708854 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:Nc5c32393ade848bb907f74d18a4e9e55 ;
#     add:outdates _:Nb7d37500492e4c838c379dcecad08f35 .
#
# <_:N4246899d8e6d4cc38156d0877fc3a5eb> a add:Change ;
#     add:appliedTo _:Nc9562e7b92244abfa589a8f0c4cfd49f ;
#     add:dependsOn event:94eb26ae-0513-463e-a06b-e523ff9e4c12 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nf9692bb813334bf98676193f94b7cebe .
#
# <_:N437f3dbffe44403b88a94fbeb88e0963> a add:Change ;
#     add:appliedTo _:N8c84bf9922954336acbe06dfad0ede0a ;
#     add:dependsOn event:eea5bb89-6c43-46fb-ae5b-fc9b90f4c696 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N9a897562c65f4be1bf130aad52446b3a .
#
# <_:N44637f8e48ba427683f6383e3cd077c4> a add:Change ;
#     add:appliedTo _:N3691d26c2dac4de1a63cee230ecca662 ;
#     add:dependsOn event:f4a6c4e9-8cae-40d1-9b74-f72eb42276eb ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N49f9d57a5ce34d06b47ae59be55bd764 .
#
# <_:N447db9c5de8e420bb60e03ada98367e9> a add:Change ;
#     add:appliedTo _:N17983aa4b98544acae80fd65631cfc44 ;
#     add:dependsOn event:7d06d35f-f7d0-4751-b66c-576b02dd5e63 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nc4bf3511664545a186be7a4b9ca2b9bc .
#
# <_:N44ecb76a031f4d3aab263b9c78d2baa1> a add:Change ;
#     add:appliedTo _:N31091f5333f246a7a22af9f0a2dfa3cd ;
#     add:dependsOn event:0da788ae-ac3e-47e2-aacf-4daf225ef9f5 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N10f68b52ac434143b4cfb4fc13c36acf .
#
# <_:N46154f15a12b455fbee6ace90037ffaa> a add:Change ;
#     add:appliedTo _:Nfdb97d936bd64a8bbd50205e520bcee5 ;
#     add:dependsOn event:d17489d2-d7c2-4670-8aa7-010cad63a6dc ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N3356842e6b524366a5c77cff33dc701c ;
#     add:outdates _:N5add67feee2a479eb64bfae26ce5032d .
#
# <_:N4653ae816f694d9495f5131d9794e255> a add:Change ;
#     add:appliedTo _:N7b5e5819b7ef41e297c6127d4960a4e3 ;
#     add:dependsOn event:86c1ebee-52c6-4b1b-8d53-1148a0df8f5f ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N38ac5ff8af3e40ddaf6a4bae1d0c0483 ;
#     add:outdates _:N16b09d079d0041e48b7d9cfdc9cdd596 .
#
# <_:N470a351d078b4381adf16561757e9d58> a add:Change ;
#     add:appliedTo _:Nd7446ed6d40b4f849a8faebc079d4149 ;
#     add:dependsOn event:12d5c1f4-1148-4c1d-ae76-2ffdd421417a ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Ncad18d6a29d342d8b581a40a9b641d64 .
#
# <_:N49d6430f71444f86bd3b3aa3b871ec88> a add:Change ;
#     add:appliedTo _:N5973050e268d41d18d40ac913788570e ;
#     add:dependsOn event:90d54b52-7791-4ffa-8796-78bc483ddb63 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N0418234aac874711b9b5d94462005983 .
#
# <_:N4a0a236f148c4db1b4d4e1954581d246> a add:Change ;
#     add:appliedTo _:Nb8bd002b73824f798b13d1098e949768 ;
#     add:dependsOn event:333c6ef1-a718-425f-b153-21f17de6bd76 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N2763aa4826d740929481b4d0f2a92527 ;
#     add:outdates _:Nd50c726a13c647f087fc40cbf8792726 .
#
# <_:N4a2a8e52b97b40fe9c666ab046a7dba7> a add:Change ;
#     add:appliedTo _:N5d0cc483ce3c4219a4c615efac4372d7 ;
#     add:dependsOn event:1455cba5-3fab-428a-8ca1-f3c52bd9d6ba ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N68963d60f39c44ab8d4364c56a27a72c ;
#     add:outdates _:Nc42b2beb512a45d78d440d53709f5334 .
#
# <_:N4b4bb5af535c41f09ad11be510997f06> a add:Change ;
#     add:appliedTo _:N4f977a5d2f134bec879a077b8fca7e47 ;
#     add:dependsOn event:62eecf35-6093-42f4-8e11-416a38f27c4a ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N881132e6b8754a1ca0434579362b4ab1 .
#
# <_:N4ca379409d264d008079ead4e20598ea> a add:Change ;
#     add:appliedTo _:N4c8cca62c2044fbf818d3d4a0d3353dc ;
#     add:dependsOn event:d26dc868-e3d9-4eab-b212-b718168a836a ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N4258c205229540d594e6528bc18beada .
#
# <_:N4cfb1d1e3c55499994bbdc98396eae88> a add:Change ;
#     add:appliedTo _:Nc284194afab3405890df97c34c00fac5 ;
#     add:dependsOn event:250b9dec-3aa7-42d5-bd5e-5750da0c6153 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Na1b500a6272b4369aaec697ce4b4956b .
#
# <_:N4d164d133d8b48f5989e172245420a07> a add:Change ;
#     add:appliedTo _:N6effe254123b423f91c509bd0b612ec2 ;
#     add:dependsOn event:ce7ee891-479d-46af-a129-b6976a9963c4 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Nd4e17ba003144adb8cbd1a83c4d61b0f .
#
# <_:N4d27467b47054ddd9bb951d2d1b27534> a add:Change ;
#     add:appliedTo _:Nda639bd486d14b5ea6250144a5dd488f ;
#     add:dependsOn event:de1cd698-a2a2-4062-9c9e-afa8c62ba736 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nb10cb5c71cff462a964f4612b78de748 .
#
# <_:N4da6e775337f4751ba55d729648474f5> a add:Change ;
#     add:appliedTo _:Nfe3446e7fa9a4c75af89a0a259dd1496 ;
#     add:dependsOn event:608f77c0-c4e8-4041-91be-2e348afeb19a ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N57c5478260254ce39d7c72f033cd520e ;
#     add:outdates _:Na85bf0aded2f4617ba3aa8bc74ea1d1a .
#
# <_:N4e0b96ac2d944d15b1cc3e81b64d5034> a add:Change ;
#     add:appliedTo _:Ne6f82f770c334be68a124362fb7445f2 ;
#     add:dependsOn event:0deb7111-e574-49f5-bb23-cc882e8cd994 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N38a5e15e342049d6b2c28106e0487fae ;
#     add:outdates _:Na05343edd9a040d98aeb4eaf6610b5e1 .
#
# <_:N4f284037a0d6478bac6326f6099e193e> a add:Change ;
#     add:appliedTo _:N105c2d1c13bf4714a2da636d6ff86f6a ;
#     add:dependsOn event:39427b7c-1b68-4788-a3b5-f20a4304af9e ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:Ne1b3e73ae2b3431881d872c1b2b8ecca .
#
# <_:N4f2ceb176986490ebbf7babea3b71ec9> a add:Change ;
#     add:appliedTo _:Nea8a586575874c71a67c15b63726971a ;
#     add:dependsOn event:5aace49d-5f6f-44e6-b84d-fc2b2a4ac4e8 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N18aca61625fa408883fcfece69c704c5 .
#
# <_:N4f8b5557617e473fa75143707b86f168> a add:Change ;
#     add:appliedTo _:Nbc4d6f6bde0246c2bc9f5249d6b45185 ;
#     add:dependsOn event:9d9e6371-30a6-4de8-8230-c15a81f6c8da ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Ncda679c69230411eb15c1f58baeb0bb2 .
#
# <_:N4fae4ee3d37a448d9c2fe72a17fbf2a7> a add:Change ;
#     add:appliedTo _:Nb8bd002b73824f798b13d1098e949768 ;
#     add:dependsOn event:a38833de-42c6-46ef-a5ea-a5d8449900b6 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N2763aa4826d740929481b4d0f2a92527 .
#
# <_:N4fafbd7821394e04a1afb515354f61a2> a add:Change ;
#     add:appliedTo _:N4d851fe4299145dcbbb5a6f0c7d7511f ;
#     add:dependsOn event:b85d204c-c88c-41d8-8a6c-779d00d30d71 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nf4380e50560e4d828b4e91d6259fb1c4 .
#
# <_:N4fbab5b8691241f8ae6efb2c34a7a88b> a add:Change ;
#     add:appliedTo _:N2df08b1845fd4089ba1f0c583464efe7 ;
#     add:dependsOn event:98f32cbc-eda9-44fb-802f-9fca1df2c3e5 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N0ef2d4f62ac04691b1ec6a2d1fff4a56 .
#
# <_:N4fc2b5fdb11d4e8086040ee78a192de3> a add:Change ;
#     add:appliedTo _:N38140a8dfff3410d819bf15dbb929eb0 ;
#     add:dependsOn event:f51aaade-000d-4706-9a2b-894a2b5cea05 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N3f89bd874cc9402ba89a6525b7e914c5 .
#
# <_:N516973043c8b4a1597f021e33d56d111> a add:Change ;
#     add:appliedTo _:Nf399916abfea4c91a2485cfeffb551ad ;
#     add:dependsOn event:ba94ab5a-74a0-4002-bd52-cff2068a9655 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N50ca64dff5184008a4cddfe55b628392 .
#
# <_:N51a2ee887475426d8569682738eaa873> a add:Change ;
#     add:appliedTo _:N14a42b8f92c64a2ea00f2a85565a42ef ;
#     add:dependsOn event:71d1680d-185f-4c02-8872-6e36cc87a6e8 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N4fe8b3e0dedf436d8008b95aba3081b5 .
#
# <_:N525b4564ef1b45cd8f49790ef5d0fe46> a add:Change ;
#     add:appliedTo _:Na79f2cee86494c79b72f27e27dbd7c85 ;
#     add:dependsOn event:0467ae2c-06e9-461a-88fe-6656d4eb8607 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N9d4869059da748c988baa42a69a1d02f .
#
# <_:N528d7387bf814c65adabcc2c16aed2dc> a add:Change ;
#     add:appliedTo _:N05d0facf3ef94ba8908b61513cee0922 ;
#     add:dependsOn event:b0d7fade-dfed-4f97-9ce8-81aeeb2e3cdd ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Na2d61258370f4d8eab1d114ed748a528 .
#
# <_:N52afcb4377cf4eef9dea89a4e8becafe> a add:Change ;
#     add:appliedTo _:N0faaefb5da314cd68c4baaf3b2e6f233 ;
#     add:dependsOn event:7a55f880-b987-4aaa-8d1e-7ab08ec124d4 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N660d1c79e3f74e58b4139d0e72c6a607 ;
#     add:outdates _:Na03621956a25438db4a7327535068672 .
#
# <_:N54a3371d05e54d6bac6e8278c42f3929> a add:Change ;
#     add:appliedTo _:Nbae09bc5889a4451a8bd9ab3665b0dea ;
#     add:dependsOn event:8d367ae8-96d0-4c60-befc-78a32f659bc2 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N681b2f17a50940f6871a3709db3412a0 .
#
# <_:N55e9875ec3d8453faf3f6d8c72128f1a> a add:Change ;
#     add:appliedTo _:N34b0b8a1f4cd4050bb7e0e5edd35c21b ;
#     add:dependsOn event:b33e4f7f-f09f-42bf-bc74-a05857404019 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N76e737427b1b44d29998e84a3c722d07 .
#
# <_:N565cb21f209b4c73919e5af32e158209> a add:Change ;
#     add:appliedTo _:N1c5e86f8cb194b0f84a785acaa1ddc9f ;
#     add:dependsOn event:c4915b37-de97-4d2a-be78-96e50c68e68a ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N3a09971591864dc09549899641273d64 .
#
# <_:N56b319d4f23a4b97b1103c6821fb05d0> a add:Change ;
#     add:appliedTo _:N77918d4fd0734841875538447031342b ;
#     add:dependsOn event:ad228ff4-fac5-4012-9c1d-cb2fe94f25b2 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N9ce858b1c2514312a92e8e08c0626cd2 ;
#     add:outdates _:N049d2557c35742e48aabe3bef18a171c .
#
# <_:N56be89d2441247b19e4a16ef5be6c99a> a add:Change ;
#     add:appliedTo _:N85254733cd2b470cba7bb231e052d035 ;
#     add:dependsOn event:27374b31-8a8a-41a5-8325-cf0b0b045adf ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N405bbc7029e14748929d16505593590e .
#
# <_:N56f191a73a3041fd83858d5ff15fb24b> a add:Change ;
#     add:appliedTo _:N6d4a94efd575436cbc6d1847f1878a85 ;
#     add:dependsOn event:41f88949-f839-40d6-a000-819600ae73ca ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nd9e007203c4d4b07a3d11211579c4e2a .
#
# <_:N588ac4d566744e2e8fd1883fdadfcf72> a add:Change ;
#     add:appliedTo _:N5d0cc483ce3c4219a4c615efac4372d7 ;
#     add:dependsOn event:18f962d5-e22f-4627-95c4-873e21017a9c ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nc42b2beb512a45d78d440d53709f5334 .
#
# <_:N59836c00fa364c32828fd51706fb244e> a add:Change ;
#     add:appliedTo _:Nd86e09e8349a415ebee2cc5cc77f2fed ;
#     add:dependsOn event:56a2bdec-5b30-4cd2-85f5-4e13862e51f2 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N8f18478c15654dd4bf5ecd461dc608e2 .
#
# <_:N59e30f35b7d345f298dfa65a1f255a75> a add:Change ;
#     add:appliedTo _:Na3339e7ce73149089008c52ee3c33208 ;
#     add:dependsOn event:88e557ee-d8c3-4589-a093-d2731af0eb33 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nc012355bea484267946707291462c5da .
#
# <_:N5a28dc84dde0424b93c71d964b3b0a8e> a add:Change ;
#     add:appliedTo _:Nd28485fb97e2449297130656680dab4f ;
#     add:dependsOn event:d5273d04-79b8-4264-89d8-acfc46e05965 ;
#     add:isChangeType ctype:AttributeVersionDisappearance ;
#     add:outdates _:N26db4774943c481a829c34f18c87c608 .
#
# <_:N5a40be29db07482bbb95aac2041b487e> a add:Change ;
#     add:appliedTo _:Na9416b6d5b644249afa1dd5c4075af00 ;
#     add:dependsOn event:3c3576f7-2398-452e-b6ab-98127c4c9cee ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N7c94cda6b1844ab7b5bebef101807113 ;
#     add:outdates _:N8e743b3df0a54c049fab198bf6b60a3a .
#
# <_:N5a4266cda6ab441aa2845042349ac0a5> a add:Change ;
#     add:appliedTo _:N53cc12fabbf341099c4fa7358ee3bdb2 ;
#     add:dependsOn event:c3f0b9db-8304-41c9-8773-7cdb25372fee ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:N63f4fad0f2e940b4b5eb061e938166b8 .
#
# <_:N5ac767f4c5f64ae2b3b1e68039538971> a add:Change ;
#     add:appliedTo _:N4a4d3a073aaa47f09327a4c8724b3867 ;
#     add:dependsOn event:a3523305-47cd-4f3c-b904-817e0e802aad ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Ne03e35516bef47a8bab0642d20bad151 .
#
# <_:N5b85cf31747f480586eb75651af9b467> a add:Change ;
#     add:appliedTo _:N2dc941a2b9564c7b8149a3fe7ec86535 ;
#     add:dependsOn event:d1bb6ff3-2226-4be4-9967-4216cc16172d ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective _:Nc8326d1b67144cffb010bd301c845c70 .
#
# <_:N5c36d61788c14caa977b775e1a0c5246> a add:Change ;
#     add:appliedTo _:N818011b333364fd38d4256e1c43771b7 ;
#     add:dependsOn event:5c8eed56-f945-4442-bce5-e16e0c07668c ;
#     add:isChangeType ctype:AttributeVersionTransition ;
#     add:makesEffective _:N3fea1e39365940d89d3e58f5d5a50304 ;
#     add:outdates _:N60c35e7cf1ad44a9831bdef6483edacd .
#
# <_:N5d5d255a6f644197b4586de42c51255d> a add:Change ;
#     add:appliedTo _:N2d7b0eaabeea4f4986d785ebfa20fe01 ;
#     add:dependsOn event:795e8f56-8434-4c3d-9f62-2d8ee97f1908 ;
#     add:isChangeType ctype:AttributeVersionTransition ;
# ...
#
# _:Nfba6420e4cf94d91b317e3d91db61d26 a add:AttributeVersion ;
#     cad:hasTaxpayer taxpayer:83a2ec0a-35c3-471a-bdd0-77360883bff2_taxpayer_1 .
#
# _:Nfc24378d11f346daa9d17a1ad7f18cb5 a add:AttributeVersion ;
#     cad:hasTaxpayer taxpayer:3c4d4277-731a-4644-b214-450b7bce2d75_taxpayer_1 .
#
# _:Nfc88d1893bf64fc8918132ae8308f503 a add:AttributeVersion ;
#     cad:hasTaxpayer taxpayer:e6823862-3808-4e2e-b9af-4cae88ee1b21_taxpayer_2 .
#
# _:Nfdaa03414df040228c459598f40ffbfd a add:AttributeVersion ;
#     cad:hasTaxpayer taxpayer:f786bc86-e8e7-48d8-9a95-864dc392d982_taxpayer_1 .
#
# _:Nfdedcb3f13284e3e85df1d35858072e0 a add:Attribute ;
#     add:hasAttributeVersion _:Nf721f1c8c35840eb94719065dd885d33 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nfe105278f7e14b7f89f07ae019a009a8 a add:AttributeVersion ;
#     cad:hasTaxpayer taxpayer:cd7810ff-8855-41fe-bb6b-abea444eb45f_taxpayer_1 .
#
# _:Nfe2ddf2493714a1b8629c55ad7ebe7cd a add:AttributeVersion ;
#     cad:hasTaxpayer taxpayer:4d605a48-f253-40dd-a83f-5a728e279a55_taxpayer_3 .
#
# _:N044d84da3a0f474287e8efe47fa82eda a add:Attribute ;
#     add:hasAttributeVersion _:N9e3d1b16df4c4374b5c8c9dd4053faf4,
#         _:Ne3a4321f06434fd7aeb14e683fdbf546 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N0aee0c4932a34ce0ae836e7ee7fa4f39 a add:Attribute ;
#     add:hasAttributeVersion _:N19b6d6df15694416a162fd80b18b7580,
#         _:N4bc1f2a1074146edad86dd0aab28c9f2 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N0cab5a64632b4429bf41b81926b2b271 a add:Attribute ;
#     add:hasAttributeVersion _:N7b243f90962840359dc9e598e86f2ed2,
#         _:Nb0437afb8f644a729e63ee2c9af1322a ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N0faaefb5da314cd68c4baaf3b2e6f233 a add:Attribute ;
#     add:hasAttributeVersion _:N660d1c79e3f74e58b4139d0e72c6a607,
#         _:Na03621956a25438db4a7327535068672 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N159f266154ce411dbc34c4556bea8ad6 a add:Attribute ;
#     add:hasAttributeVersion _:N08f4f45ad14441908a077cfbead7b9c1,
#         _:Nc6f5906c01e44c16b908117704d997da ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N18255571301446c9b43e1cb28d9220ff a add:Attribute ;
#     add:hasAttributeVersion _:N1466dd10d5624e0f8ca2f115d5947d37,
#         _:Nac47154baa204991b43bb1dc65e847a9 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N195b0b5aefa946048d088356396be74b a add:Attribute ;
#     add:hasAttributeVersion _:N2da6c5f426254e6f908b96ba9f533e47,
#         _:N6754eaaab722475f912ba3c7e7d7d4ab ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N1c5e86f8cb194b0f84a785acaa1ddc9f a add:Attribute ;
#     add:hasAttributeVersion _:N3a09971591864dc09549899641273d64,
#         _:Nb524ebf2252341cc834927fa210024ad ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N1f7d8f3384414491ae0879e493bd51e0 a add:Attribute ;
#     add:hasAttributeVersion _:N5b58f06690e54dc7bc6f02d75fd21312,
#         _:Ne10d02e1ed554e078b70dc068c186214 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:
;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N76e7adec658d47b59430859849395841 a add:Attribute ;
#     add:hasAttributeVersion _:N19a4778a9b6445a6802cca0955a02a05,
#         _:Nb2b24477e9584d81a92e9b76aa1573e9 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N77918d4fd0734841875538447031342b a add:Attribute ;
#     add:hasAttributeVersion _:N049d2557c35742e48aabe3bef18a171c,
#         _:N9ce858b1c2514312a92e8e08c0626cd2 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N864180f2cd8d425c9eb8344e033d75d4 a add:Attribute ;
#     add:hasAttributeVersion _:N450ce1bc9e304bfe80f61f211b417e06,
#         _:N91ec56e7088e4b7aa2888b3b563d135f ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N8c090b2d1b9241cdb63c90f3422439b1 a add:Attribute ;
#     add:hasAttributeVersion _:N468ab08956ad48149aaf327ae1702718,
#         _:Nbf9a61ce2b5749c68825f240925f4f1b ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N9dfc7269c3a8427892436a5415fd626b a add:Attribute ;
#     add:hasAttributeVersion _:N11e08e125dc24c7da652ab1efc5e3748,
#         _:N80ff0e1d8f0340d18fc611a07712e542 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Naad3861d67ad42c192512034a14db476 a add:Attribute ;
#     add:hasAttributeVersion _:N2827ea25737b43f3b324877b8f3e08a3,
#         _:N3420fd475efc4791ba9033588ec643cc ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nb2b6bf574e534d2c967d89cbbc01b35e a add:Attribute ;
#     add:hasAttributeVersion _:N51c5f63953864db38b0372c52a513855,
#         _:Nd0812c8fec094d878c0e21c172f7b9d7 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nb403b364d8f64a88b2c459e4a72dfc35 a add:Attribute ;
#     add:hasAttributeVersion _:N1b534e8bb9f04a048b85fac78a728ad0,
#         _:N6e750d7e60a5478a93d339995cd4f093 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nb8bd002b73824f798b13d1098e949768 a add:Attribute ;
#     add:hasAttributeVersion _:N2763aa4826d740929481b4d0f2a92527,
#         _:Nd50c726a13c647f087fc40cbf8792726 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nbae09bc5889a4451a8bd9ab3665b0dea a add:Attribute ;
#     add:hasAttributeVersion _:N681b2f17a50940f6871a3709db3412a0,
#         _:Nebdaa58c6c0741fead1dcc9dca8bca3c ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nbc4d6f6bde0246c2bc9f5249d6b45185 a add:Attribute ;
#     add:hasAttributeVersion _:N864dc94b0ab14eaf95a63d5668dbba68,
#         _:Ncda679c69230411eb15c1f58baeb0bb2 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nc284194afab3405890df97c34c00fac5 a add:Attribute ;
#     add:hasAttributeVersion _:N4f7decad9b2f4cc79867bb4801aa2ba0,
#         _:Na1b500a6272b4369aaec697ce4b4956b ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nc614de17d27a4702bedad7ea7c5bf147 a add:Attribute ;
#     add:hasAttributeVersion _:N0b4ce60bb7144c3d94b0aa425f00924c,
#         _:Ndeb6ef43acfc4b6ba3fbbe12b163ddfb ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nc70c86c8cfc1413fb45b356ad00b2a48 a add:Attribute ;
#     add:hasAttributeVersion _:N683515d28b8d4ca580ffcab674df2773,
#         _:N7bda89bddc5546308f2e0d46b0c0bddd ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nc7170e71cd3c4da1a0042ffa7d2d37b6 a add:Attribute ;
#     add:hasAttributeVersion _:N1b88e1f204874d91a2fc61f418336c00,
#         _:Nf84f770f5718419ca644783a5d7fba7a ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Ncc2cacd96d134341bb9a6b8e39368daf a add:Attribute ;
#     add:hasAttributeVersion _:N1fd6bb96a6e14bfa9339dcc6034ff97e,
#         _:N8bd0fd0935c5413ea97c46193e60e998 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nd7bde2ff3eee4e5aa42e0467687b6e12 a add:Attribute ;
#     add:hasAttributeVersion _:N2829797bfb8542e682add1d5d5f14831,
#         _:Nef0c101ad42b41c9adedd1cceaf44f3e ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nd854167673ce4892bf70e7028453ed47 a add:Attribute ;
#     add:hasAttributeVersion _:N55f1ee5021b04e089c6941f2006d0d5d,
#         _:N6f8f289c7c5b4baf8380c0bbce6c9b39 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Ne6f82f770c334be68a124362fb7445f2 a add:Attribute ;
#     add:hasAttributeVersion _:N38a5e15e342049d6b2c28106e0487fae,
#         _:Na05343edd9a040d98aeb4eaf6610b5e1 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nf01029b10ab24609a1cc7bcfb191eb4b a add:Attribute ;
#     add:hasAttributeVersion _:Na71370549dd24a178891c230b79685f3,
#         _:Nb1d747cb63b14ad98e2cad1b71d33323 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nfa87fd4b0ef3470c83e108239e3a6539 a add:Attribute ;
#     add:hasAttributeVersion _:N318e3907d1c847a3bc4c3b38892cf57f,
#         _:N4202fdb4c2c34d4aa400acfa8f07fc64 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nfe3446e7fa9a4c75af89a0a259dd1496 a add:Attribute ;
#     add:hasAttributeVersion _:N57c5478260254ce39d7c72f033cd520e,
#         _:Na85bf0aded2f4617ba3aa8bc74ea1d1a ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N0460a961df2645dbb079c276cc2e49e2 a add:Attribute ;
#     add:hasAttributeVersion _:N7402bde1b0164679afa2de50f99c3172,
#         _:N7adfb5cbbe824818b720ebe689c4a08a,
#         _:N7ba05c7b10a444ac9961b281fdd570d1 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N18aceec2d5fc41ac998000e7e121705c a add:Attribute ;
#     add:hasAttributeVersion _:N009f306f1ba344b9aae2e225c632034a,
#         _:N82d1ea63319d4d6a93c6bb174d73749a,
#         _:Ne4e39d8cf0514f3f9012ed2f31a3704b ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N1f566ee0e9524644afeeb19cac81a29c a add:Attribute ;
#     add:hasAttributeVersion _:N0271f891e73049aaa7910a23d340110d,
#         _:N26be5b0baccf4d5ea113abced4c4c1e2,
#         _:N61df2494623b46929272e606d270e148 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N277e590083244c88abbede441ea7d99e a add:Attribute ;
#     add:hasAttributeVersion _:N0c42c23d245e48e9b3e2a582636f774f,
#         _:N1687cb6d224441488b40714516d4a0ff,
#         _:Nfba6420e4cf94d91b317e3d91db61d26 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N2b34511eebfa471f8083fe9560948ee7 a add:Attribute ;
#     add:hasAttributeVersion _:N0e865ab090b54b7b9ce3b25a70165f6a,
#         _:N9469dac58a2240c1842c86ab9b2ce964,
#         _:Nd3f74dfaf84a465da7b9ab2acafbd499 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N2df08b1845fd4089ba1f0c583464efe7 a add:Attribute ;
#     add:hasAttributeVersion _:N00b6a78347194f959dc331c7566742dc,
#         _:N0ef2d4f62ac04691b1ec6a2d1fff4a56,
#         _:N4216e895db8b4da2a09e783868ba5263 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N3ba824892660481ebfbfe300660542ba a add:Attribute ;
#     add:hasAttributeVersion _:N0513920db2c648a4aa96608291411ec4,
#         _:N5ff3bdca15434cc0a7270a40a4248032,
#         _:N994cd06bb3364674afa821963e0ddfd1 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N4b1381dbc11b4a3ea3f822d7ffab38be a add:Attribute ;
#     add:hasAttributeVersion _:N03ebdfcb9d454d0cba52b1d0ca364184,
#         _:Nb03a1f4771914c0e859322d180937843,
#         _:Nd08e25f7e9054076baede83331d9682a ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N61e6fe0f51134776aa9df6b12c2f3d00 a add:Attribute ;
#     add:hasAttributeVersion _:N37141b19831e43308429d0eca375f94a,
#         _:N8c5711e9f53b4fe59b92c2080e721cfb,
#         _:Nef9f06c51353488283c95cc5e5898c98 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N648b90d3ccad4fb1b11845b9dc49a5be a add:Attribute ;
#     add:hasAttributeVersion _:N0f51fde6e0c3417c852680af73be675d,
#         _:N9cfec402b84f4f35bf46865953b7303e,
#         _:Nc4a904355c9a4c54a0f6d1a472f3dd16 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N6effe254123b423f91c509bd0b612ec2 a add:Attribute ;
#     add:hasAttributeVersion _:N27f97f40e5514da69f4e9f1071bb48d5,
#         _:N83f30c674be34acfa0ecd288bc994c39,
#         _:Nd4e17ba003144adb8cbd1a83c4d61b0f ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N7b5e5819b7ef41e297c6127d4960a4e3 a add:Attribute ;
#     add:hasAttributeVersion _:N16b09d079d0041e48b7d9cfdc9cdd596,
#         _:N210d33d8c52c4f79a82edb30fe52847c,
#         _:N38ac5ff8af3e40ddaf6a4bae1d0c0483 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N818011b333364fd38d4256e1c43771b7 a add:Attribute ;
#     add:hasAttributeVersion _:N11fd1246b3464e9c9ffbfea315210c45,
#         _:N3fea1e39365940d89d3e58f5d5a50304,
#         _:N60c35e7cf1ad44a9831bdef6483edacd ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N899c4c80bfa24585a052c056964f03be a add:Attribute ;
#     add:hasAttributeVersion _:N63ffcbcb2e7a43e8b2ee14d02da1c4e8,
#         _:Na513d836357345a1b5da209f26c639e4,
#         _:Ndbc623001672430ca01da7850942446b ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N90694a8598574fd5951b7ca70b732260 a add:Attribute ;
#     add:hasAttributeVersion _:N37d18c87dca740b4a20004f2b1e128ed,
#         _:N6694f01e9a4b46b4a07d4213e276b07e,
#         _:Nb85b61bc33bb4ed1a5be2b473dbaf2cf ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:N963889cda40b4659a221801315414390 a add:Attribute ;
#     add:hasAttributeVersion _:N6d01cbb433a94db28fb5d6c52254b92a,
#         _:N6fd878de99044ac9b8525c8660423988,
#         _:Ncba7b594d0b24694b4ab382bcb2a8f4b ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nf8d96e1e710b41798ad71c505e0f7e7b a add:Attribute ;
#     add:hasAttributeVersion _:N7bc153ded9f0476f9d409bfe8c948d79,
#         _:Nd8dd225116794f9c83b7f28ca3e96b42,
#         _:Nfc88d1893bf64fc8918132ae8308f503 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Nfdb97d936bd64a8bbd50205e520bcee5 a add:Attribute ;
#     add:hasAttributeVersion _:N3356842e6b524366a5c77cff33dc701c,
#         _:N5add67feee2a479eb64bfae26ce5032d,
#         _:Nfe2ddf2493714a1b8629c55ad7ebe7cd ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
#
# _:Na9416b6d5b644249afa1dd5c4075af00 a add:Attribute ;
#     add:hasAttributeVersion _:N7c94cda6b1844ab7b5bebef101807113,
#         _:N8204bb0fa025477786a99268de2004d4,
#         _:N8e743b3df0a54c049fab198bf6b60a3a,
#         _:Nf58f2b74e3ee471ab013746a2174b780 ;
#     add:isAttributeType cad_atype:PlotTaxpayer .
# <Graph identifier=Nf95d9ab364324ef5978e898dc820f1fb (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### 1.X Création des états de parcelles

# %%
matrices
# Out:
#       ID                                  UUID   Type_CF Num_Folio  \
# 0      1  7c13b9ec-506c-4675-b691-335b828bbe11      Bâti       108
# 1      2  649a3bb0-7483-44c8-ad90-96bfc1808fdd      Bâti       114
# 2      3  bf640773-d6ff-4ba8-be3b-ffdd199dd8a4      Bâti        82
# 3      4  fe2c20fe-237f-4da7-8c7d-1ae33e5e1b96      Bâti        82
# 4      5  a8d13691-1a81-4684-9db7-98ee1fbc354d      Bâti        64
# ..   ...                                   ...       ...       ...
# 437  219  da62bcf1-3993-420b-8aac-e7cd1d1b4cda  Non Bâti      1221
# 438  220  d0f7ae85-fd51-459b-a4b4-48a8335cf44a  Non Bâti      1221
# 439  221  e0d84f8b-4b9b-4b54-92f0-e1d36d5e6e45  Non Bâti      1222
# 440  222  af70cad2-55f9-4163-8c6b-ece562802b66  Non Bâti      1222
# 441  223  244a34a1-1a2f-4170-8564-77a1899f17fe  Non Bâti      1222
#
#      Alt_Num_CF  Groupe_CF  Ordre_de_lecture Voie Num_Voie  \
# 0           NaN          1                 1  NaN      NaN
# 1           NaN          1                 1  NaN      NaN
# 2           NaN          1                 1  NaN      NaN
# 3           NaN          1                 2  NaN      NaN
# 4           NaN          1                 1  NaN      NaN
# ..          ...        ...               ...  ...      ...
# 437         NaN          1                 6  NaN      NaN
# 438         NaN          1                 7  NaN      NaN
# 439         NaN          1                 1  NaN      NaN
# 440         NaN          1                 2  NaN      NaN
# 441         NaN          1                 3  NaN      NaN
#
#                          Image  ... Porté à_treated Ligne barrée ? CF rayé ?  \
# 0    FRAD094_3P_000255_01_0586  ...             NaN            Non       Non
# 1    FRAD094_3P_000255_01_0588  ...              82            Oui       Oui
# 2    FRAD094_3P_000255_01_0579  ...             NaN            Non       Non
# 3    FRAD094_3P_000255_01_0579  ...             NaN            Non       Non
# 4    FRAD094_3P_000255_01_0571  ...             NaN            Non       Non
# ..                         ...  ...             ...            ...       ...
# 437  FRAD094_3P_000264_01_0221  ...             NaN            Non       Non
# 438  FRAD094_3P_000264_01_0221  ...             NaN            Non       Non
# 439  FRAD094_3P_000264_01_0222  ...             NaN            Non       Non
# 440  FRAD094_3P_000264_01_0222  ...             NaN            Non       Non
# 441  FRAD094_3P_000264_01_0222  ...             NaN            Non       Non
#
#                                          Spécification Commentaire Cote liée  \
# 0    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# 1    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# 2    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# 3    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# 4    Matrice des propriétés bâties ne sont plus mis...         NaN       NaN
# ..                                                 ...         ...       ...
# 437                                                NaN         NaN       NaN
# 438                                                NaN         NaN       NaN
# 439                                                NaN         NaN       NaN
# 440                                                NaN         NaN       NaN
# 441                                                NaN         NaN       NaN
#
#      registre Num_Folio_clean Tire_de_clean Porte_a_clean
# 0    MAT_1813             108         EMPTY         EMPTY
# 1    MAT_1813             114         EMPTY            82
# 2    MAT_1813              82           114         EMPTY
# 3    MAT_1813              82         EMPTY         EMPTY
# 4    MAT_1813              64         EMPTY         EMPTY
# ..        ...             ...           ...           ...
# 437  MAT_1848            1221         EMPTY         EMPTY
# 438  MAT_1848            1221         EMPTY         EMPTY
# 439  MAT_1848            1222         EMPTY         EMPTY
# 440  MAT_1848            1222         EMPTY         EMPTY
# 441  MAT_1848            1222         EMPTY         EMPTY
#
# [442 rows x 37 columns]

# %%
matrices.columns
# Out:
# Index(['ID', 'UUID', 'Type_CF', 'Num_Folio', 'Alt_Num_CF', 'Groupe_CF',
#        'Ordre_de_lecture', 'Voie', 'Num_Voie', 'Image', 'Section_clean',
#        'Parcelle_clean', 'Lieu-dit_transcript', 'Lieu-dit_clean',
#        'Lieu-dit_treated', 'Lieu-dit_type', 'Propriétaires_transcript',
#        'Nature_transcript', 'Nature_clean', 'Nature_treated', 'Date entrée',
#        'Date entrée_treated', 'Date sortie', 'Date sortie_treated', 'Tiré de',
#        'Tiré de_treated', 'Porté à', 'Porté à_treated', 'Ligne barrée ?',
#        'CF rayé ?', 'Spécification', 'Commentaire', 'Cote liée', 'registre',
#        'Num_Folio_clean', 'Tire_de_clean', 'Porte_a_clean'],
#       dtype='object')

# %%
from namespaces import *

# Create a new RDF graph
g = Graph()

g.bind('landmark', landmarkuri)
g.bind('owner', owneruri)
g.bind('source', srcuri)
g.bind('cad_ltype', cad_ltype)
g.bind('cad_atype', cad_atype)
g.bind('cad_etype', cad_etype)
g.bind('cad_spval', cad_spval)
g.bind('ctype', ctype)
g.bind('lrtype', lrtype)
g.bind('srctype', srctype)
g.bind('mlclasse', mlclasse)
g.bind('pnature', pnature)

g.bind('cad', cad)
g.bind('add', add)
g.bind('rico', rico)
g.bind('fpo', fpo)
g.bind('time',time)

# Iterate over each row in the DataFrame
for index, row in matrices.iterrows():
    #Infos de l'image
    json = parse_record_id(row["Image"])
    #Infos de la matrice et du plan
    MATRICE_ID = matrices_metada[row['registre']]["MATRICE_ID"]
    MATRICE_START = matrices_metada[row['registre']]["MATRICE_START"]
    MATRICE_END = matrices_metada[row['registre']]["MATRICE_END"]
    PLAN = matrices_metada[row['registre']]["PLAN"]
    #Article de classement correspondant à la ligne
    articleclassementuri = URIRef(srcuri + f"{row['UUID']}_classement")
    Iarticleclassementuri = URIRef(srcuri + f"{row['UUID']}_classement_instanciation")
    g.add((Iarticleclassementuri, cad.lineOrderInArea, Literal(row['Ordre_de_lecture'], datatype=XSD.integer))) #Ordre dans le compte foncier (ce sera plutôt dans la page avec DAN)

    #Création de l'état des landmarks de type Plot
    subject_uri = URIRef(landmarkuri + f"{row['UUID']}")
    g.add((subject_uri, RDF.type, add.Landmark))
    g.add((subject_uri, add.isLandmarkType, cad_ltype.Plot))
    g.add((subject_uri, DCTERMS.identifier, Literal(row['Section_clean'] + '-' + str(row['Parcelle_clean']), datatype=XSD.string)))
    g.add((subject_uri, SKOS.prefLabel, Literal(row['Section_clean'] + '-' + str(row['Parcelle_clean']) + ' ('+ COMMUNE +')', datatype=XSD.string)))
    g.add((subject_uri, RDFS.label, Literal(row['Section_clean'] + '-' + str(row['Parcelle_clean']) + ' ('+ COMMUNE +')', datatype=XSD.string)))

    #LandmarkRelation certaine Plot <=> Section
    relationode = BNode()
    g.add((URIRef(relationode.n3()), RDF.type, add.LandmarkRelation))
    g.add((URIRef(relationode.n3()), add.locatum, add_uri))
    if MATRICE_ID == 'MAT_1848':
        g.add((URIRef(relationode.n3()), add.relatum, URIRef(landmarkuri + 'da6a5c2c-e86d-43bb-8950-7169bd0df60a')))
    else:
        g.add((URIRef(relationode.n3()), add.relatum, URIRef(landmarkuri + '87d7c2f6-306b-45a1-a833-5e17821c3102')))

    #Article de classement et folios précédents/suivants
    plotMentionAttr = BNode()
    g.add((subject_uri, add.hasAttribute,plotMentionAttr))
    g.add((plotMentionAttr, RDF.type, add.Attribute))
    g.add((plotMentionAttr, add.isAttributeType, cad_atype.PlotMention))
    plotMentionAttrVersion = BNode()
    g.add((plotMentionAttr, add.hasAttributeVersion, plotMentionAttrVersion))
    g.add((plotMentionAttrVersion, RDF.type, add.AttributeVersion))
    
    ## Article de classement
    g.add((plotMentionAttrVersion, cad.isMentionnedIn, articleclassementuri))

    ## Folio.s ou valeur.s spéciale.s précédent.s (Tiré de)
    if not pd.isnull(row['Tiré de_treated']):
        tire_de = str(row['Tiré de_treated']).split(';')
        for f in tire_de:
            f = str(f)
            if any(char.isdigit() for char in f) and 'mission' not in f:
                g.add((plotMentionAttrVersion, cad.takenFrom, URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{MATRICE_ID}_{f}")))
            elif 'mission' in f:
                g.add((plotMentionAttrVersion, cad.takenFrom, URIRef(cad_spval + f"OmissionSV")))
            elif f != '' or f != 'nan':
                g.add((plotMentionAttrVersion, cad.takenFrom, URIRef(cad_spval + f)))
    else:
        g.add((plotMentionAttrVersion, cad.takenFrom, URIRef(cad_spval + "CelluleVideSV")))
    ## Folio.s ou valeur.s spéciale.s  suivant.s (Porté à)
    if not pd.isnull(row['Porté à_treated']):
        porte_a = str(row['Porté à_treated']).split(';')
        for f in porte_a:
            if any(char.isdigit() for char in str(f)) and 'mission' not in f:
                g.add((plotMentionAttrVersion, cad.passedTo, URIRef(srcuri + f"{json['departement']}_{COMMUNE}_{MATRICE_ID}_{f}")))
            elif f != '' or f != 'nan':
                g.add((plotMentionAttrVersion, cad.passedTo, URIRef(cad_spval + f)))
    else:
        g.add((plotMentionAttrVersion, cad.passedTo, URIRef(cad_spval + "CelluleVideSV")))

    ## Time
    hastime = BNode()
    if not pd.isnull(row['Date entrée_treated']) or not pd.isnull(['Date sortie_treated']):
        g.add((plotMentionAttrVersion, add.hasTime, hastime))
        g.add((hastime, RDF.type, add.TimeInterval))

        hasbeginning = BNode()
        g.add((hasbeginning, RDF.type, add.TimeInstant))
        g.add((hasbeginning, add.timeCalendar, time.Gregorian))
        g.add((hasbeginning, add.timePrecision, time.Year))
        if not pd.isna(row['Date entrée_treated']) and not pd.isnull(row['Date entrée_treated']):
            g.add((hastime, add.hasBeginning, hasbeginning))
            g.add((hasbeginning, add.timeStamp, Literal(datetime.strptime(str(int(row['Date entrée_treated'])) + '-01-01', '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))
        else:
            g.add((hastime, add.hasEarliestTimeInstant, hasbeginning))
            g.add((hasbeginning, add.timeStamp, Literal(datetime.strptime(MATRICE_START + '-01-01', '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))#date d'ouverture de la matrice
        
        hasend = BNode()
        g.add((hasend,RDF.type, add.TimeInstant))
        g.add((hasend, add.timeCalendar, time.Gregorian))
        g.add((hasend, add.timePrecision, time.Year))

        if not pd.isnull(row['Date sortie_treated']) and row['Date sortie_treated'] != 'nan':
            g.add((hastime, add.hasEnd, hasend))
            g.add((hasend, add.timeStamp, Literal(datetime.strptime(str(int(row['Date sortie_treated'])) + '-12-31', '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))
        else:
            g.add((hastime, add.hasLatestTimeInstant, hasend))
            g.add((hasend, add.timeStamp, Literal(datetime.strptime(MATRICE_END + '-12-31', '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))
    
    #Address
    if not pd.isnull(row['Lieu-dit_treated']):
        plotaddress = BNode()
        g.add((subject_uri, add.hasAttribute, plotaddress))
        g.add((plotaddress, RDF.type, add.Attribute))
        g.add((plotaddress, add.isAttributeType, cad_atype.PlotAddress))
        plotaddressversion = BNode()
        g.add((plotaddress, add.hasAttributeVersion, plotaddressversion))
        g.add((plotaddressversion, RDF.type, add.AttributeVersion))
        relationode = BNode()
        g.add((plotaddressversion, cad.hasPlotAddress, relationode))
        g.add((relationode, RDF.type, add.LandmarkRelation))
        g.add((relationode, add.isLandmarkRelationType, lrtype.Undefined))
        g.add((relationode, add.locatum, subject_uri))
        for indexadd, rowadd in addresses.iterrows():
            if row['Lieu-dit_treated'] == rowadd['Lieu-dit_treated'] and row['registre'] == rowadd['registre']:
                g.add((relationode, add.relatum, URIRef(landmarkuri + str(rowadd['address_uuid']))))

    #Nature
    if not pd.isnull(row['Nature_treated']):
        nature = BNode()
        g.add((subject_uri, add.hasAttribute, nature))
        g.add((nature, RDF.type, add.Attribute))
        g.add((nature, add.isAttributeType, cad_atype.PlotNature))
        natures = row['Nature_treated'].split(',')
        for n in natures:
            natureversion = BNode()
            g.add((nature, add.hasAttributeVersion, natureversion))
            g.add((natureversion, RDF.type, add.AttributeVersion))
            g.add((natureversion, add.hasNature, URIRef(pnature + n)))

print(g.serialize(format='turtle'))
g.serialize(destination=f"{OUTPUT_FOLDER_PATH}/{COMMUNE}_landmarks_plot_mentions.ttl", format='turtle')
# Out:
# @prefix add: <http://rdf.geohistoricaldata.org/def/address#> .
# @prefix cad: <http://data.ign.fr/def/cadastre#> .
# @prefix cad_atype: <http://data.ign.fr/id/codes/cadastre/attributeType/> .
# @prefix cad_ltype: <http://data.ign.fr/id/codes/cadastre/landmarkType/> .
# @prefix cad_spval: <http://data.ign.fr/id/codes/cadastrenap/specialCellValue/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix landmark: <http://data.ign.fr/id/landmark/> .
# @prefix lrtype: <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/> .
# @prefix pnature: <http://data.ign.fr/id/codes/cadastre/plotNature/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
 a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:isMentionnedIn source:fb5aff88-b1e7-4fe1-91fc-daa663de2cc2_classement ;
#                     cad:passedTo cad_spval:AdditionConstructionSV,
#                         source:94_Gentilly_MAT_NB_1848_844 ;
#                     cad:takenFrom cad_spval:ConstructionNouvelleSV ;
#                     add:hasTime [ a add:TimeInterval ;
#                             add:hasBeginning [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1853-01-01T00:00:00"^^xsd:dateTimeStamp ] ;
#                             add:hasEnd [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1860-12-31T00:00:00"^^xsd:dateTimeStamp ] ] ] ;
#             add:isAttributeType cad_atype:PlotMention ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     add:hasNature pnature:Maison ] ;
#             add:isAttributeType cad_atype:PlotNature ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:hasPlotAddress [ a add:LandmarkRelation ;
#                             add:isLandmarkRelationType lrtype:Undefined ;
#                             add:locatum landmark:fb5aff88-b1e7-4fe1-91fc-daa663de2cc2 ;
#                             add:relatum landmark:7c5a1891-c80d-4859-84bf-f5985dce0196 ] ] ;
#             add:isAttributeType cad_atype:PlotAddress ] ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-18 (Gentilly)"^^xsd:string .
#
# landmark:fd32faa8-7d33-4601-83aa-1826e48a9fe1 a add:Landmark ;
#     rdfs:label "B-224 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "B-224"^^xsd:string ;
#     add:hasAttribute [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:isMentionnedIn source:fd32faa8-7d33-4601-83aa-1826e48a9fe1_classement ;
#                     cad:passedTo cad_spval:CelluleVideSV ;
#                     cad:takenFrom cad_spval:CelluleVideSV ;
#                     add:hasTime [ a add:TimeInterval ;
#                             add:hasEarliestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1836-01-01T00:00:00"^^xsd:dateTimeStamp ] ;
#                             add:hasLatestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1847-12-31T00:00:00"^^xsd:dateTimeStamp ] ] ] ;
#             add:isAttributeType cad_atype:PlotMention ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     add:hasNature pnature:Terre ] ;
#             add:isAttributeType cad_atype:PlotNature ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:hasPlotAddress [ a add:LandmarkRelation ;
#                             add:isLandmarkRelationType lrtype:Undefined ;
#                             add:locatum landmark:fd32faa8-7d33-4601-83aa-1826e48a9fe1 ;
#                             add:relatum landmark:82c828d1-52d8-4fc7-aef2-fdcc432612a3 ] ] ;
#             add:isAttributeType cad_atype:PlotAddress ] ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "B-224 (Gentilly)"^^xsd:string .
#
# landmark:fd91be0e-449a-4cab-8271-3facff0981ef a add:Landmark ;
#     rdfs:label "B-230 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "B-230"^^xsd:string ;
#     add:hasAttribute [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:hasPlotAddress [ a add:LandmarkRelation ;
#                             add:isLandmarkRelationType lrtype:Undefined ;
#                             add:locatum landmark:fd91be0e-449a-4cab-8271-3facff0981ef ;
#                             add:relatum landmark:4e6fe677-6afc-4f78-b6fb-622ceac06234 ] ] ;
#             add:isAttributeType cad_atype:PlotAddress ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:isMentionnedIn source:fd91be0e-449a-4cab-8271-3facff0981ef_classement ;
#                     cad:passedTo cad_spval:CelluleVideSV ;
#                     cad:takenFrom cad_spval:ConstructionNouvelleSV ;
#                     add:hasTime [ a add:TimeInterval ;
#                             add:hasBeginning [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1844-01-01T00:00:00"^^xsd:dateTimeStamp ] ;
#                             add:hasLatestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1847-12-31T00:00:00"^^xsd:dateTimeStamp ] ] ] ;
#             add:isAttributeType cad_atype:PlotMention ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     add:hasNature pnature:Maison ] ;
#             add:isAttributeType cad_atype:PlotNature ] ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "B-230 (Gentilly)"^^xsd:string .
#
# landmark:fdbbec58-a810-4328-8907-5e21a66e2ff6 a add:Landmark ;
#     rdfs:label "B-224 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "B-224"^^xsd:string ;
#     add:hasAttribute [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:isMentionnedIn source:fdbbec58-a810-4328-8907-5e21a66e2ff6_classement ;
#                     cad:passedTo cad_spval:AugmentationSV ;
#                     cad:takenFrom cad_spval:ConstructionNouvelleSV ;
#                     add:hasTime [ a add:TimeInterval ;
#                             add:hasBeginning [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1843-01-01T00:00:00"^^xsd:dateTimeStamp ] ;
#                             add:hasEnd [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1844-12-31T00:00:00"^^xsd:dateTimeStamp ] ] ] ;
#             add:isAttributeType cad_atype:PlotMention ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     add:hasNature pnature:Maison ] ;
#             add:isAttributeType cad_atype:PlotNature ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:hasPlotAddress [ a add:LandmarkRelation ;
#                             add:isLandmarkRelationType lrtype:Undefined ;
#                             add:locatum landmark:fdbbec58-a810-4328-8907-5e21a66e2ff6 ;
#                             add:relatum landmark:a37cd34c-5705-479e-a294-0db5f110c37e ] ] ;
#             add:isAttributeType cad_atype:PlotAddress ] ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "B-224 (Gentilly)"^^xsd:string .
#
# landmark:feafda70-c3b4-4b1a-bfbf-8482e304ed9c a add:Landmark ;
#     rdfs:label "D-34 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-34"^^xsd:string ;
#     add:hasAttribute [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     add:hasNature pnature:Maison ] ;
#             add:isAttributeType cad_atype:PlotNature ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:isMentionnedIn source:feafda70-c3b4-4b1a-bfbf-8482e304ed9c_classement ;
#                     cad:passedTo cad_spval:CelluleVideSV ;
#                     cad:takenFrom cad_spval:ConstructionNouvelleSV ;
#                     add:hasTime [ a add:TimeInterval ;
#                             add:hasBeginning [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1858-01-01T00:00:00"^^xsd:dateTimeStamp ] ;
#                             add:hasLatestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1860-12-31T00:00:00"^^xsd:dateTimeStamp ] ] ] ;
#             add:isAttributeType cad_atype:PlotMention ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:hasPlotAddress [ a add:LandmarkRelation ;
#                             add:isLandmarkRelationType lrtype:Undefined ;
#                             add:locatum landmark:feafda70-c3b4-4b1a-bfbf-8482e304ed9c ;
#                             add:relatum landmark:fc0e64dd-fd1d-4978-b501-3f0082d52f51 ] ] ;
#             add:isAttributeType cad_atype:PlotAddress ] ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-34 (Gentilly)"^^xsd:string .
#
# landmark:ff589dbe-8fb0-4e9c-a19d-895fc20271ce a add:Landmark ;
#     rdfs:label "D-76 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-76"^^xsd:string ;
#     add:hasAttribute [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     add:hasNature pnature:Maison ] ;
#             add:isAttributeType cad_atype:PlotNature ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:hasPlotAddress [ a add:LandmarkRelation ;
#                             add:isLandmarkRelationType lrtype:Undefined ;
#                             add:locatum landmark:ff589dbe-8fb0-4e9c-a19d-895fc20271ce ;
#                             add:relatum landmark:473cbe33-f954-4dc1-9c57-b449ec77d2dd ] ] ;
#             add:isAttributeType cad_atype:PlotAddress ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:isMentionnedIn source:ff589dbe-8fb0-4e9c-a19d-895fc20271ce_classement ;
#                     cad:passedTo cad_spval:CelluleVideSV ;
#                     cad:takenFrom cad_spval:ConstructionNouvelleSV ;
#                     add:hasTime [ a add:TimeInterval ;
#                             add:hasBeginning [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1859-01-01T00:00:00"^^xsd:dateTimeStamp ] ;
#                             add:hasLatestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1860-12-31T00:00:00"^^xsd:dateTimeStamp ] ] ] ;
#             add:isAttributeType cad_atype:PlotMention ] ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-76 (Gentilly)"^^xsd:string .
#
# landmark:ffa37e40-1eb4-465a-b778-c626fed700b3 a add:Landmark ;
#     rdfs:label "D-65 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-65"^^xsd:string ;
#     add:hasAttribute [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:hasPlotAddress [ a add:LandmarkRelation ;
#                             add:isLandmarkRelationType lrtype:Undefined ;
#                             add:locatum landmark:ffa37e40-1eb4-465a-b778-c626fed700b3 ;
#                             add:relatum landmark:211a6eff-5619-452a-84bb-5eaa5c572bca ] ] ;
#             add:isAttributeType cad_atype:PlotAddress ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     add:hasNature pnature:Jardin ] ;
#             add:isAttributeType cad_atype:PlotNature ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:isMentionnedIn source:ffa37e40-1eb4-465a-b778-c626fed700b3_classement ;
#                     cad:passedTo cad_spval:CelluleVideSV ;
#                     cad:takenFrom cad_spval:CelluleVideSV ;
#                     add:hasTime [ a add:TimeInterval ;
#                             add:hasEarliestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1848-01-01T00:00:00"^^xsd:dateTimeStamp ] ;
#                             add:hasLatestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1860-12-31T00:00:00"^^xsd:dateTimeStamp ] ] ] ;
#             add:isAttributeType cad_atype:PlotMention ] ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-65 (Gentilly)"^^xsd:string .
#
# landmark:ffb6bb8f-447f-4da8-b6c1-d9326fcc00bf a add:Landmark ;
#     rdfs:label "B-264 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "B-264"^^xsd:string ;
#     add:hasAttribute [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:hasPlotAddress [ a add:LandmarkRelation ;
#                             add:isLandmarkRelationType lrtype:Undefined ;
#                             add:locatum landmark:ffb6bb8f-447f-4da8-b6c1-d9326fcc00bf ;
#                             add:relatum landmark:82c828d1-52d8-4fc7-aef2-fdcc432612a3 ] ] ;
#             add:isAttributeType cad_atype:PlotAddress ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     cad:isMentionnedIn source:ffb6bb8f-447f-4da8-b6c1-d9326fcc00bf_classement ;
#                     cad:passedTo cad_spval:CelluleVideSV ;
#                     cad:takenFrom cad_spval:CelluleVideSV ;
#                     add:hasTime [ a add:TimeInterval ;
#                             add:hasEarliestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1836-01-01T00:00:00"^^xsd:dateTimeStamp ] ;
#                             add:hasLatestTimeInstant [ a add:TimeInstant ;
#                                     add:timeCalendar time:Gregorian ;
#                                     add:timePrecision time:Year ;
#                                     add:timeStamp "1847-12-31T00:00:00"^^xsd:dateTimeStamp ] ] ] ;
#             add:isAttributeType cad_atype:PlotMention ],
#         [ a add:Attribute ;
#             add:hasAttributeVersion [ a add:AttributeVersion ;
#                     add:hasNature pnature:Terre ] ;
#             add:isAttributeType cad_atype:PlotNature ] ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "B-264 (Gentilly)"^^xsd:string .
# <Graph identifier=N77096d5e954f4aaa8b5d0f21df316f19 (<class 'rdflib.graph.Graph'>)>
