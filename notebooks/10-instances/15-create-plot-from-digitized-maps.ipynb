# %%
import json 
import pandas as pd
import numpy as np
import uuid
import re
from rdflib import Graph, Literal, Namespace, RDF, URIRef, BNode
from rdflib.namespace import XSD, DCTERMS, PROV, SKOS, RDFS
from functions import *
from namespaces import *
from shapely.geometry import shape
from datetime import datetime

# %%
#import json files
ROOT = "C:/Users/stual/PycharmProjects/peuplement_ontology/ontologie-peuplement/"

with open(ROOT + 'data/gentilly/parcelles_1811.geojson') as f:
    data_1811 = json.load(f)

with open(ROOT + 'data/gentilly/parcelles_1848.geojson') as f:
    data_1845 = json.load(f)
COMMUNE = 'Gentilly'

# %%
NUM_DEPT = '94'
COMMUNE = 'Gentilly'
matrices_metada = {
    "MAT_1813": {
        "PLAN": "1811",
        "MATRICE_ID": "MAT_B_NB_1813",
        "MATRICE_START": "1813",
        "MATRICE_END": "1835"
    },
    "MAT_1836": {
        "PLAN": "1811",
        "MATRICE_ID": "MAT_NB_1836",
        "MATRICE_START": "1836",
        "MATRICE_END": "1847"
    },
    "MAT_1848": {
        "PLAN": "1845",
        "MATRICE_ID": "MAT_NB_1848",
        "MATRICE_START": "1848",
        "MATRICE_END": "1860"
    }
}

# %%
#Créer un objet Turtle avec une URI
g = Graph()

g.bind('landmark', landmarkuri)
g.bind('owner', owneruri)
g.bind('source', srcuri)
g.bind('change', changeuri)
g.bind('event',eventuri)
g.bind('cad_ltype', cad_ltype)
g.bind('cad_atype', cad_atype)
g.bind('pnature',pnature)
g.bind('ctype',ctype)
g.bind('atype',atype)

g.bind('cad', cad)
g.bind('add', add)
g.bind('rico', rico)
g.bind('fpo', fpo)
g.bind('time',time)

# %%
def get_base_Skos_Concept(str):
    if str == 'B':
        return 'ProprieteBatie'
    elif str == 'NB':
        return 'ProprieteNonBatie'
    elif str == 'B-NB' or str == 'NB-B':
        return 'ProprieteBatie;ProprieteNonBatie'
    
def geojson_to_wkt(geojson_geometry):
    shapely_geometry = shape(geojson_geometry)
    return shapely_geometry.wkt

# %%
geojsons = [data_1811, data_1845]
for i in range(len(geojsons)):
    if i == 0:
        CAD = '1811'
        BEGIN = '1811-01-01'
        END = '1847-12-31'
        LANDMARK_SECTION = "87d7c2f6-306b-45a1-a833-5e17821c3102"
    elif i == 1:
        CAD = '1845'
        BEGIN = '1845-01-01'
        END = '1859-12-31'
        LANDMARK_SECTION = 'da6a5c2c-e86d-43bb-8950-7169bd0df60a'

    for elem in geojsons[i]['features']:
        #Create Landmark of type Plot
        resource_uri = URIRef(landmarkuri + NUM_DEPT + '_' + COMMUNE + '_' +  CAD + '_' + elem['properties']['section'] + str(elem['properties']['numero']) + '_' + str(uuid.uuid4()))
        g.add((resource_uri, RDF.type, add.Landmark))
        g.add((resource_uri, add.isLandmarkType, cad_ltype.Plot))
        g.add((resource_uri, DCTERMS.identifier, Literal(elem['properties']['section'] + '-' + elem['properties']['numero'], datatype=XSD.string)))
        g.add((resource_uri, SKOS.prefLabel, Literal(elem['properties']['section'] + '-' + str(elem['properties']['numero']) + ' ('+ COMMUNE +')', datatype=XSD.string)))
        g.add((resource_uri, RDFS.label, Literal(elem['properties']['section'] + '-' + str(elem['properties']['numero']) + ' ('+ COMMUNE +')', datatype=XSD.string)))

        #Create Plot Landmark Relation : Plot <=> Section
        landmarkRelation = URIRef(BNode().n3())
        g.add((landmarkRelation, RDF.type, add.LandmarkRelation))
        g.add((landmarkRelation, add.locatum, resource_uri))
        g.add((landmarkRelation, add.relatum, URIRef(landmarkuri + LANDMARK_SECTION)))
        g.add((landmarkRelation, add.isLandmarkRelationType, lrtype.Within))

        #Landmark Appearance
        ## Change
        changeapp = URIRef(changeuri + str(uuid.uuid4()))
        g.add((changeapp, RDF.type, add.Change))
        g.add((changeapp,add.appliedTo,resource_uri))
        g.add((changeapp,add.isChangeType,ctype.LandmarkAppearance))
        
        ## Event
        eventapp = URIRef(eventuri + str(uuid.uuid4()))
        g.add((eventapp, RDF.type, add.Event))
        g.add((changeapp,add.dependsOn,eventapp))
        time_ = BNode()
        g.add((eventapp, add.hasTime, URIRef(time_.n3())))
        g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        g.add((URIRef(time_.n3()), add.timeCalendar,time.Gregorian))
        g.add((URIRef(time_.n3()), add.timePrecision,time.Year))
        g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(BEGIN, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        #Landmark Disappearance (NOT USED)
        ## Change
        #changedis = URIRef(changeuri + str(uuid.uuid4()))
        #g.add((changedis, RDF.type, add.Change))
        #g.add((changedis,add.appliedTo,resource_uri))
        #g.add((changedis,add.isChangeType,ctype.LandmarkDisappearance))
        
        ## Event
        #eventdis= URIRef(eventuri + str(uuid.uuid4()))
        #g.add((eventdis, RDF.type, add.Event))
        #g.add((changedis,add.dependsOn,eventdis))
        #time_ = BNode()
        #g.add((eventdis, add.hasLatestTimeInstant, URIRef(time_.n3())))
        #g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        #g.add((URIRef(time_.n3()), add.timeCalendar,time.Gregorian))
        #g.add((URIRef(time_.n3()), add.timePrecision,time.Year))
        #g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(END, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        # Plot Nature
        ## Version
        natureattr = BNode()
        g.add((URIRef(natureattr.n3()),RDF.type,add.Attribute))
        g.add((resource_uri, add.hasAttribute, URIRef(natureattr.n3())))
        g.add((URIRef(natureattr.n3()), add.isAttributeType, cad_atype.PlotNature))
        natureattrversion = BNode()
        g.add((URIRef(natureattr.n3()), add.hasAttributeVersion,URIRef(natureattrversion.n3())))
        g.add((URIRef(natureattrversion.n3()),RDF.type,add.AttributeVersion))
        nature = get_base_Skos_Concept(elem['properties']['nature'])
        if ';' in nature:
            for n in nature.split(';'):
                g.add((URIRef(natureattrversion.n3()),cad.hasPlotNature,URIRef(pnature+n)))
        else:
            g.add((URIRef(natureattrversion.n3()),cad.hasPlotNature,URIRef(pnature+nature)))
        
        ## Plot Nature Appearance
        ### Change
        changenatapp = URIRef(changeuri + str(uuid.uuid4()))
        g.add((changenatapp, RDF.type, add.Change))
        g.add((changenatapp, add.isChangeType, ctype.AttributeVersionAppearance))
        g.add((changenatapp,add.appliedTo,URIRef(natureattr.n3())))
        g.add((changenatapp,add.makesEffective,URIRef(natureattrversion.n3())))
        ### Event
        eventnatapp = URIRef(eventuri + str(uuid.uuid4()))
        g.add((eventnatapp, RDF.type, add.Event))
        g.add((changenatapp,add.dependsOn,eventnatapp))
        time_ = BNode()
        g.add((eventnatapp, add.hasTime, URIRef(time_.n3())))
        g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        g.add((URIRef(time_.n3()), add.timeCalendar,time.Gregorian))
        g.add((URIRef(time_.n3()), add.timePrecision,time.Year))
        g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(BEGIN, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        ## Plot Nature Disappearance
        ### Change
        #changenatdis = URIRef(changeuri + str(uuid.uuid4()))
        #g.add((changenatdis, RDF.type, add.Change))
        #g.add((changenatdis,add.appliedTo,URIRef(natureattr.n3())))
        #g.add((changenatdis,add.outdates,URIRef(natureattrversion.n3())))
        ### Event
        #eventnatdis = URIRef(eventuri + str(uuid.uuid4()))
        #g.add((eventnatdis, RDF.type, add.Event))
        #g.add((changenatdis,add.dependsOn,eventnatdis))
        #time_ = BNode()
        #g.add((eventnatdis, add.hasLatestTimeInstant, URIRef(time_.n3())))
        #g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        #g.add((URIRef(time_.n3()), add.timeCalendar,time.Gregorian))
        #g.add((URIRef(time_.n3()), add.timePrecision,time.Year))
        #g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(END, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        #Plot Geometry
        geom = BNode()
        g.add((URIRef(geom.n3()), RDF.type, add.Attribute))
        g.add((URIRef(geom.n3()), add.isAttributeType, atype.Geometry))
        g.add((resource_uri, add.hasAttribute, URIRef(geom.n3())))
        geomversion = BNode()
        g.add((URIRef(geom.n3()), add.hasAttributeVersion, URIRef(geomversion.n3())))
        g.add((URIRef(geomversion.n3()), RDF.type, add.AttributeVersion))
        g.add((URIRef(geomversion.n3()), add.versionValue, Literal("<http://www.opengis.net/def/crs/EPSG/0/2154>" + geojson_to_wkt(elem['geometry']), datatype=geo.wktLiteral)))
        g.add((URIRef(geomversion.n3()), PROV.wasGeneratedBy, URIRef(activity + "0006")))

        ## Plot Geometry Appearance
        ### Change
        changegeomapp = URIRef(changeuri + str(uuid.uuid4()))
        g.add((changegeomapp, RDF.type, add.Change))
        g.add((changegeomapp, add.isChangeType, ctype.AttributeVersionAppearance))
        g.add((changegeomapp, add.appliedTo, URIRef(geom.n3())))
        g.add((changegeomapp, add.makesEffective, URIRef(geomversion.n3())))
        ### Event
        eventgeomapp = URIRef(eventuri + str(uuid.uuid4()))
        g.add((eventgeomapp, RDF.type, add.Event))
        g.add((changegeomapp, add.dependsOn, eventgeomapp))
        time_ = BNode()
        g.add((eventgeomapp, add.hasTime, URIRef(time_.n3())))
        g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        g.add((URIRef(time_.n3()), add.timeCalendar, time.Gregorian))
        g.add((URIRef(time_.n3()), add.timePrecision, time.Year))
        g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(BEGIN, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        ## Plot Geometry Disappearance
        ### Change
        #changegeomdis = URIRef(changeuri + str(uuid.uuid4()))
        #g.add((changegeomdis, RDF.type, add.Change))
        #g.add((changegeomdis, add.appliedTo, URIRef(geom.n3())))
        #g.add((changegeomdis, add.outdates, URIRef(geomversion.n3())))
        ### Event
        #eventgeomdis = URIRef(eventuri + str(uuid.uuid4()))
        #g.add((eventgeomdis, RDF.type, add.Event))
        #g.add((changegeomdis, add.dependsOn, eventgeomdis))
        #time_ = BNode()
        #g.add((eventgeomdis, add.hasLatestTimeInstant, URIRef(time_.n3())))
        #g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        #g.add((URIRef(time_.n3()), add.timeCalendar, time.Gregorian))
        #g.add((URIRef(time_.n3()), add.timePrecision, time.Year))
        #g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(END, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

print(g.serialize(format='turtle'))
g.serialize(destination=f"{ROOT}data/rdf/{COMMUNE}_landmarks_initial_plots.ttl", format='turtle')
# Out:
# @prefix add: <http://rdf.geohistoricaldata.org/def/address#> .
# @prefix atype: <http://rdf.geohistoricaldata.org/id/codes/address/attributeType/> .
# @prefix cad: <http://rdf.geohistoricaldata.org/def/cadastre#> .
# @prefix cad_atype: <http://rdf.geohistoricaldata.org/id/codes/cadastre/attributeType/> .
# @prefix cad_ltype: <http://rdf.geohistoricaldata.org/id/codes/cadastre/landmarkType/> .
# @prefix change: <http://rdf.geohistoricaldata.org/id/change/> .
# @prefix ctype: <http://rdf.geohistoricaldata.org/id/codes/address/changeType/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix event: <http://rdf.geohistoricaldata.org/id/event/> .
# @prefix geo: <http://www.opengis.net/ont/geosparql#> .
# @prefix landmark: <http://rdf.geohistoricaldata.org/id/landmark/> .
# @prefix pnature: <http://rdf.geohistoricaldata.org/id/codes/cadastre/plotNature/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix time: <http://www.w3.org/2006/time#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <_:N03b5f17d32814e3bb240f73de7bb144a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D410bis_8141b594-cbe9-451b-a1e5-6c657e7dd270 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N0569e14ed740427e815ed9346269d1dd> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D81_390a9405-6c23-46ba-a52a-b2f1bf1ba5b9 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N056aaa49f5a440268762934fda353f5e> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D87_6bce4bea-64fe-40d5-b1bb-27345e6ee96b ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N05d45657334a428f9f33baa0cc1dd827> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D54_2f889c02-8de2-442b-b15c-e51dce2634bf ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N0726d49f72b6482c9b67bb038974fcf7> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D423_7b6cad47-f86a-4176-9362-2b7bfe5121c2 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N0761590271c94cf0b3ae2b085918403f> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D16_f6c13c83-edf5-4585-865c-3c6c9042e7e4 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N097c23a29b1b4ac9a8af20d661ef45b5> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B263_c6f9eda5-129a-4d31-8d59-1417ae254ae0 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:N0a167a73177741298da0b46c8c2211c1> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D421_27881f8f-d543-4b82-ac6c-7b3275738407 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N0bc136ce8b2c481682f3f460e993f57c> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D70_3d7b37cd-0cc0-4ffc-9516-82ee7204f8a8 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N113ddb710e4643bcbe511e350eec62b7> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D425_cd8aaaf1-b13d-4b5d-b325-942917917608 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N11a50b7415124cf9b56850ff93c8f76b> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D78_470beab0-38c0-4d7c-9cec-94b9287cd115 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N13622ee18e314c0ab543efbeb9bf0e8f> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D82_968f74e6-eb47-48f6-9f2f-828fbe7e4416 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:
a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D410_63254ac9-f2e2-4e6f-b68a-6e3d7bb8ca7f ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nf565f23b9a714619982efa95344f8a8e> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D429_4688818b-9b95-47a5-aa21-f3e15cda2b2c ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nf62a0d3cd2464b468ccd352f3d6a2a8a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D414_fd9bcd58-5df8-4c50-8358-4afc51189c8a ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nfc79a40eca814c0999750ad361551d69> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D411_1077cb16-be55-46e6-a15b-6feafd4f4049 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nfee5dbe1f589498f86d1389d303f9921> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D53_9bf0c869-d960-4996-ae54-09411a99aa6f ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# change:0142bff8-1277-436b-99c4-26c15751da9c a add:Change ;
#     add:appliedTo <_:N5253cfd4c61e459a892996822c460b98> ;
#     add:dependsOn event:4ffad648-9736-4ff1-8634-388061c69837 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:N237faec09bbd42cf9ea61ba6ece16079> .
#
# change:019517b4-6b21-4908-b84a-3e528068e459 a add:Change ;
#     add:appliedTo <_:Nf87002b7be9a41c18c721545b8186277> ;
#     add:dependsOn event:67bc3d06-f288-4360-98e4-7fa99f2a9987 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:N335d2cc447f046c9aff22829da45cd13> .
#
# change:01dbf5a4-52ac-4a7b-90f3-b7200d21680f a add:Change ;
#     add:appliedTo <_:Na0179d1646e1463a9bbd49fcecb90884> ;
#     add:dependsOn event:a156a138-b984-40c9-b8c9-19b1e6de1c08 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:Ne121957a4eea4ed6b01d349b1e1c8989> .
#
# change:022c9a3b-c361-46c5-9020-cfb19548d817 a add:Change ;
#     add:appliedTo <_:Nc96f69cf8a144f289ca14ca4ffd8767a> ;
#     add:dependsOn event:5531bac2-c136-4e7f-a8c2-9d1268b20172 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:Ndc9898064e234cbbbe1bd5bc9d2e9c90> .
#
# change:02a85a49-6502-4657-8232-9ab46793f86e a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1845_D24_d94002ba-8c09-49dd-b7f1-738c36fb4af9 ;
#     add:dependsOn event:f9a4ee21-37e8-45bb-8e03-e18e3011ee71 ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:03045f6e-82b6-48b7-bc9c-0367db62f09a a add:Change ;
#     add:appliedTo <_:Ne45730b2991742c584bb67dd3e80e1f1> ;
#     add:dependsOn event:f7d05dee-797d-4c2b-8195-e32cb20820a4 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:Nf162af688c6c419e86b42bff44e1f520> .
#
# change:0359fea1-2a45-4574-bfa3-4de9cf6f1f6d a add:Change ;
#     add:appliedTo <_:Nde29ee2e46f04a4889e7865a43aa0991> ;
#     add:dependsOn event:c07ad59f-8fe1-42e3-a573-631417d07242 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:N0e339c7638cf460bbfcafba8552effd2> .
#
# change:040e6828-0038-4992-88c0-59544beb3ba1 a add:Change ;
#     add:appliedTo <_:N3a33e0bbcdea4b2e85b7b1b2fdf88809> ;
#     add:dependsOn event:a6b5a68f-4f89-43bf-a20f-cb38ee781c9b ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:N20d78e8c9fcc4919af76c2393711b1de> .
#
# change:045912c5-f1a4-4109-8870-24bbe2e85ee3 a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1845_D38_6e4e0ccf-3da6-4c7e-847a-f0ce258e3baa ;
#     add:dependsOn event:ac58e5f6-3b03-4146-8181-f1788d6ba548 ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:05e6fb6a-c54c-4320-a7fa-f42815d5a556 a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1845_D22_067611f2-0707-4551-b9a6-c9b1c429f591 ;
#     add:dependsOn event:d0e46da2-0ccb-4ad7-b40a-a8f685c8593b ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:0698b7bc-14ad-4246-acc0-31098323e8ec a add:Change ;
#     add:appliedTo <_:Ndf86ebb9673844bda9729d7ad2f51d9e> ;
#     add:dependsOn event:67c4a23d-5525-451f-a1e1-9115bf08dade ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:N3e0e15a158cb49eba885da698afb5da7> .
#
# change:08e03a8e-1bad-4b42-a587-dca03265a4f0 a add:Change ;
#     add:appliedTo <_:N8fd8eeef268143e7b8a23287b9c80e35> ;
#     add:dependsOn event:dbfef832-d822-4dbf-b745-1e4c38a66d8b ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:N1df0c859b06f4a3aa768c588a8908420> .
#
# ...
#         <_:Nd816962f1fe84aedb59f1a4c5fce8171> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-57 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D58_dc237590-702d-4dd1-95a1-785e577f919e a add:Landmark ;
#     rdfs:label "D-58 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-58"^^xsd:string ;
#     add:hasAttribute <_:N8434ad527159459cb9aab72fdf219b2d>,
#         <_:Nc4835ce891214c8080c6ce1488f92267> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-58 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D59_6678bd1c-a054-4994-be22-d593a2441598 a add:Landmark ;
#     rdfs:label "D-59 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-59"^^xsd:string ;
#     add:hasAttribute <_:N978c5273467347eba0de50c68125d16b>,
#         <_:Nea2eb3cd4c484d6a981f20e675b74ded> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-59 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D5_83c4b23e-b18a-4b3c-a351-1d346e5a9803 a add:Landmark ;
#     rdfs:label "D-5 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-5"^^xsd:string ;
#     add:hasAttribute <_:N9234897186f94c298c9a94cd2b2e14d6>,
#         <_:Na8114d48246140fea5628ce3a1880f96> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-5 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D5bis_7bf933e3-7756-41d3-bcbb-1c235b3af46f a add:Landmark ;
#     rdfs:label "D-5bis (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-5bis"^^xsd:string ;
#     add:hasAttribute <_:N309e1f5c88eb4778b524e8193cc25b12>,
#         <_:N5253cfd4c61e459a892996822c460b98> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-5bis (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D60_0aa74720-a97a-496f-a3e6-b476d1192617 a add:Landmark ;
#     rdfs:label "D-60 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-60"^^xsd:string ;
#     add:hasAttribute <_:N058ed23b66b14088a95e0922bff7ea11>,
#         <_:Nf2c0d4e4fa934196af36c07905ed119f> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-60 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D61_e37a6774-3e2e-45f1-ae14-3ea0be028dae a add:Landmark ;
#     rdfs:label "D-61 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-61"^^xsd:string ;
#     add:hasAttribute <_:N0e0b0e40ac0646a095c8bf773f4eca34>,
#         <_:N50ab55ed8a9940dfbf52ae9864d49c7f> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-61 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D63_3ba8ae42-e094-4546-a2e8-735fe22d0a80 a add:Landmark ;
#     rdfs:label "D-63 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-63"^^xsd:string ;
#     add:hasAttribute <_:N230e3e23171344cd9c091bc95cf829b3>,
#         <_:N3289962f30e5406d9bf2e2192c71b893> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-63 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D64_170efedb-c9c4-4154-85ec-415224666cdc a add:Landmark ;
#     rdfs:label "D-64 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-64"^^xsd:string ;
#     add:hasAttribute <_:N14ea9760ea9448f5813565f288633fac>,
#         <_:Nf3860f9b70f4473894b5f7cb0f0afa01> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-64 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D65_ca824e7c-3089-494d-ae1c-1d688457b68a a add:Landmark ;
#     rdfs:label "D-65 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-65"^^xsd:string ;
#     add:hasAttribute <_:N47d52591ad6e49e89a78265ef9a9dfa1>,
#         <_:Nf5e1fd1c996b42789c396956a2ed6085> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-65 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D66_9996dc1e-5329-4156-94b5-1b11a9310dee a add:Landmark ;
#     rdfs:label "D-66 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-66"^^xsd:string ;
#     add:hasAttribute <_:Nb3fb8a142e4642589c466e313445cb9d>,
#         <_:Nfec287a99bd5439dbd07b78c1eabeb25> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-66 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D67_196f9204-6874-4de7-9ba2-ab151c72a299 a add:Landmark ;
#     rdfs:label "D-67 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-67"^^xsd:string ;
#     add:hasAttribute <_:N94f697c2f7334490851baf75dec1d361>,
#         <_:Ndcdf3b1e744d43e0b455bb1c11c545df> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-67 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D68_8fa9d44e-3b9d-4169-9c9e-e68d96110978 a add:Landmark ;
#     rdfs:label "D-68 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-68"^^xsd:string ;
#     add:hasAttribute <_:N350be59e252f42e4834df9f6a0b8ddc7>,
#         <_:N65418457e963469792acb901076b6b77> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-68 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D69_31f3d990-3a8a-439e-bb77-3b2ec6d023cc a add:Landmark ;
#     rdfs:label "D-69 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-69"^^xsd:string ;
#     add:hasAttribute <_:N725282ea8c6442cfa185abe8e57b38b9>,
#         <_:Nc122f11ffd7540b4b899974d436c7681> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-69 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D6_0e50f5e1-a8c7-415f-8fd3-60eb2ebc3f26 a add:Landmark ;
#     rdfs:label "D-6 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-6"^^xsd:string ;
#     add:hasAttribute <_:Nad36983f6f0a44a883280e002e0c3d95>,
#         <_:Nc0afcace2d954ffabf3fa2ed18db1c87> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-6 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D70_3d7b37cd-0cc0-4ffc-9516-82ee7204f8a8 a add:Landmark ;
#     rdfs:label "D-70 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-70"^^xsd:string ;
#     add:hasAttribute <_:N688150a533aa41568bb1b527878de509>,
#         <_:N72ca14fa7f834101b42fb3a94f01b07a> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-70 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D71_c53431ec-0eda-47f5-bda4-abc141d2bc7f a add:Landmark ;
#     rdfs:label "D-71 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-71"^^xsd:string ;
#     add:hasAttribute <_:N0d91948f715346f3bf60d6340fbdde36>,
#         <_:N92d30628623c4a0e94bb3849c7e5eed9> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-71 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D72_c63a455a-e700-4b36-a5e4-e794c48b9ff4 a add:Landmark ;
#     rdfs:label "D-72 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-72"^^xsd:string ;
#     add:hasAttribute <_:Nc3541f44bf324b20a941da8dd012e0cc>,
#         <_:Nc4f9ef39031142d38617e10814cef8c3> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-72 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D73_dc6ad4ed-4646-4ac5-a56f-d35ad52a043f a add:Landmark ;
#     rdfs:label "D-73 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-73"^^xsd:string ;
#     add:hasAttribute <_:N6635d377b97d48a8bb575635a178d0fb>,
#         <_:N75021a7b597e4851b3b9f70b3f9550a9> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-73 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D74_818bea7c-a6ee-4096-8cea-907879ae360f a add:Landmark ;
#     rdfs:label "D-74 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-74"^^xsd:string ;
#     add:hasAttribute <_:N3d62a486fb1f442fa8bb8f3f19d94705>,
#         <_:Ne5b97c72153a49a7b90e7d39dbec8f5f> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-74 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D75_033242f7-c9b6-455c-9eb8-2286e43d7b2b a add:Landmark ;
#     rdfs:label "D-75 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-75"^^xsd:string ;
#     add:hasAttribute <_:N8898dc4ee79b4f1eb96bea868247feac>,
#         <_:Nccde7dd437714531b458f477416773e6> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-75 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D76_09052c38-2d25-4d94-a08b-776b6fce2961 a add:Landmark ;
#     rdfs:label "D-76 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-76"^^xsd:string ;
#     add:hasAttribute <_:N12c5c15f52e24600bc6bfa3afa4d20fa>,
#         <_:N1c67c35b78ef4ba7af4f5f392528665c> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-76 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D77_a82f6448-105e-43fb-a843-2e031ac58770 a add:Landmark ;
#     rdfs:label "D-77 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-77"^^xsd:string ;
#     add:hasAttribute <_:Ncee8b745570b4b759e050b78d0302182>,
#         <_:Nf165c1d4c56d44169898ebe200d99c3e> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-77 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D78_470beab0-38c0-4d7c-9cec-94b9287cd115 a add:Landmark ;
#     rdfs:label "D-78 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-78"^^xsd:string ;
#     add:hasAttribute <_:N272142148d7b43748fb7218642ad65d5>,
#         <_:N3051271377514a51b4eb45ee040cf421> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-78 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D79_5c6bf713-8b20-4581-97b8-4fc020cf3298 a add:Landmark ;
#     rdfs:label "D-79 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-79"^^xsd:string ;
#     add:hasAttribute <_:N8edc190307894e66bd97f0ebb190e126>,
#         <_:Nd742bd70072947f08ece25fff2e208f1> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-79 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D80_c29dbf06-1ff8-4bcf-a3dd-a12bd2407b6c a add:Landmark ;
#     rdfs:label "D-80 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-80"^^xsd:string ;
#     add:hasAttribute <_:N3c1f6cff3f144097a8e667a395221643>,
#         <_:Nc2c3a7c30dc74a158c49955ce757c1bd> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-80 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D81_390a9405-6c23-46ba-a52a-b2f1bf1ba5b9 a add:Landmark ;
#     rdfs:label "D-81 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-81"^^xsd:string ;
#     add:hasAttribute <_:N14b4cb606fb14041a4311dc31c6cf5c2>,
#         <_:N4c519df907c245bc8132ddd66d20ba32> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-81 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D82_968f74e6-eb47-48f6-9f2f-828fbe7e4416 a add:Landmark ;
#     rdfs:label "D-82 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-82"^^xsd:string ;
#     add:hasAttribute <_:Na876b254a2b94805a0474826b3b39840>,
#         <_:Ne3ca8fbdba10425ba0d3d348810df4a6> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-82 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D83_43bfaf30-efc7-443a-9800-770b5d008d19 a add:Landmark ;
#     rdfs:label "D-83 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-83"^^xsd:string ;
#     add:hasAttribute <_:N703f3b675c0c44d1b426711aa94e01f7>,
#         <_:Nae193a4d854844f5bb29851ee8d9a227> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-83 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D84_d2888db5-046e-42e3-ad0a-db6888e0e100 a add:Landmark ;
#     rdfs:label "D-84 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-84"^^xsd:string ;
#     add:hasAttribute <_:N084dc5c6901e4a3aa32b4a3c356b1b9f>,
#         <_:N1f745e2f1140442ea0685eed5a743948> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-84 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D85_821cf872-40d9-4251-b671-8965e8a3302a a add:Landmark ;
#     rdfs:label "D-85 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-85"^^xsd:string ;
#     add:hasAttribute <_:Na3df052e83ca4793b804cb6db260cee8>,
#         <_:Nc1ce2ac54e8e4a52886ebdf020063cbf> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-85 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D86_d2c080b9-f5d0-41d7-a515-00ca76ce9ba5 a add:Landmark ;
#     rdfs:label "D-86 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-86"^^xsd:string ;
#     add:hasAttribute <_:N3712cf92e4fa450ea9ae4b823193dcd5>,
#         <_:Ndafdcad70e734deba49c66bd8bb158a8> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-86 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D87_6bce4bea-64fe-40d5-b1bb-27345e6ee96b a add:Landmark ;
#     rdfs:label "D-87 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-87"^^xsd:string ;
#     add:hasAttribute <_:N9320b6d8711547778423fd0ddd2bcff7>,
#         <_:Na9f8aeb1b8cd47c9abd45740d3f14fb0> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-87 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D88_2fa33494-e596-4fcd-b92d-af9da68f423f a add:Landmark ;
#     rdfs:label "D-88 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-88"^^xsd:string ;
#     add:hasAttribute <_:N5aad17054e814dc1aefb8f5f4feba24c>,
#         <_:Nf2d27afb16bf4586b3a6a3024754065d> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-88 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D89_686f20cb-d046-4755-b545-b1bff881046e a add:Landmark ;
#     rdfs:label "D-89 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-89"^^xsd:string ;
#     add:hasAttribute <_:N56362283a86441eebed9fc9c5323b841>,
#         <_:Ne4bf647a4412439b9cba385fd4346f56> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-89 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D8_04078436-e72f-475c-beae-5abd71b442d8 a add:Landmark ;
#     rdfs:label "D-8 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-8"^^xsd:string ;
#     add:hasAttribute <_:N4f6d8566c84447cfbe264fa1bff3fd5e>,
#         <_:Nd6f35a7394704a53ad3ebd101a49fa79> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-8 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D90_d7bab380-955c-48a4-9a9a-e431a3f92cb2 a add:Landmark ;
#     rdfs:label "D-90 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-90"^^xsd:string ;
#     add:hasAttribute <_:N76526ec9af864b69987f38ee057c1c11>,
#         <_:N859cec52de334742afe7bc89b259f6eb> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-90 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D91_c030444c-9f4f-438f-9576-3d0b53a6120e a add:Landmark ;
#     rdfs:label "D-91 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-91"^^xsd:string ;
#     add:hasAttribute <_:N5877eabac2364769ac290afefbd701b5>,
#         <_:Ndebc5a44e1f84ce8b07413c1a3d8e466> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-91 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D92_40ea8c55-7575-467f-8d2a-1f462b5fdb8d a add:Landmark ;
#     rdfs:label "D-92 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-92"^^xsd:string ;
#     add:hasAttribute <_:N2bae5c306ca447e2bc80e22ed9ae5edd>,
#         <_:Na0ca6dd0dcdb496ab7031fe64e7031b2> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-92 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D93_442695db-de67-4264-8385-bb01d71e79f6 a add:Landmark ;
#     rdfs:label "D-93 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-93"^^xsd:string ;
#     add:hasAttribute <_:N07d466454c7c453b92f774af356b13ac>,
#         <_:Nc3f8e92e1a8f49fb8789af202278433f> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-93 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D94_e24276d0-5066-43c4-8779-ec7c0b79b36c a add:Landmark ;
#     rdfs:label "D-94 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-94"^^xsd:string ;
#     add:hasAttribute <_:Nf0e3f4229f0846d595363a99496425bb>,
#         <_:Nfc9916c4c56a41d291def80837639e8d> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-94 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D95_0628cb53-e599-4b66-811f-6b8a658a66ce a add:Landmark ;
#     rdfs:label "D-95 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-95"^^xsd:string ;
#     add:hasAttribute <_:N0f840518f9564d3ba7826d40d4cd2ccf>,
#         <_:Na494ab24596f409eba372237b071f39f> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-95 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D9_74002381-06eb-466e-99c6-9fd5449debc0 a add:Landmark ;
#     rdfs:label "D-9 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-9"^^xsd:string ;
#     add:hasAttribute <_:N036668d7578d4de3964db20fac9ee294>,
#         <_:N3cd9433a4f8540559af8deb299a8857f> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-9 (Gentilly)"^^xsd:string .
# <Graph identifier=Na3624962273b4759a2ddf4b8970c443c (<class 'rdflib.graph.Graph'>)>
