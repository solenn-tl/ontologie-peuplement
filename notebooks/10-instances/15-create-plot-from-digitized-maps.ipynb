# %%
import json 
import pandas as pd
import numpy as np
import uuid
import re
from rdflib import Graph, Literal, Namespace, RDF, URIRef, BNode
from rdflib.namespace import XSD, DCTERMS, PROV, SKOS, RDFS
from functions import *
from namespaces import *
from shapely.geometry import shape
from datetime import datetime

# %%
#import json files
ROOT = "C:/Users/stual/PycharmProjects/peuplement_ontology/ontologie-peuplement/"

with open(ROOT + 'data/gentilly/parcelles_1811.geojson') as f:
    data_1811 = json.load(f)

with open(ROOT + 'data/gentilly/parcelles_1848.geojson') as f:
    data_1845 = json.load(f)
COMMUNE = 'Gentilly'

# %%
NUM_DEPT = '94'
COMMUNE = 'Gentilly'
matrices_metada = {
    "MAT_1813": {
        "PLAN": "1811",
        "MATRICE_ID": "MAT_B_NB_1813",
        "MATRICE_START": "1813",
        "MATRICE_END": "1836", #20 septembre 1836
        "MATRICE_START_DAY": "-01-01",
        "MATRICE_END_DAY": "-09-20",
    },
    "MAT_1836": {
        "PLAN": "1811",
        "MATRICE_ID": "MAT_NB_1836",
        "MATRICE_START": "1836",#21 septembre 1836
        "MATRICE_END": "1848",
        "MATRICE_START_DAY": "-09-21",
        "MATRICE_END_DAY": "-03-31",
    },
    "MAT_1848": {
        "PLAN": "1845",
        "MATRICE_ID": "MAT_NB_1848",
        "MATRICE_START": "1848",#1er avril 1848
        "MATRICE_END": "1860",
        "MATRICE_START_DAY": "-04-01",
        "MATRICE_END_DAY": "-12-31"
    }
}

# %%
#Créer un objet Turtle avec une URI
g = Graph()

g.bind('landmark', landmarkuri)
g.bind('owner', owneruri)
g.bind('source', srcuri)
g.bind('change', changeuri)
g.bind('event',eventuri)
g.bind('cad_ltype', cad_ltype)
g.bind('cad_atype', cad_atype)
g.bind('pnature',pnature)
g.bind('ctype',ctype)
g.bind('atype',atype)

g.bind('cad', cad)
g.bind('add', add)
g.bind('rico', rico)
g.bind('fpo', fpo)
g.bind('time',time)

# %%
def get_base_Skos_Concept(str):
    if str == 'B':
        return 'ProprieteBatie'
    elif str == 'NB':
        return 'ProprieteNonBatie'
    elif str == 'B-NB' or str == 'NB-B':
        return 'ProprieteBatie;ProprieteNonBatie'
    
def geojson_to_wkt(geojson_geometry):
    shapely_geometry = shape(geojson_geometry)
    return shapely_geometry.wkt

# %%
geojsons = [data_1811, data_1845]
for i in range(len(geojsons)):
    if i == 0:
        CAD = '1811'
        BEGIN = '1811-01-01'
        END = '1848-03-31'
        LANDMARK_SECTION = "87d7c2f6-306b-45a1-a833-5e17821c3102"
    elif i == 1:
        CAD = '1845'
        BEGIN = '1845-01-01'
        END = '1860-12-31'
        LANDMARK_SECTION = 'da6a5c2c-e86d-43bb-8950-7169bd0df60a'

    for elem in geojsons[i]['features']:
        #Create Landmark of type Plot
        resource_uri = URIRef(landmarkuri + NUM_DEPT + '_' + COMMUNE + '_' +  CAD + '_' + elem['properties']['section'] + str(elem['properties']['numero']) + '_' + str(uuid.uuid4()))
        g.add((resource_uri, RDF.type, add.Landmark))
        g.add((resource_uri, add.isLandmarkType, cad_ltype.Plot))
        g.add((resource_uri, DCTERMS.identifier, Literal(elem['properties']['section'] + '-' + elem['properties']['numero'], datatype=XSD.string)))
        g.add((resource_uri, SKOS.prefLabel, Literal(elem['properties']['section'] + '-' + str(elem['properties']['numero']) + ' ('+ COMMUNE +')', datatype=XSD.string)))
        g.add((resource_uri, RDFS.label, Literal(elem['properties']['section'] + '-' + str(elem['properties']['numero']) + ' ('+ COMMUNE +')', datatype=XSD.string)))

        #Create Plot Landmark Relation : Plot <=> Section
        landmarkRelation = URIRef(BNode().n3())
        g.add((landmarkRelation, RDF.type, add.LandmarkRelation))
        g.add((landmarkRelation, add.locatum, resource_uri))
        g.add((landmarkRelation, add.relatum, URIRef(landmarkuri + LANDMARK_SECTION)))
        g.add((landmarkRelation, add.isLandmarkRelationType, lrtype.Within))

        #Landmark Appearance
        ## Change
        changeapp = URIRef(changeuri + str(uuid.uuid4()))
        g.add((changeapp, RDF.type, add.Change))
        g.add((changeapp,add.appliedTo,resource_uri))
        g.add((changeapp,add.isChangeType,ctype.LandmarkAppearance))
        
        ## Event
        eventapp = URIRef(eventuri + str(uuid.uuid4()))
        g.add((eventapp, RDF.type, add.Event))
        g.add((changeapp,add.dependsOn,eventapp))
        time_ = BNode()
        g.add((eventapp, add.hasTime, URIRef(time_.n3())))
        g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        g.add((URIRef(time_.n3()), add.timeCalendar,time.Gregorian))
        g.add((URIRef(time_.n3()), add.timePrecision,time.Year))
        g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(BEGIN, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        #Landmark Disappearance (NOT USED)
        ## Change
        #changedis = URIRef(changeuri + str(uuid.uuid4()))
        #g.add((changedis, RDF.type, add.Change))
        #g.add((changedis,add.appliedTo,resource_uri))
        #g.add((changedis,add.isChangeType,ctype.LandmarkDisappearance))
        
        ## Event
        #eventdis= URIRef(eventuri + str(uuid.uuid4()))
        #g.add((eventdis, RDF.type, add.Event))
        #g.add((changedis,add.dependsOn,eventdis))
        #time_ = BNode()
        #g.add((eventdis, add.hasLatestTimeInstant, URIRef(time_.n3())))
        #g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        #g.add((URIRef(time_.n3()), add.timeCalendar,time.Gregorian))
        #g.add((URIRef(time_.n3()), add.timePrecision,time.Year))
        #g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(END, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        # Plot Nature
        ## Version
        natureattr = BNode()
        g.add((URIRef(natureattr.n3()),RDF.type,add.Attribute))
        g.add((resource_uri, add.hasAttribute, URIRef(natureattr.n3())))
        g.add((URIRef(natureattr.n3()), add.isAttributeType, cad_atype.PlotNature))
        natureattrversion = BNode()
        g.add((URIRef(natureattr.n3()), add.hasAttributeVersion,URIRef(natureattrversion.n3())))
        g.add((URIRef(natureattrversion.n3()),RDF.type,add.AttributeVersion))
        nature = get_base_Skos_Concept(elem['properties']['nature'])
        if ';' in nature:
            for n in nature.split(';'):
                g.add((URIRef(natureattrversion.n3()),cad.hasPlotNature,URIRef(pnature+n)))
        else:
            g.add((URIRef(natureattrversion.n3()),cad.hasPlotNature,URIRef(pnature+nature)))
        
        ## Plot Nature Appearance
        ### Change
        changenatapp = URIRef(changeuri + str(uuid.uuid4()))
        g.add((changenatapp, RDF.type, add.Change))
        g.add((changenatapp, add.isChangeType, ctype.AttributeVersionAppearance))
        g.add((changenatapp,add.appliedTo,URIRef(natureattr.n3())))
        g.add((changenatapp,add.makesEffective,URIRef(natureattrversion.n3())))
        ### Event
        eventnatapp = URIRef(eventuri + str(uuid.uuid4()))
        g.add((eventnatapp, RDF.type, add.Event))
        g.add((changenatapp,add.dependsOn,eventnatapp))
        time_ = BNode()
        g.add((eventnatapp, add.hasTime, URIRef(time_.n3())))
        g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        g.add((URIRef(time_.n3()), add.timeCalendar,time.Gregorian))
        g.add((URIRef(time_.n3()), add.timePrecision,time.Year))
        g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(BEGIN, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        ## Plot Nature Disappearance
        ### Change
        #changenatdis = URIRef(changeuri + str(uuid.uuid4()))
        #g.add((changenatdis, RDF.type, add.Change))
        #g.add((changenatdis,add.appliedTo,URIRef(natureattr.n3())))
        #g.add((changenatdis,add.outdates,URIRef(natureattrversion.n3())))
        ### Event
        #eventnatdis = URIRef(eventuri + str(uuid.uuid4()))
        #g.add((eventnatdis, RDF.type, add.Event))
        #g.add((changenatdis,add.dependsOn,eventnatdis))
        #time_ = BNode()
        #g.add((eventnatdis, add.hasLatestTimeInstant, URIRef(time_.n3())))
        #g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        #g.add((URIRef(time_.n3()), add.timeCalendar,time.Gregorian))
        #g.add((URIRef(time_.n3()), add.timePrecision,time.Year))
        #g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(END, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        #Plot Geometry
        geom = BNode()
        g.add((URIRef(geom.n3()), RDF.type, add.Attribute))
        g.add((URIRef(geom.n3()), add.isAttributeType, atype.Geometry))
        g.add((resource_uri, add.hasAttribute, URIRef(geom.n3())))
        geomversion = BNode()
        g.add((URIRef(geom.n3()), add.hasAttributeVersion, URIRef(geomversion.n3())))
        g.add((URIRef(geomversion.n3()), RDF.type, add.AttributeVersion))
        g.add((URIRef(geomversion.n3()), add.versionValue, Literal("<http://www.opengis.net/def/crs/EPSG/0/2154>" + geojson_to_wkt(elem['geometry']), datatype=geo.wktLiteral)))
        g.add((URIRef(geomversion.n3()), PROV.wasGeneratedBy, URIRef(activity + "0006")))

        ## Plot Geometry Appearance
        ### Change
        changegeomapp = URIRef(changeuri + str(uuid.uuid4()))
        g.add((changegeomapp, RDF.type, add.Change))
        g.add((changegeomapp, add.isChangeType, ctype.AttributeVersionAppearance))
        g.add((changegeomapp, add.appliedTo, URIRef(geom.n3())))
        g.add((changegeomapp, add.makesEffective, URIRef(geomversion.n3())))
        ### Event
        eventgeomapp = URIRef(eventuri + str(uuid.uuid4()))
        g.add((eventgeomapp, RDF.type, add.Event))
        g.add((changegeomapp, add.dependsOn, eventgeomapp))
        time_ = BNode()
        g.add((eventgeomapp, add.hasTime, URIRef(time_.n3())))
        g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        g.add((URIRef(time_.n3()), add.timeCalendar, time.Gregorian))
        g.add((URIRef(time_.n3()), add.timePrecision, time.Year))
        g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(BEGIN, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

        ## Plot Geometry Disappearance
        ### Change
        #changegeomdis = URIRef(changeuri + str(uuid.uuid4()))
        #g.add((changegeomdis, RDF.type, add.Change))
        #g.add((changegeomdis, add.appliedTo, URIRef(geom.n3())))
        #g.add((changegeomdis, add.outdates, URIRef(geomversion.n3())))
        ### Event
        #eventgeomdis = URIRef(eventuri + str(uuid.uuid4()))
        #g.add((eventgeomdis, RDF.type, add.Event))
        #g.add((changegeomdis, add.dependsOn, eventgeomdis))
        #time_ = BNode()
        #g.add((eventgeomdis, add.hasLatestTimeInstant, URIRef(time_.n3())))
        #g.add((URIRef(time_.n3()), RDF.type, add.TimeInstant))
        #g.add((URIRef(time_.n3()), add.timeCalendar, time.Gregorian))
        #g.add((URIRef(time_.n3()), add.timePrecision, time.Year))
        #g.add((URIRef(time_.n3()), add.timeValue, Literal(datetime.strptime(END, '%Y-%m-%d'), datatype=XSD.dateTimeStamp)))

print(g.serialize(format='turtle'))
g.serialize(destination=f"{ROOT}data/rdf/{COMMUNE}_landmarks_initial_plots.ttl", format='turtle')
# Out:
# @prefix add: <http://rdf.geohistoricaldata.org/def/address#> .
# @prefix atype: <http://rdf.geohistoricaldata.org/id/codes/address/attributeType/> .
# @prefix cad: <http://rdf.geohistoricaldata.org/def/cadastre#> .
# @prefix cad_atype: <http://rdf.geohistoricaldata.org/id/codes/cadastre/attributeType/> .
# @prefix cad_ltype: <http://rdf.geohistoricaldata.org/id/codes/cadastre/landmarkType/> .
# @prefix change: <http://rdf.geohistoricaldata.org/id/change/> .
# @prefix ctype: <http://rdf.geohistoricaldata.org/id/codes/address/changeType/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix event: <http://rdf.geohistoricaldata.org/id/event/> .
# @prefix geo: <http://www.opengis.net/ont/geosparql#> .
# @prefix landmark: <http://rdf.geohistoricaldata.org/id/landmark/> .
# @prefix pnature: <http://rdf.geohistoricaldata.org/id/codes/cadastre/plotNature/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix time: <http://www.w3.org/2006/time#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <_:N021cdcc21da34c879ca83a448f4f1696> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D78_32a94f94-7c27-40f7-87f5-c918d83be615 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N031f9ffb4ab64b139aec54f2442346c4> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D53_0014d14f-a9b0-4c63-be00-bea58dcfe419 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N0dd88e554b224f30983021e344464c3d> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D47_a2f71dc2-4c7e-46e9-9dd5-7c0ae4f669e1 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N0e2513405039417489fef4911980a986> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D90_097be866-6f54-4ba8-8f38-beb88bd8d6ff ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N0e4b613e17b141bf81e1ab58e5ce008d> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D21_f0e5f659-a781-46ec-a8f3-6225004c9442 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N0f2f6f444586405889194ae8aefe3dc8> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D85_d25e74ab-3ec5-4171-bc3b-b7b2a996ed4a ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N135fc627ee174b87b218c6d8e31c417b> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D42_309b6406-3c0b-4980-a581-eead61781ab9 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N1ef43fdea3094ea2b30b7ea9fd447ec9> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D63_6d29394c-bb5d-41f3-81a2-e14ce464e907 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N1f17851b0f6849358a55247c6f63488a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D60_b9acd5dc-35a2-48e0-b957-6060fedcea98 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N1f6bc363f28e4089866842e4eb0663c3> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B267_64fd973d-2999-4afd-8d99-20eb735bad02 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:N20048976939f408a9443876be56498ef> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D44_09c298b7-2e0b-4397-9639-1d4353a71a24 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N2058a20e6f354efa8d25792a1a92e6a4> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D410bis_fb5a43e7-26da-49e9-b49b-506bcf712bfc ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N21183211305b46c7b97204ec8d707496> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D14_c6bc4028-3765-49f2-ad38-80b1400b154c ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N24765c09390f4acba4ba284056ed54b5> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D19_85f68242-36e4-454d-be51-ce761c388b31 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N28889c9d5c5a47a4ab16c9056fa3718d> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D17_299ca0ad-36ed-4af9-acbf-379ed328cd65 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N28e42163d4f24d14ad12f1e0f004aeb0> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D41_745b57e9-6f50-42df-bda7-2bef0413c4b0 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N2ae69ef7b5f940fb9fb187881afcea9d> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D84_94216ddc-f68f-4450-8ee6-4cec811d67ad ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N2c49fbfb9b9949cc957fefa6f5bc5c6d> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D23_9c544529-4b36-4525-a56b-3db69042031b ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N2ce9942a7d7b4b23b3e50fa3cc4a3e76> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D58_96dbb784-8284-46ca-82d5-b30393255814 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N2dfd9c8fd4194192b05a37bb3e2b8881> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D16_639821a4-3cb0-4f51-a38e-5b1b6ff9fe6f ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N2e03cc48e4ed471e8782e1ddeaebb5d4> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D410_615f84ef-5c5f-4954-9590-0741ea69e425 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N324a5900bd404259b7d1687a86026b17> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D35_04bab81e-d3a1-467a-9c3b-5f3a6e399a05 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N324e5b0488a8400eae957fd33087bc44> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D70_9ade0936-a67f-42d5-91cd-c74e8161a2fc ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N33be2be4137c45f7833250f9f1783517> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B261_193bda22-acbf-4064-a1f9-cc447697e974 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:N3ab1f5f4bdba4adfacad0a4ae915d5dc> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D40_9e08a86e-e435-40f1-a0ef-e196c9427784 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N3be93a01bcce46a0967e88686b093956> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D37_7b1fe35f-1095-4ed9-a708-60e9a9c7e4de ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N3c7d803371754ab29fd045e205eb5431> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D421_2bd30fb6-c74c-4bb9-a8d6-ebbbaf8a81d6 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N3eb84e39b7f14d10940eceb2aba42a24> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D15_c2957ded-8b34-43f3-b3aa-3a9ccf9ae497 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N3fc3e0d06c394d0cb5e0de95521046c2> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D48_958a32eb-857d-41a6-b971-88081bcfce96 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N402d1e3b9dea479097e0bd8e7fc45915> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D423_6d8d7b15-b6e8-49b9-930b-0a54735b3e9a ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N4384f12d0be642529dc9b158526a4ae4> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D29_e86e8ccf-52e3-455e-bf1d-8280f5ffaa1b ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N47760770993f432d9f3f8758dfd225f2> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D25_7adb0cef-afa7-408f-a901-fd356aafbd09 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N4889704dfcfc4dfbb8f1f514e0ef2c0c> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D71_d1dd5c70-1882-437c-b433-321427dc9a85 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N490a56566a5041509d978e218ff2c29e> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D409_678981a6-189c-4243-817d-4b05547dbddf ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N4a9faa8eeb58430bbbbdce40b76ae901> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D8_5583d18c-c6bf-4793-9485-2edf0405b609 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N4b337ac9a0ad47ceac216db22a234264> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D431_60b30ba6-3356-4cbf-a77b-9b016d01aa29 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N4c7a412e0c424193a1b68784c0468b30> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D417_116a579a-5fcb-493d-9800-da35430f6880 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N4de15ca3f8614a00b5755b09bc0f6e9e> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D24_1fb18db2-a22c-4180-a2fc-32ec913d8d76 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N4e067532790e481cb7a54ff3cfd000d2> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D81_d52b0db3-fcd0-4a97-a5f9-e0e3df0b240f ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N4f482b37eb2f48dd8c70121a5ebe0771> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D424_7af567cb-8b63-45a8-994f-5e0c76055062 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N51c9a337d9384ae4a895d98877e62976> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D91_f356f410-40ce-48d0-a59e-9592583a4bbd ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N553fec113a894429b00b4864de649698> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D66_ef1e265f-8780-4ae3-8058-e8f2f40a273d ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N57d3de9d895c4aadbbdc10ca2518b18d> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D50_73fc0e89-c5c8-4cc5-9bb6-eda1f1ea7283 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N5821b4aa71bf458ca18739f34a87bad0> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B263_db1d29ee-d94f-4a62-87ae-60ed19bd5066 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:N5abbc95f659e47f683f7bf07ec24d710> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D31_aaa21df2-1bef-4c78-9aab-204655553980 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N5b2c4c6e92e54e4a88ceda373906086a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D11_a1d6650e-e221-42a8-8515-1ff7ae69af19 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N600426cc119848a3a6223493f7987c11> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D77_3cb335ae-78be-4fb2-b7e4-62d3d2fb447a ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N62a0c613127d4187adb04efdf00e5abc> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D75_a854a048-7e73-4aea-84b8-9e0334f194f4 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N64f4cfa45ee241cd9c15e27225fdf1e1> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D429_2ba74fdd-fab3-48e5-bd97-26ff3dd99404 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N65080c3f3828443f8b2132d1291eb992> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D65_b410bfdd-d291-4c7e-b565-ae5bfb738a9a ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N6704e0c025b74385b73ef8127e5c27fa> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D412_e2f5bca5-f39e-4986-859e-7e9ea1896d2b ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N678d405b0a3742529cbde6aac2d3c7ef> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B229_cc89e22a-4fd7-4cf3-87a4-6aa0185b8b8f ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:N69208b1338a849ff815a6d03b39afd8b> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D55_f75ecb62-6737-4139-b826-7a1b5477e666 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N69841608579f4bec82e0c51b41cd477b> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B260_113e1f6b-4ecd-41f2-9561-6ab25bac3fe7 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:N69d5e3eb17a748f7ad4e1e38475c440f> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D64_1d4c4487-2348-4532-bc8a-7a4ff527f1ce ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N6ec899153c0b4506806112d8322dc5e4> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D86_17b1b03f-c605-4e4b-82fc-16031ef1cdba ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N711b6d2693d44ad6b111188d8e0de03b> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D45_69291118-7e2c-4984-ab2d-eab7712473dc ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N7a6980fe7f81434a86ef8f997974f621> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D408_817d67a9-1bd5-4def-adfe-638ce32f56e8 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N7b532f50914c489881aebf9c89979e2c> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D95_9b0732e1-8c13-4b0e-8c23-20c352828770 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N7b54a5f337ca457db5e1bf0248243d55> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D76_b435d3cc-ba93-436a-942d-29bf8f975c39 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N7e0f9b0f1a484b4495b8208bb0c9e1c1> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D10_99263736-6885-44ec-9f36-761b99ec9dfd ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N7ee0cad8067041f794cff53915201722> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D3_f16b8168-1d73-4863-8700-a6028c19538f ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N800102bed8294b3eb91b633442c9664e> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D69_3e6e569e-11e2-455a-8ac3-4d8ecaf5f885 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N834ca91e22c94ead9d662ccd91540fa7> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D414_cd787469-ce46-4f70-bf79-2f1c81940df2 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N85098cf1fbbb4428b4ae3a018fa57356> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D79_39e29a04-8183-4966-8728-37e1c4d018b8 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N8612852f9a3e4c9986eee3fe918d7c74> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D94_272d4edf-4a7b-417f-8863-9413abb5ec11 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N89866a312a9045e388b6b3a6a43587c8> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D74_7f6602d4-454e-4ccd-be9f-30852b0d60ab ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N8cc8072f195b4e55a75298e60c7db9d6> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D411_fd323639-8d84-40d3-be73-9aa6aa59ab31 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N929fd7bc050841c09b07ba204d110aac> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D430_63981518-cdf8-4565-a606-090d4bd97b5c ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N97392400c8554975897421870be9d9bc> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D52_62df36b7-9d16-49e2-89c1-a2a96bdcd179 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N98d2290ff04b423096a87ab7e3b17aea> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D59_bc346f10-14b6-481b-8495-6262958fef75 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:N99819704a3cd41d38c776386e9893469> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D39_1005c0ae-2e04-4f2c-995e-55c927dd4982 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na0a14b1aaed142d48d9ce732b48610ec> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D56_20c113af-9c55-45f9-a7b3-7d0d0fa4fb2c ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na123a2baca26419b8fccca57b1af7948> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D36_b5ed2dd3-1b40-4a9a-9cc3-1bedf80391aa ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na1ce28bf0d0e434483be8a807ce461d4> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D26_1733a836-a654-4db8-847d-d2b5b571654e ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na22fafcc2d1e4019b938eb2bf27ab40a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B265_84edfeee-a3f3-493a-a783-75a1289db05e ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Na2dc7703c6a340c0a6ad0816e2a737c8> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B224_03ce3da9-c15a-45ac-a9d9-67c820d597dd ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Na31504ff51464d8b8f70339347184619> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D12_4eefdfcd-939c-4bd0-8c03-3208488fae5c ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na4361c4f5a5045a3a3ba9419f25b4b44> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D422_ae5b1174-800e-4341-8d68-64364d9c8ec6 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na4bb159abe264543a1e136c1a809d422> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D1_230a08d8-5bea-4a99-b870-eded218d2eeb ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na55d2a6bc42147089f72f578393054bf> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D73_2e8d7872-6d4d-4cde-a29f-7b5e11da72ce ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na5db121c3d05402b92feb048db6d6976> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D30_6adf4d36-70c5-4a5e-968c-64e99422969c ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na73732629b2542f18cfef7611bfb22df> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D34_58630bfb-aae8-47b2-85cf-f73917a5d0ae ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Na91ef88cc6674ecab78871cc66b45ef7> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D88_a95383cc-2caa-4068-b88a-5fdf74abb6de ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Naa80f1910728488c80d455d66c717989> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D72_5516a526-8097-425e-a154-4def297f36dd ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Naaf00448df2c4825b92865942330785d> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D415_7630149d-fd69-4238-a38c-2202659f216c ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nab227ce5306d4a79b580650000f085f2> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D5_5e133bee-3390-4441-9f7c-8565b17bd40e ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nb1deeb3ffdfd4581a0219fe69f826945> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D51_ceffb9a1-183e-4610-80f1-eaf137591c41 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nb4c8de862f4041419d7575c9abb8cbd9> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D57_0b885f18-b683-4645-b094-f76b961e5b81 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nb61cdd126ebd42dbb99ca6e7236024c1> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D5bis_e6727139-0598-4c79-aa17-f4c1e268670e ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nb8bd8d96736145889b2dcdb66a0c2542> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D82_0570ea8e-6eb4-415e-8488-a729bf6cb0d8 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nb923ee973d0a46cf8316d4f5c5202928> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D54_90fb03e2-5103-421b-952a-bb527389d61d ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nb9c8ece6f5ff429f9744ee8ef82d33a5> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D20_41293fd1-a876-423b-86a2-0e73dc9f59c8 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nba81991abebc4adab50ae021989b00bc> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D46_70eee9d2-8a15-498b-b16a-10b3bf195346 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nbae87a17b9924b7783015b206eeb510c> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D413_d925ccee-7942-4b30-bac9-b1770e6d5a1f ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nbb431794cf36419eb3a7f21a984f5ef9> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B264_dfdff02a-67f7-4cbb-ac1d-073efb02ce50 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Nbc84fe712e034b17a0f51f385242594b> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D420_51972e62-8832-4bc0-8803-d16f7f2bd9d5 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nbd237c1cddaf4d48aaaf2b325cc1e515> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B226_d3bf15a3-0ecc-4d00-b32b-cad6fede5a5f ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Nc1b527f69f2d429c939f890c532f3bb6> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D32_e8500f37-455a-443d-83db-30f13cbb905d ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nc31b1026f67c418aa2ce0ed60cc53a48> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D27_85f46e7d-58cd-4851-8de8-3065fcd52377 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nc7b82198133b481b88b924b008df95ae> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D87_80e49231-98a4-4032-a927-04272ddc60e5 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nc832d7406e26459ea266630b7c5ac60a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D89_7ab08c0e-09b8-451a-ae90-83e712389534 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nc950bdd3e318419f86157e50e6ee4479> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D418_f3359f07-f3d4-4c73-9c13-bb9066ba974c ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nc98c748f59594ad19d0189f5303c2805> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D6_8edbed0f-dfd9-4117-a815-d4324e4f7e59 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nce091539882842e78cc250c063d7280a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D416_635f049c-15cf-4f13-b804-875da6218277 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Ncf4897b706a643558c33559612d2bc24> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D18_f0b2fa68-9cf6-4fbf-ba63-72099e7591d6 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nd00ad86e1a1e4da0b3a0225142fbcda2> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D80_1bb57d92-2cef-46f6-b03e-4ea28a5d6ac4 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nd06f0501aaee484b8e0c7d98a9208e1e> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D67_810440bf-328b-4a92-aa65-af0ced920241 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nd0c01cd24df243dc9da1ba9966667228> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D93_7ecb4f1b-8807-47a6-bca8-c34cd8e927be ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nd2e9da53dd194641bc4270f2ff6e8d46> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D68_19faa88d-a9f9-49da-bf1f-5995458ab69a ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nd3a1eb338e044aca9f1e25bae95851c9> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D83_9a93643e-0289-4c3a-afe7-80e807512f63 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nd3af38c5731040389107a56912e18a98> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D49_cf1a9e04-2596-456b-9d9b-a0638735ec16 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nd56bcafcea014caab7ed0d86732239a9> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D432_107f783c-c9a1-4f02-8a54-68f9563f8901 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nd78aa413502b4c18a70a3c13a8468320> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B262_7f4a5d72-a1fe-4336-89aa-f3a7467e3971 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Nd91cfc9d13894ebdae24ef7969e6a29b> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B232_93fbbae9-07ec-4aac-9eae-e99ac24aeb40 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Nd9d2e5abc1b244cc908dc785b5cc90f4> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D22_c7e6279f-e33f-4935-bd7c-54b3ccec6e03 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Ndb79e4beb1224fb7ba32ff03d72ff74a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D419_f2b3ff85-ded0-40ec-a737-dd2ac954eb60 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Ndbe728140fe642c28ed427f3bfe47f28> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D425_b723b649-e8ef-4a69-be53-5c75fd88d3d9 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Ndfc72c54d08e42619482c8b1b1972756> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B228_12171aab-16d4-48a0-acd3-96abbfb0b1ce ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Ne51cbfaa457b4a50a4614225a346494b> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D33_0e2eda81-25e9-48bd-956d-e330d8fa23d6 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Ned2d899f392c48679d8ce9c6fe77c1ad> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D9_2e12699f-dcf9-4ab8-a47d-8789634b5ac3 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nedd7bd34477b4fe48bd79ee6ad3851ff> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D43_143538aa-00c8-4601-9450-fa6bbffde5c2 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nee58b4080a614396b02e875d69a150b5> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D38_6ac9effd-1f13-4f27-8460-2f8ee676faaa ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nf12cc664ce484670b54f12ebe7209a32> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D2_8180e8ce-14a8-4cbe-85ee-0f391af14ae9 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nf186201dde25461bbaa95f556445b156> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D61_7eb582d8-fdc7-42ec-aaca-94ccae56f307 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nf44fa40ebfec4256b761cc93cafad150> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B231_e2883b14-48ac-4a54-abee-addb70df66a8 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Nf61bdfae2a054ca0b4823f84e0a9f72a> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B230_93ecdfe9-bb0f-4b3e-8fa5-4fa4264c5f99 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# <_:Nf6f33152b0a54ea9995f3e168600faa3> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D13_2ed742cc-2aa9-4a7f-8d53-1087656aea8a ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nf831e153bdc44dbab9709b8625ba2597> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D428_bd00cfd9-f6ac-4875-b6c6-3cbcb8025eb1 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nf876725de3f347669904f14b54b34267> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D427_59b377b9-e2ea-4f26-a0ef-879a2c698a85 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nf8aa2431ad56433c82949a00b546bbe5> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D92_9c3070f1-282f-4034-9f68-d8887c346475 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nfedfd3677cb5489d9c3ce13426bb7208> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1845_D4_ee961bcb-f432-4d67-adcd-f474412c4232 ;
#     add:relatum landmark:da6a5c2c-e86d-43bb-8950-7169bd0df60a .
#
# <_:Nff293e615fca40df8f3e002b5186ae7e> a add:LandmarkRelation ;
#     add:isLandmarkRelationType <http://rdf.geohistoricaldata.org/id/codes/address/landmarkRelationType/Within> ;
#     add:locatum landmark:94_Gentilly_1811_B227_1e63afe5-e254-4530-a935-2dfc30e7ce68 ;
#     add:relatum landmark:87d7c2f6-306b-45a1-a833-5e17821c3102 .
#
# change:0074dba2-ad33-44b9-b17d-bab3ee5f48be a add:Change ;
#     add:appliedTo <_:Nffad1327c1114ebcb6a30bd35ba84d53> ;
#     add:dependsOn event:b49b09fb-21ab-4081-9e83-e2c7c480c37e ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:Nb2ae12754279413a818bbc7cdf97873d> .
#
# change:01759955-fa34-436d-a8b7-6170472e086f a add:Change ;
#     add:appliedTo <_:N4cf3356b56fd49dab3290839c097e784> ;
#     add:dependsOn event:a078d7ff-37d3-483e-be6f-93ec66540f5c ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:Nac82751c10914f05966ce13a54e7f771> .
#
# change:02b7cc41-ae35-40cf-848c-6aa82794d065 a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1845_D58_96dbb784-8284-46ca-82d5-b30393255814 ;
#     add:dependsOn event:c9846120-26d2-4cc7-9935-7a15d626dd09 ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:0459e381-6150-4d61-be69-403628745549 a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1811_B224_03ce3da9-c15a-45ac-a9d9-67c820d597dd ;
#     add:dependsOn event:453a78a2-ba38-4658-b668-37e63d20f3fd ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:050bf008-1aad-4be7-a425-f726a2fbd095 a add:Change ;
#     add:appliedTo <_:Ne35727405c364e8eb444e61fa3fc19dc> ;
#     add:dependsOn event:5234832e-c732-48a5-a9a5-35d326435e0c ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:N036acf9409184c33aa38ae5a3ff388e6> .
#
# change:05fbc53e-b075-4b1b-9722-e55b9dc474e6 a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1845_D90_097be866-6f54-4ba8-8f38-beb88bd8d6ff ;
#     add:dependsOn event:32ce6ede-a6a5-4c74-9d86-c2f80c581e80 ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:070619ce-8380-4ae8-9fa9-dd4e2b2e2116 a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1845_D20_41293fd1-a876-423b-86a2-0e73dc9f59c8 ;
#     add:dependsOn event:27ba3fe7-4489-498b-8a77-7c9d3a30308e ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:074abe7b-057f-4679-8579-2839805f3a18 a add:Change ;
#     add:appliedTo <_:N3ef3f6b88ee34e6a940f3d902c66160c> ;
#     add:dependsOn event:e8b3f3d1-dea1-4ea2-af90-993d2e36e677 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:Nfd736e71e8324e3c80520de26440c756> .
#
# change:08aab29f-58e7-4321-9bc6-e232ff6491c9 a add:Change ;
#     add:appliedTo <_:Ndc71bc62b34b4ae8a915444d09dbb2ca> ;
#     add:dependsOn event:6c04e4ee-e9ed-4408-b005-5fcf05f1f6f0 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:Nce710c64c58b4a47a13ee01696e558aa> .
#
# change:08ca07aa-d3c7-474f-af4b-ead7337a194a a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1811_B231_e2883b14-48ac-4a54-abee-addb70df66a8 ;
#     add:dependsOn event:27246473-ae01-45e7-9acd-b1432d9a5a53 ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:08dd3295-87a7-4e7e-bb02-366094e33e36 a add:Change ;
#     add:appliedTo landmark:94_Gentilly_1845_D68_19faa88d-a9f9-49da-bf1f-5995458ab69a ;
#     add:dependsOn event:77887f51-b1cb-4958-b892-622c1e7c97e5 ;
#     add:isChangeType ctype:LandmarkAppearance .
#
# change:09f454a2-f021-47af-b37f-d422cb86cf2e a add:Change ;
#     add:appliedTo <_:N79949b7637254751864d12b696a817b4> ;
#     add:dependsOn event:199e1323-f9e8-480f-a2a2-6b74a181c4e5 ;
#     add:isChangeType ctype:AttributeVersionAppearance ;
#     add:makesEffective <_:Nbeba968731174ecea8259b40c520f01e> .
#
# change:0ae10263-dfda-4e88-a0f9-27b5c0aafacb a add:Change ;
#     add:appliedTo <_:Ne3b245d3757742c9b78f22c012bf3ba6> ;
# ...
#         <_:Na71481bed40d4c8289eebe638145c88e> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-57 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D58_96dbb784-8284-46ca-82d5-b30393255814 a add:Landmark ;
#     rdfs:label "D-58 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-58"^^xsd:string ;
#     add:hasAttribute <_:N0d4c023a2d94470b8e30f4f801de17f6>,
#         <_:Nb45369884e4a4b17bf62a5933b57bc27> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-58 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D59_bc346f10-14b6-481b-8495-6262958fef75 a add:Landmark ;
#     rdfs:label "D-59 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-59"^^xsd:string ;
#     add:hasAttribute <_:N8c605fcb337e462ea3a55715ceb8e878>,
#         <_:Nc1a36abfcaf3432fb7d66c4ef8f14e53> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-59 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D5_5e133bee-3390-4441-9f7c-8565b17bd40e a add:Landmark ;
#     rdfs:label "D-5 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-5"^^xsd:string ;
#     add:hasAttribute <_:N167921b576ae46d5b6330dbed2d5777b>,
#         <_:N973bd90f635940529e3b663d2d8b6b8b> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-5 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D5bis_e6727139-0598-4c79-aa17-f4c1e268670e a add:Landmark ;
#     rdfs:label "D-5bis (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-5bis"^^xsd:string ;
#     add:hasAttribute <_:N99566ec192b24bcabd1daa98f42cf7c4>,
#         <_:Nb65e215c411a4204859ce9def366bef7> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-5bis (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D60_b9acd5dc-35a2-48e0-b957-6060fedcea98 a add:Landmark ;
#     rdfs:label "D-60 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-60"^^xsd:string ;
#     add:hasAttribute <_:Naba31bd51305453a9c4d8bf985ef85a1>,
#         <_:Nf40e2fb94be74c998de46bee90b065ac> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-60 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D61_7eb582d8-fdc7-42ec-aaca-94ccae56f307 a add:Landmark ;
#     rdfs:label "D-61 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-61"^^xsd:string ;
#     add:hasAttribute <_:N1d47bde7d9604302b60127eade97412b>,
#         <_:Nc49759763aa54713a9c629881f4331e7> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-61 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D63_6d29394c-bb5d-41f3-81a2-e14ce464e907 a add:Landmark ;
#     rdfs:label "D-63 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-63"^^xsd:string ;
#     add:hasAttribute <_:N1e8f97e653764eb982ddd5b49372ff9b>,
#         <_:Ncf85a52ef5824858bd5bb76ef6f03ab3> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-63 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D64_1d4c4487-2348-4532-bc8a-7a4ff527f1ce a add:Landmark ;
#     rdfs:label "D-64 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-64"^^xsd:string ;
#     add:hasAttribute <_:N49b581ab5703430b841084cdc2306a8f>,
#         <_:Nb67f15ea3fc34a488c26429a4d1e5f0f> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-64 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D65_b410bfdd-d291-4c7e-b565-ae5bfb738a9a a add:Landmark ;
#     rdfs:label "D-65 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-65"^^xsd:string ;
#     add:hasAttribute <_:N90df75f63765429899c885cdd42e5165>,
#         <_:Nb5e45176b22a435fbc68a4506b688698> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-65 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D66_ef1e265f-8780-4ae3-8058-e8f2f40a273d a add:Landmark ;
#     rdfs:label "D-66 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-66"^^xsd:string ;
#     add:hasAttribute <_:N35fc535e14cc448b9d026b57d08db438>,
#         <_:Nda56c88ab5674a3d9625af46d7eb08b6> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-66 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D67_810440bf-328b-4a92-aa65-af0ced920241 a add:Landmark ;
#     rdfs:label "D-67 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-67"^^xsd:string ;
#     add:hasAttribute <_:N5b40c135209246f5ad383f053b43b1e8>,
#         <_:N6e0a765c750c4c148e41631b07304ef7> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-67 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D68_19faa88d-a9f9-49da-bf1f-5995458ab69a a add:Landmark ;
#     rdfs:label "D-68 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-68"^^xsd:string ;
#     add:hasAttribute <_:N1689b9a5990e4a02a4c31d43e087ebe2>,
#         <_:N6b6475607ed6404da7d9f5babdc7c850> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-68 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D69_3e6e569e-11e2-455a-8ac3-4d8ecaf5f885 a add:Landmark ;
#     rdfs:label "D-69 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-69"^^xsd:string ;
#     add:hasAttribute <_:N50951405d27245c6a090f842c0a09f07>,
#         <_:Nfb0b50d4fccf47aebc3c15ff881ecf16> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-69 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D6_8edbed0f-dfd9-4117-a815-d4324e4f7e59 a add:Landmark ;
#     rdfs:label "D-6 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-6"^^xsd:string ;
#     add:hasAttribute <_:Nb875b493156040f1891c83c52ea85f68>,
#         <_:Nffad1327c1114ebcb6a30bd35ba84d53> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-6 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D70_9ade0936-a67f-42d5-91cd-c74e8161a2fc a add:Landmark ;
#     rdfs:label "D-70 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-70"^^xsd:string ;
#     add:hasAttribute <_:N79949b7637254751864d12b696a817b4>,
#         <_:N886ac11185594a2db42c5bb94eb5c460> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-70 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D71_d1dd5c70-1882-437c-b433-321427dc9a85 a add:Landmark ;
#     rdfs:label "D-71 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-71"^^xsd:string ;
#     add:hasAttribute <_:Nb390649e2adb4f8b9d21ab80e8f39d5d>,
#         <_:Nf1df3929603247118d20bc28e914d1f0> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-71 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D72_5516a526-8097-425e-a154-4def297f36dd a add:Landmark ;
#     rdfs:label "D-72 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-72"^^xsd:string ;
#     add:hasAttribute <_:N0f23d555562148ab8a6a0ab5dc46fa6b>,
#         <_:N1a0ef4fc27964d9fa3d39bd605d437ee> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-72 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D73_2e8d7872-6d4d-4cde-a29f-7b5e11da72ce a add:Landmark ;
#     rdfs:label "D-73 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-73"^^xsd:string ;
#     add:hasAttribute <_:Nd176fa3aaa794d6f84ba639f525982e4>,
#         <_:Nebb8a0fd582146d2895ebef4e3bc694d> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-73 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D74_7f6602d4-454e-4ccd-be9f-30852b0d60ab a add:Landmark ;
#     rdfs:label "D-74 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-74"^^xsd:string ;
#     add:hasAttribute <_:N0874421e27924a8f8cd6c31cf1657bd9>,
#         <_:N1f6da00734ee4aacae10b964426c9ac7> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-74 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D75_a854a048-7e73-4aea-84b8-9e0334f194f4 a add:Landmark ;
#     rdfs:label "D-75 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-75"^^xsd:string ;
#     add:hasAttribute <_:N12e33a0e39ab458981a51b42ee3089b3>,
#         <_:Nc6c6e850a8ff42dd885e5998a9d1f981> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-75 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D76_b435d3cc-ba93-436a-942d-29bf8f975c39 a add:Landmark ;
#     rdfs:label "D-76 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-76"^^xsd:string ;
#     add:hasAttribute <_:N2d2c056106994c3bbcebc896f1aff6dd>,
#         <_:Nadd1d7a59bd64a2cb3ee3022e75db6dc> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-76 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D77_3cb335ae-78be-4fb2-b7e4-62d3d2fb447a a add:Landmark ;
#     rdfs:label "D-77 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-77"^^xsd:string ;
#     add:hasAttribute <_:N7bba542467054b9c9cdcf003d61b3ffe>,
#         <_:N9b4f445c656b4b669f0fbcde81c36df4> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-77 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D78_32a94f94-7c27-40f7-87f5-c918d83be615 a add:Landmark ;
#     rdfs:label "D-78 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-78"^^xsd:string ;
#     add:hasAttribute <_:N87076d0fa123414b8460e61b964bd299>,
#         <_:Nbe871d7c68d44308914b1b5c50322464> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-78 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D79_39e29a04-8183-4966-8728-37e1c4d018b8 a add:Landmark ;
#     rdfs:label "D-79 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-79"^^xsd:string ;
#     add:hasAttribute <_:Nb4ffe6ed1ac140ceb28893865d98703a>,
#         <_:Nb9216715faf547bdaec68f616efc915a> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-79 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D80_1bb57d92-2cef-46f6-b03e-4ea28a5d6ac4 a add:Landmark ;
#     rdfs:label "D-80 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-80"^^xsd:string ;
#     add:hasAttribute <_:N2230026f63b9423583ce8494d5b32bcd>,
#         <_:Nd221ca4674b7401291f8a17eab2ca41c> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-80 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D81_d52b0db3-fcd0-4a97-a5f9-e0e3df0b240f a add:Landmark ;
#     rdfs:label "D-81 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-81"^^xsd:string ;
#     add:hasAttribute <_:N78190677b9404e7daa159c883a5623ef>,
#         <_:Ne1011cd8c890495aa44440e73781ffc6> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-81 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D82_0570ea8e-6eb4-415e-8488-a729bf6cb0d8 a add:Landmark ;
#     rdfs:label "D-82 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-82"^^xsd:string ;
#     add:hasAttribute <_:Nd522dbdeb7ca479ca30df438498b812d>,
#         <_:Nf9595ea8dc1243d885daf9a07a759647> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-82 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D83_9a93643e-0289-4c3a-afe7-80e807512f63 a add:Landmark ;
#     rdfs:label "D-83 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-83"^^xsd:string ;
#     add:hasAttribute <_:N2509e65e9fd84e3ba208af49d45e99d8>,
#         <_:N92e329ac054f4dcbbb29950923401c91> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-83 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D84_94216ddc-f68f-4450-8ee6-4cec811d67ad a add:Landmark ;
#     rdfs:label "D-84 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-84"^^xsd:string ;
#     add:hasAttribute <_:N009bbbc566df49d281642cccf5322a5b>,
#         <_:N06c5ca956932407aa7afdfd265cb8561> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-84 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D85_d25e74ab-3ec5-4171-bc3b-b7b2a996ed4a a add:Landmark ;
#     rdfs:label "D-85 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-85"^^xsd:string ;
#     add:hasAttribute <_:N2cf43d62df2144b98d705bb5bd8eeb5c>,
#         <_:Na9559a178f8244c9bf9aa1c0b591bd01> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-85 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D86_17b1b03f-c605-4e4b-82fc-16031ef1cdba a add:Landmark ;
#     rdfs:label "D-86 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-86"^^xsd:string ;
#     add:hasAttribute <_:N60115fec475e4418bcac794637760dd8>,
#         <_:Ne81e164a73ef421d8975aea277264f6b> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-86 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D87_80e49231-98a4-4032-a927-04272ddc60e5 a add:Landmark ;
#     rdfs:label "D-87 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-87"^^xsd:string ;
#     add:hasAttribute <_:N511c52dd1e17453ea89d8609e03a564b>,
#         <_:N836dad63996d406b811e0bbed71e4128> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-87 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D88_a95383cc-2caa-4068-b88a-5fdf74abb6de a add:Landmark ;
#     rdfs:label "D-88 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-88"^^xsd:string ;
#     add:hasAttribute <_:N0c3e07d5e50549a4984f190fd5976788>,
#         <_:N89170af25df44c588b7053dfad5fa63f> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-88 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D89_7ab08c0e-09b8-451a-ae90-83e712389534 a add:Landmark ;
#     rdfs:label "D-89 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-89"^^xsd:string ;
#     add:hasAttribute <_:N3f36ce4dfcbc4cc4817643682d2c03ce>,
#         <_:Nab027b5b3f69419c953d1e21aa664d81> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-89 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D8_5583d18c-c6bf-4793-9485-2edf0405b609 a add:Landmark ;
#     rdfs:label "D-8 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-8"^^xsd:string ;
#     add:hasAttribute <_:N24ab59743eea4ebead568950b9075cb4>,
#         <_:Na39eef83195145bb8e456426f1b3150a> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-8 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D90_097be866-6f54-4ba8-8f38-beb88bd8d6ff a add:Landmark ;
#     rdfs:label "D-90 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-90"^^xsd:string ;
#     add:hasAttribute <_:N720290639274433980077c5d8ad81f34>,
#         <_:Ne038d997b2814a1ea09e52dd9620219e> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-90 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D91_f356f410-40ce-48d0-a59e-9592583a4bbd a add:Landmark ;
#     rdfs:label "D-91 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-91"^^xsd:string ;
#     add:hasAttribute <_:Nc10330d70dd34fbca1f20b921b70f053>,
#         <_:Ned04634819734b6bb07b6d666c7001b1> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-91 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D92_9c3070f1-282f-4034-9f68-d8887c346475 a add:Landmark ;
#     rdfs:label "D-92 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-92"^^xsd:string ;
#     add:hasAttribute <_:N248297af2baf4071aef8210129a19fc7>,
#         <_:N34c8e26e06e54227a42600280690463e> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-92 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D93_7ecb4f1b-8807-47a6-bca8-c34cd8e927be a add:Landmark ;
#     rdfs:label "D-93 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-93"^^xsd:string ;
#     add:hasAttribute <_:N17aca6460a1d44b08f81bc4ddefa53b6>,
#         <_:Nff9425d2ae1f4c93952e4b9b170b1118> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-93 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D94_272d4edf-4a7b-417f-8863-9413abb5ec11 a add:Landmark ;
#     rdfs:label "D-94 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-94"^^xsd:string ;
#     add:hasAttribute <_:N5fb518ade46b4ab0af0be7414826f6a5>,
#         <_:Nd03132cd0c504bddbb2a9af17e6a26d4> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-94 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D95_9b0732e1-8c13-4b0e-8c23-20c352828770 a add:Landmark ;
#     rdfs:label "D-95 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-95"^^xsd:string ;
#     add:hasAttribute <_:N53fa621b321e4868a1af78f8b03ee5f9>,
#         <_:N7001667bed1d43359ea2803043b66928> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-95 (Gentilly)"^^xsd:string .
#
# landmark:94_Gentilly_1845_D9_2e12699f-dcf9-4ab8-a47d-8789634b5ac3 a add:Landmark ;
#     rdfs:label "D-9 (Gentilly)"^^xsd:string ;
#     dcterms:identifier "D-9"^^xsd:string ;
#     add:hasAttribute <_:N20ad5fc778b244709c4edf237b59700d>,
#         <_:Nf96f629cde2845a1895750ee9fa3e968> ;
#     add:isLandmarkType cad_ltype:Plot ;
#     skos:prefLabel "D-9 (Gentilly)"^^xsd:string .
# <Graph identifier=N3f1d37db20fb4c14b22e7818014d243d (<class 'rdflib.graph.Graph'>)>
