# %% [markdown]
# ## Sources

# %%
import pandas as pd
import numpy as np
import csv
import uuid

# %% [markdown]
# ### SKOS Concept

# %%
PATH = "/home/STual/KG-cadastre/gentilly/data/SKOS_SOURCES.csv"

skos_srcs = pd.read_csv(PATH,header=0)
display(skos_srcs)
# Out:
#                                 skos:Concept skos:inScheme  \
# 0                                       Plan    SourceList
# 1                          TableauAssemblage    SourceList
# 2                            PlanParcellaire    SourceList
# 3                      PlanParcellaireMinute    SourceList
# 4                       PlanParcellaireFinal    SourceList
# 5                  PlanParcellaireIssuDAtlas    SourceList
# 6                          RegistreCadastral    SourceList
# 7                          MatriceCadastrale    SourceList
# 8                            EtatsDeSections    SourceList
# 9    MatriceCadastrale1807_1822_Bati_NonBati    SourceList
# 10        MatriceCadastrale1822_1914_NonBati    SourceList
# 11           MatriceCadastrale1882_1911_Bati    SourceList
# 12  MatriceCadastrale1914_Renovation_NonBati    SourceList
# 13     MatriceCadastrale1911_Renovation_Bati    SourceList
# 14                   EtatsDeSections_Av_1822    SourceList
# 15           EtatsDeSections_Av_1822_NonBati    SourceList
# 16              EtatsDeSections_Av_1822_Bati    SourceList
# 17                   EtatsDeSections_Ap_1822    SourceList
# 18            EtatsDeSections_Scp_Seine_1835    SourceList
# 19                           FicheInventaire    SourceList
# 20                            PageDeRegistre    SourceList
# 21                                ZoneDePage    SourceList
# 22                        LigneEtatDeSection    SourceList
# 23                             CompteFoncier    SourceList
# 24                                   Ouvrage    SourceList
#
#                skos:broader  \
# 0                       NaN
# 1                      Plan
# 2                      Plan
# 3           PlanParcellaire
# 4           PlanParcellaire
# 5      PlanParcellaireFinal
# 6                       NaN
# 7         RegistreCadastral
# 8         RegistreCadastral
# 9         MatriceCadastrale
# 10        MatriceCadastrale
# 11        MatriceCadastrale
# 12        MatriceCadastrale
# 13        MatriceCadastrale
# 14          EtatsDeSections
# 15  EtatsDeSections_Av_1822
# 16  EtatsDeSections_Av_1822
# 17          EtatsDeSections
# 18          EtatsDeSections
# 19                      NaN
# 20        RegistreCadastral
# 21           PageDeRegistre
# 22               ZoneDePage
# 23               ZoneDePage
# 24                      NaN
#
#                                            rdfs:label  \
# 0                                                Plan
# 1                                Tableau d'assemblage
# 2                                    Plan parcellaire
# 3                           Plan parcellaire : minute
# 4                              Plan parcellaire final
# 5                       Plan parcellaire issu d'atlas
# 6                                  Registre cadastral
# 7                                  Matrice cadastrale
# 8                                   Etats de sections
# 9   Matrice de rôles des propriétés bâties et non ...
# 10      Matrice des propriétés non bâties (1822-1914)
# 11          Matrice des propriétés bâties (1882-1911)
# 12  Matrice des propriétés non bâties (1914-rénova...
# 13    Matrice des propriétés bâties (1911-rénovation)
# 14                Etats de sections antérieurs à 1822
# 15  Etats de sections antérieurs à 1822 : chapitre...
# 16  Etats de sections antérieurs à 1822 : chapitre...
# 17               Etats de sections postérieurs à 1822
# 18  Etats de sections spécifiques à la rénovation ...
# 19                            Inventaire des archives
# 20                         Page de registre cadastral
# 21    Zone située dans une page de registre cadastral
# 22               Ligne de tableau d'états de sections
# 23  Zone située dans une page de matrice correspon...
# 24                                            Ouvrage
#
#                                     skos:prefLabel@fr  \
# 0                                                Plan
# 1                                Tableau d'assemblage
# 2                                    Plan parcellaire
# 3                           Plan parcellaire : minute
# 4                              Plan parcellaire final
# 5                       Plan parcellaire issu d'atlas
# 6                                  Registre cadastral
# 7                                  Matrice cadastrale
# 8                                   Etats de sections
# 9   Matrice de rôles des propriétés bâties et non ...
# 10      Matrice des propriétés non bâties (1822-1914)
# 11          Matrice des propriétés bâties (1882-1911)
# 12  Matrice des propriétés non bâties (1914-rénova...
# 13    Matrice des propriétés bâties (1911-rénovation)
# 14                Etats de sections antérieurs à 1822
# 15                                                NaN
# 16                                                NaN
# 17               Etats de sections postérieurs à 1822
# 18  Etats de sections spécifiques à la rénovation ...
# 19                            Inventaire des archives
# 20                         Page de registre cadastral
# 21    Zone située dans une page de registre cadastral
# 22               Ligne de tableau d'états de sections
# 23  Zone située dans une page de matrice correspon...
# 24                                            Ouvrage
#
#                                     skos:prefLabel@en  \
# 0                                                 Map
# 1            Assembly map of the cadastral index maps
# 2                                 Cadastral index map
# 3               Cadastral index map : working version
# 4                 Cadastral index map : final version
# 5   Cadastral index map : final version extract fr...
# 6                                            Register
# 7                                   Mutation register
# 8                                    Initial register
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Mutation register of unbuilt properties (1914-...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                         Archival Records Inventory
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                      skos:altLabel@fr  skos:altLabel@en  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# 5                                                 NaN               NaN
# 6                                                 NaN               NaN
# 7                                                 NaN               NaN
# 8                                                 NaN               NaN
# 9   Matrice des propriétés bâties et non bâties (1...               NaN
# 10       Matrice des propriétés foncières (1822-1914)               NaN
# 11                                                NaN               NaN
# 12                                                NaN               NaN
# 13                                                NaN               NaN
# 14                                                NaN               NaN
# 15                                                NaN               NaN
# 16                                                NaN               NaN
# 17                                                NaN               NaN
# 18                                                NaN               NaN
# 19                                         Inventaire               NaN
# 20                                                NaN               NaN
# 21                                                NaN               NaN
# 22                                                NaN               NaN
# 23                                                NaN               NaN
# 24                                                NaN               NaN
#
#                                       skos:definition
# 0   Plan faisant partie de la documentation cadast...
# 1   Plan réalisé à l'échelle d'une commune représe...
# 2   Plan représentant les parcellaires d'une porti...
# 3   Version de travail du plan parcellaire, peut c...
# 4                Version finale d'un plan parcellaire
# 5   Version finale d'un plan parcellaire extraire ...
# 6   Registre faisant partie de la documentation ca...
# 7   Registre contenant l'ensemble des mutations af...
# 8   Registre d'état de sections décrivant le parce...
# 9   Matrice cadastrale créée entre 1807 et 1822, d...
# 10  Matrice cadastrale créée entre 1822 et 1914, d...
# 11  Matrice cadastrale utilisée à partir de 1882 p...
# 12  Matrice cadastrale utilisée à partir de 1914 p...
# 13  Matrice cadastrale utilisée à partir de 1911 p...
# 14  Registre d'états de sections créé avant 1822. ...
# 15  Partie d'un registre d'états de sections créé ...
# 16  Partie d'un registre d'états de sections créé ...
# 17      Registre d'états de sections créé après 1822.
# 18  Registre d'états de sections spécifique à la t...
# 19  Fiches d'inventaire décrivant le contenu des a...
# 20                           Page issue d'un registre
# 21              Zone située dans une page de registre
# 22  Ligne du tableau principal d'un registre d'éta...
# 23  Ensemble de lignes et de cellules qui décriven...
# 24                           Ouvrage (livre, article)

# %%
# Print the list of column headers
print(skos_srcs.columns.tolist())
# Out:
# ['skos:Concept', 'skos:inScheme', 'skos:broader', 'rdfs:label', 'skos:prefLabel@fr', 'skos:prefLabel@en', 'skos:altLabel@fr', 'skos:altLabel@en', 'skos:definition']

# %%
from rdflib import Graph, Literal, Namespace, URIRef
from rdflib.namespace import SKOS, RDF, OWL

# Create a new RDF graph
g = Graph()

baseuri = Namespace("http://data.ign.fr/id/codes/cadastrenap/sourceType/")
g.bind('srctype', baseuri)

# Define the namespaces
cad = Namespace("http://data.ign.fr/def/cadastre#")
src = Namespace("http://data.ign.fr/def/sources#")
g.bind('cad', cad)
g.bind('src', src)

mlclasse= Namespace("http://data.ign.fr/id/codes/cadastrenap/mlClasse/")
g.bind('mlclasse', mlclasse)

# Iterate over each row in the DataFrame
for index, row in skos_srcs.iterrows():
    subject_uri = URIRef(baseuri + f"{str(row['skos:Concept'])}")
    g.add((subject_uri, RDF.type, OWL.NamedIndividual))
    g.add((subject_uri, RDF.type, cad.SourceType))
    g.add((subject_uri, RDF.type, SKOS.Concept))
    g.add((subject_uri, SKOS.inScheme, URIRef(cad + f"{str(row['skos:inScheme'])}")))
    g.add((subject_uri, SKOS.prefLabel, Literal(row["skos:prefLabel@fr"],lang='fr')))

    if row["skos:altLabel@fr"] == row["skos:altLabel@fr"]:
        g.add((subject_uri, SKOS.altLabel, Literal(row["skos:altLabel@fr"],lang='fr')))

    if row["skos:prefLabel@en"] == row["skos:prefLabel@en"]:
        g.add((subject_uri, SKOS.prefLabel, Literal(row["skos:prefLabel@en"],lang='en')))

    if row["skos:altLabel@en"] == row["skos:altLabel@en"]:
        g.add((subject_uri, SKOS.altLabel, Literal(row["skos:altLabel@en"],lang='en')))

    if row["skos:broader"] == row["skos:broader"]:
        g.add((subject_uri, SKOS.broader, URIRef(baseuri + f"{str(row['skos:broader'])}")))

    if row["skos:definition"] == row["skos:definition"]:
        g.add((subject_uri, SKOS.definition, Literal(row["skos:definition"],lang='fr')))

# Print out the graph in Turtle syntax
print(g.serialize(format='turtle'))
# Out:
# @prefix cad: <http://data.ign.fr/def/cadastre#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix srctype: <http://data.ign.fr/id/codes/cadastrenap/sourceType/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# srctype:CompteFoncier a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:ZoneDePage ;
#     skos:definition "Ensemble de lignes et de cellules qui décrivent les parcelles d'un ou plusieurs propriétaires conjoints ou sucessifs"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Zone située dans une page de matrice correspondant à un compte foncier"@fr .
#
# srctype:EtatsDeSections_Ap_1822 a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:EtatsDeSections ;
#     skos:definition "Registre d'états de sections créé après 1822."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Etats de sections postérieurs à 1822"@fr .
#
# srctype:EtatsDeSections_Av_1822_Bati a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:EtatsDeSections_Av_1822 ;
#     skos:definition "Partie d'un registre d'états de sections créé avant 1822 dédié à la description des propriétés bâties."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "NaN"^^xsd:double .
#
# srctype:EtatsDeSections_Av_1822_NonBati a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:EtatsDeSections_Av_1822 ;
#     skos:definition "Partie d'un registre d'états de sections créé avant 1822 dédié à la description des propriétés non bâties."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "NaN"^^xsd:double .
#
# srctype:EtatsDeSections_Scp_Seine_1835 a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:EtatsDeSections ;
#     skos:definition "Registre d'états de sections spécifique à la tentative de rénovation du cadastre ayant eu lieu entre 1835 et 1845 dans le département de la Seine. "@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Etats de sections spécifiques à la rénovation du cadastre de la Seine (1835-1845)"@fr .
#
# srctype:FicheInventaire a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:altLabel "Inventaire"@fr ;
#     skos:definition "Fiches d'inventaire décrivant le contenu des archives localisées dans un service d'archives."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Archival Records Inventory"@en,
#         "Inventaire des archives"@fr .
#
# srctype:LigneEtatDeSection a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:ZoneDePage ;
#     skos:definition "Ligne du tableau principal d'un registre d'état de sections décrivant une parcelle à l'initialisation du cadastre"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Ligne de tableau d'états de sections"@fr .
#
# srctype:MatriceCadastrale1807_1822_Bati_NonBati a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:altLabel "Matrice des propriétés bâties et non bâties (1807-1822)"@fr ;
#     skos:broader srctype:MatriceCadastrale ;
#     skos:definition "Matrice cadastrale créée entre 1807 et 1822, décrit les propriétés bâties et non bâties d'une commune."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Matrice de rôles des propriétés bâties et non bâties (1807-1822)"@fr .
#
# srctype:MatriceCadastrale1822_1914_NonBati a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:altLabel "Matrice des propriétés foncières (1822-1914)"@fr ;
#     skos:broader srctype:MatriceCadastrale ;
#     skos:definition "Matrice cadastrale créée entre 1822 et 1914, décrit les propriétés bâties et non bâties jusqu'à 1882 puis uniquement les propriétés non bâties jusqu'à 1914."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Matrice des propriétés non bâties (1822-1914)"@fr .
#
# srctype:MatriceCadastrale1882_1911_Bati a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:MatriceCadastrale ;
#     skos:definition "Matrice cadastrale utilisée à partir de 1882 pour décrire les propriétés bâties."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Matrice des propriétés bâties (1882-1911)"@fr .
#
# srctype:MatriceCadastrale1911_Renovation_Bati a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:MatriceCadastrale ;
#     skos:definition "Matrice cadastrale utilisée à partir de 1911 pour décrire les propriétés bâties."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Matrice des propriétés bâties (1911-rénovation)"@fr .
#
# srctype:MatriceCadastrale1914_Renovation_NonBati a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:MatriceCadastrale ;
#     skos:definition "Matrice cadastrale utilisée à partir de 1914 pour décrire les propriétés non bâties"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Mutation register of unbuilt properties (1914-cadaster renovation)"@en,
#         "Matrice des propriétés non bâties (1914-rénovation)"@fr .
#
# srctype:Ouvrage a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:definition "Ouvrage (livre, article)"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Ouvrage"@fr .
#
# srctype:PlanParcellaireIssuDAtlas a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:PlanParcellaireFinal ;
#     skos:definition "Version finale d'un plan parcellaire extraire d'un atlas communal ou cantonal"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Cadastral index map : final version extract from atlas"@en,
#         "Plan parcellaire issu d'atlas"@fr .
#
# srctype:PlanParcellaireMinute a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:PlanParcellaire ;
#     skos:definition "Version de travail du plan parcellaire, peut comprendre des traits de constructions, notes de travail ou une numérotation non définitive des parcelles."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Cadastral index map : working version"@en,
#         "Plan parcellaire : minute"@fr .
#
# srctype:TableauAssemblage a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:Plan ;
#     skos:definition "Plan réalisé à l'échelle d'une commune représentant l'assemblage des plans parcellaires qui détaillent les parcelles de la commune."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Assembly map of the cadastral index maps"@en,
#         "Tableau d'assemblage"@fr .
#
# srctype:PageDeRegistre a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:RegistreCadastral ;
#     skos:definition "Page issue d'un registre"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Page de registre cadastral"@fr .
#
# srctype:PlanParcellaireFinal a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:PlanParcellaire ;
#     skos:definition "Version finale d'un plan parcellaire"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Cadastral index map : final version"@en,
#         "Plan parcellaire final"@fr .
#
# srctype:EtatsDeSections_Av_1822 a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:EtatsDeSections ;
#     skos:definition "Registre d'états de sections créé avant 1822. Contient une partie dédiée à la description du sol (propriété non bâties) et une partie dédiée à la description des bâtiments (propriétés bâties)."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Etats de sections antérieurs à 1822"@fr .
#
# srctype:Plan a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:definition "Plan faisant partie de la documentation cadastrale"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Map"@en,
#         "Plan"@fr .
#
# srctype:PlanParcellaire a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:Plan ;
#     skos:definition "Plan représentant les parcellaires d'une portion d'une commune (section entière ou partie d'une section), réalisé à des échelles situées entre 1:1250 et 1:5000."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Cadastral index map"@en,
#         "Plan parcellaire"@fr .
#
# srctype:ZoneDePage a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:PageDeRegistre ;
#     skos:definition "Zone située dans une page de registre"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Zone située dans une page de registre cadastral"@fr .
#
# srctype:EtatsDeSections a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:RegistreCadastral ;
#     skos:definition "Registre d'état de sections décrivant le parcellaire d'une commune à une date donnée, proche de la réalisation d'un plan cadastral."@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Initial register"@en,
#         "Etats de sections"@fr .
#
# srctype:RegistreCadastral a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:definition "Registre faisant partie de la documentation cadastrale"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Register"@en,
#         "Registre cadastral"@fr .
#
# srctype:MatriceCadastrale a cad:SourceType,
#         owl:NamedIndividual,
#         skos:Concept ;
#     skos:broader srctype:RegistreCadastral ;
#     skos:definition "Registre contenant l'ensemble des mutations affectant les parcelles pendant la période de validité de la matrice"@fr ;
#     skos:inScheme cad:SourceList ;
#     skos:prefLabel "Mutation register"@en,
#         "Matrice cadastrale"@fr .

# %% [markdown]
# ### Instances

# %%
PATH = "/home/STual/KG-cadastre/gentilly/data/SOURCES.csv"

sources = pd.read_csv(PATH,header=0)
display(sources)
# Out:
#     CODE_ARCHIVES       rdf:type  \
# 0              94      RecordSet
# 1              94  Instanciation
# 2              94  Instanciation
# 3              94      RecordSet
# 4              94  Instanciation
# 5              94  Instanciation
# 6              94  Instanciation
# 7              94  Instanciation
# 8              94  Instanciation
# 9              94  Instanciation
# 10             94      RecordSet
# 11             94  Instanciation
# 12             94  Instanciation
# 13             94  Instanciation
# 14             94  Instanciation
# 15             94  Instanciation
# 16             94  Instanciation
# 17             94  Instanciation
# 18             94  Instanciation
# 19             94  Instanciation
# 20             94  Instanciation
# 21             94  Instanciation
# 22             94  Instanciation
#
#                                        rico:name rico:location  \
# 0   Matrices des propriétés bâties et non bâties      Gentilly
# 1                                            NaN      Gentilly
# 2                                            NaN      Gentilly
# 3   Matrice des propriétés foncières (1836-1848)      Gentilly
# 4                                            NaN      Gentilly
# 5                                            NaN      Gentilly
# 6                                            NaN      Gentilly
# 7                                            NaN      Gentilly
# 8                                            NaN      Gentilly
# 9                                            NaN      Gentilly
# 10  Matrice des propriétés foncières (1848-1860)      Gentilly
# 11                                           NaN      Gentilly
# 12                                           NaN      Gentilly
# 13                                           NaN      Gentilly
# 14                                           NaN      Gentilly
# 15                                           NaN      Gentilly
# 16                                           NaN      Gentilly
# 17                                           NaN      Gentilly
# 18                                           NaN      Gentilly
# 19                                           NaN      Gentilly
# 20                                           NaN      Gentilly
# 21                                           NaN      Gentilly
# 22                                           NaN      Gentilly
#
#          rico:identifier     rsfs:comment/Folios  \
# 0          MAT_B_NB_1813                     NaN
# 1                  3P255  NB : 1-542 ; B : 1-166
# 2   FRAD094_3P_000255_01                     NaN
# 3            MAT_NB_1836                     NaN
# 4                  3P256                   1-480
# 5                  3P257                 481-980
# 6                  3P258                981-1150
# 7   FRAD094_3P_000256_01                     NaN
# 8   FRAD094_3P_000257_01                     NaN
# 9   FRAD094_3P_000258_01                     NaN
# 10           MAT_NB_1848                     NaN
# 11                 3P259                   1-500
# 12                 3P263                     NaN
# 13                 3P264                     NaN
# 14                 3P265                     NaN
# 15                 3P266                     NaN
# 16                 3P267                     NaN
# 17  FRAD094_3P_000259_01                     NaN
# 18  FRAD094_3P_000263_01                     NaN
# 19  FRAD094_3P_000264_01                     NaN
# 20  FRAD094_3P_000265_01                     NaN
# 21  FRAD094_3P_000266_01                     NaN
# 22  FRAD094_3P_000267_01                     NaN
#
#                               hasSourceType  hasCreationDate  \
# 0   MatriceCadastrale1807_1822_Bati_NonBati           1813.0
# 1                                       NaN              NaN
# 2                                       NaN              NaN
# 3        MatriceCadastrale1822_1914_NonBati           1836.0
# 4                                       NaN              NaN
# 5                                       NaN              NaN
# 6                                       NaN              NaN
# 7                                       NaN              NaN
# 8                                       NaN              NaN
# 9                                       NaN              NaN
# 10       MatriceCadastrale1822_1914_NonBati           1848.0
# 11                                      NaN              NaN
# 12                                      NaN              NaN
# 13                                      NaN              NaN
# 14                                      NaN              NaN
# 15                                      NaN              NaN
# 16                                      NaN              NaN
# 17                                      NaN              NaN
# 18                                      NaN              NaN
# 19                                      NaN              NaN
# 20                                      NaN              NaN
# 21                                      NaN              NaN
# 22                                      NaN              NaN
#
#     hasValidTime/hasBeginning  hasValidTime/hasEnd  \
# 0                      1813.0               1836.0
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                      1836.0               1848.0
# 4                         NaN                  NaN
# 5                         NaN                  NaN
# 6                         NaN                  NaN
# 7                         NaN                  NaN
# 8                         NaN                  NaN
# 9                         NaN                  NaN
# 10                     1848.0               1860.0
# 11                        NaN                  NaN
# 12                        NaN                  NaN
# 13                        NaN                  NaN
# 14                        NaN                  NaN
# 15                        NaN                  NaN
# 16                        NaN                  NaN
# 17                        NaN                  NaN
# 18                        NaN                  NaN
# 19                        NaN                  NaN
# 20                        NaN                  NaN
# 21                        NaN                  NaN
# 22                        NaN                  NaN
#
#    rico:isOrWasInstantiationOf rico:isOrWasDigitalInstantiationOf  \
# 0                          NaN                                NaN
# 1                MAT_B_NB_1813                                NaN
# 2                          NaN                      MAT_B_NB_1813
# 3                          NaN                                NaN
# 4                  MAT_NB_1836                                NaN
# 5                  MAT_NB_1836                                NaN
# 6                  MAT_NB_1836                                NaN
# 7                          NaN                        MAT_NB_1836
# 8                          NaN                        MAT_NB_1836
# 9                          NaN                        MAT_NB_1836
# 10                         NaN                                NaN
# 11                 MAT_NB_1848                                NaN
# 12                 MAT_NB_1848                                NaN
# 13                 MAT_NB_1848                                NaN
# 14                 MAT_NB_1848                                NaN
# 15                 MAT_NB_1848                                NaN
# 16                 MAT_NB_1848                                NaN
# 17                         NaN                        MAT_NB_1848
# 18                         NaN                        MAT_NB_1848
# 19                         NaN                        MAT_NB_1848
# 20                         NaN                        MAT_NB_1848
# 21                         NaN                        MAT_NB_1848
# 22                         NaN                        MAT_NB_1848
#
#    rico:hasOrHadDerivedInstanciation  \
# 0                                NaN
# 1               FRAD094_3P_000255_01
# 2                                NaN
# 3                                NaN
# 4               FRAD094_3P_000256_01
# 5               FRAD094_3P_000257_01
# 6               FRAD094_3P_000258_01
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11              FRAD094_3P_000259_01
# 12              FRAD094_3P_000263_01
# 13              FRAD094_3P_000264_01
# 14              FRAD094_3P_000265_01
# 15              FRAD094_3P_000266_01
# 16              FRAD094_3P_000267_01
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
#
#                     rico:hasOrHadPhysicalLocation
# 0                                             NaN
# 1   Archives Départementales du Val-de-Marne (94)
# 2                                             NaN
# 3                                             NaN
# 4   Archives Départementales du Val-de-Marne (94)
# 5   Archives Départementales du Val-de-Marne (94)
# 6   Archives Départementales du Val-de-Marne (94)
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11  Archives Départementales du Val-de-Marne (94)
# 12  Archives Départementales du Val-de-Marne (94)
# 13  Archives Départementales du Val-de-Marne (94)
# 14  Archives Départementales du Val-de-Marne (94)
# 15  Archives Départementales du Val-de-Marne (94)
# 16  Archives Départementales du Val-de-Marne (94)
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN

# %%
# Print the list of column headers
print(sources.columns.tolist())
# Out:
# ['CODE_ARCHIVES', 'rdf:type', 'rico:name', 'rico:location', 'rico:identifier', 'rsfs:comment/Folios', 'hasSourceType', 'hasCreationDate', 'hasValidTime/hasBeginning', 'hasValidTime/hasEnd', 'rico:isOrWasInstantiationOf', 'rico:isOrWasDigitalInstantiationOf', 'rico:hasOrHadDerivedInstanciation', 'rico:hasOrHadPhysicalLocation']

# %%
from rdflib import Graph, Literal, Namespace, RDF, URIRef, BNode
from rdflib.namespace import XSD

# Create a new RDF graph
g = Graph()

baseuri = Namespace("http://data.ign.fr/id/source/")
g.bind('source', baseuri)

# Define the namespaces
cad = Namespace("http://data.ign.fr/def/cadastre#")
add = Namespace("http://rdf.geohistoricaldata.org/def/address#")
src = Namespace("http://data.ign.fr/def/sources#")
rico = Namespace("https://www.ica.org/standards/RiC/ontology#")
fpo = Namespace("https://github.com/johnBradley501/FPO/raw/master/fpo.owl#")
time = Namespace("http://www.w3.org/2006/time#")
g.bind('cad', cad)
g.bind('add', add)
g.bind('src', src)
g.bind('rico', rico)
g.bind('fpo', fpo)
g.bind('time',time)

srctype = Namespace("http://data.ign.fr/id/codes/cadastrenap/sourceType/")
mlclasse= Namespace("http://data.ign.fr/id/codes/cadastrenap/mlClasse/")
g.bind('srctype', srctype)
g.bind('mlclasse', mlclasse)

# Iterate over each row in the DataFrame
for index, row in sources.iterrows():

    #URI = http://data.ign.fr/id/sources/{location}_{identifier}
    subject_uri = URIRef(baseuri + f"{str(row['CODE_ARCHIVES'])}_{str(row['rico:location'])}_{str(row['rico:identifier'])}")
    g.add((subject_uri, rico.identifier, Literal(row["rico:identifier"])))

    if row["rdf:type"] == "RecordSet":
        g.add((subject_uri, RDF.type, rico.RecordSet))
        g.add((subject_uri, rico.name, Literal(row["rico:name"])))
        g.add((subject_uri, rico.location, Literal(row["rico:location"])))
        g.add((subject_uri, src.hasSourceType, URIRef(srctype + f'{row["hasSourceType"]}')))
        creationDateBNode = BNode()
        g.add((subject_uri, src.hasCreationDate, creationDateBNode))
        g.add((creationDateBNode, RDF.type, add.CrispTimeInstant))
        g.add((creationDateBNode, add.timeCalendar, time.Gregorian))
        g.add((creationDateBNode, add.timePrecision, time.Year))
        str_date = "{:.0f}".format(row["hasCreationDate"])
        g.add((creationDateBNode, add.timeStamp, Literal(str_date, datatype=XSD.dateTimeStamp)))
        validTimeNode = BNode()
        validTimeNodeBegin = BNode()
        validTimeNodeEnd = BNode()
        g.add((subject_uri, src.hasValidTime, validTimeNode))
        g.add((validTimeNode, RDF.type, time.Interval))
        g.add((validTimeNode, add.hasBeginning, validTimeNodeBegin))
        g.add((validTimeNodeBegin, add.timeCalendar, time.Gregorian))
        g.add((validTimeNodeBegin, add.timePrecision, time.Year))
        str_date = "{:.0f}".format(row["hasValidTime/hasBeginning"])
        g.add((validTimeNodeBegin, add.timeStamp, Literal(str_date, datatype=XSD.dateTimeStamp)))
        g.add((validTimeNode, add.hasEnd, validTimeNodeEnd))
        g.add((validTimeNodeEnd, add.timeCalendar, time.Gregorian))
        g.add((validTimeNodeEnd, add.timePrecision, time.Year))
        str_date = "{:.0f}".format(row["hasValidTime/hasEnd"])
        g.add((validTimeNodeEnd, add.timeStamp, Literal(str_date, datatype=XSD.dateTimeStamp)))
    elif row["rdf:type"] == "Instanciation":
        if row["rico:identifier"][0:2] == '3P' :
            g.add((subject_uri, RDF.type, rico.Instantiation))
            g.add((subject_uri,rico.isOrWasInstantiationOf,URIRef(baseuri + f'{str(row["CODE_ARCHIVES"])}_{row["rico:location"]}_{row["rico:isOrWasInstantiationOf"]}')))
            g.add((subject_uri, rico.hasOrHadDerivedInstanciation, URIRef(baseuri + f'{str(row["CODE_ARCHIVES"])}_{row["rico:location"]}_{row["rico:hasOrHadDerivedInstanciation"]}')))
            g.add((subject_uri,rico.hasOrHadPhysicalLocation,Literal(row['rico:hasOrHadPhysicalLocation'])))
        elif row["rico:identifier"][0:2] != '3P' :
            g.add((subject_uri, RDF.type, rico.Instantiation))
            g.add((subject_uri,rico.isOrWasDigitalInstantiationOf,URIRef(baseuri + f'{str(row["CODE_ARCHIVES"])}_{row["rico:location"]}_{row["rico:isOrWasDigitalInstantiationOf"]}')))
# Print out the graph in Turtle syntax
print(g.serialize(format='turtle'))
# Out:
# @prefix add: <http://rdf.geohistoricaldata.org/def/address#> .
# @prefix rico: <https://www.ica.org/standards/RiC/ontology#> .
# @prefix source: <http://data.ign.fr/id/source/> .
# @prefix src: <http://data.ign.fr/def/sources#> .
# @prefix srctype: <http://data.ign.fr/id/codes/cadastrenap/sourceType/> .
# @prefix time: <http://www.w3.org/2006/time#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# source:94_Gentilly_3P255 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000255_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P255" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_B_NB_1813 .
#
# source:94_Gentilly_3P256 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000256_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P256" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1836 .
#
# source:94_Gentilly_3P257 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000257_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P257" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1836 .
#
# source:94_Gentilly_3P258 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000258_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P258" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1836 .
#
# source:94_Gentilly_3P259 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000259_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P259" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_3P263 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000263_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P263" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_3P264 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000264_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P264" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_3P265 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000265_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P265" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_3P266 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000266_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P266" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_3P267 a rico:Instantiation ;
#     rico:hasOrHadDerivedInstanciation source:94_Gentilly_FRAD094_3P_000267_01 ;
#     rico:hasOrHadPhysicalLocation "Archives Départementales du Val-de-Marne (94)" ;
#     rico:identifier "3P267" ;
#     rico:isOrWasInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_FRAD094_3P_000255_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000255_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_B_NB_1813 .
#
# source:94_Gentilly_FRAD094_3P_000256_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000256_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1836 .
#
# source:94_Gentilly_FRAD094_3P_000257_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000257_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1836 .
#
# source:94_Gentilly_FRAD094_3P_000258_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000258_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1836 .
#
# source:94_Gentilly_FRAD094_3P_000259_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000259_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_FRAD094_3P_000263_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000263_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_FRAD094_3P_000264_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000264_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_FRAD094_3P_000265_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000265_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_FRAD094_3P_000266_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000266_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_FRAD094_3P_000267_01 a rico:Instantiation ;
#     rico:identifier "FRAD094_3P_000267_01" ;
#     rico:isOrWasDigitalInstantiationOf source:94_Gentilly_MAT_NB_1848 .
#
# source:94_Gentilly_MAT_B_NB_1813 a rico:RecordSet ;
#     src:hasCreationDate [ a add:CrispTimeInstant ;
#             add:timeCalendar time:Gregorian ;
#             add:timePrecision time:Year ;
#             add:timeStamp "1813"^^xsd:dateTimeStamp ] ;
#     src:hasSourceType srctype:MatriceCadastrale1807_1822_Bati_NonBati ;
#     src:hasValidTime [ a time:Interval ;
#             add:hasBeginning [ add:timeCalendar time:Gregorian ;
#                     add:timePrecision time:Year ;
#                     add:timeStamp "1813"^^xsd:dateTimeStamp ] ;
#             add:hasEnd [ add:timeCalendar time:Gregorian ;
#                     add:timePrecision time:Year ;
#                     add:timeStamp "1836"^^xsd:dateTimeStamp ] ] ;
#     rico:identifier "MAT_B_NB_1813" ;
#     rico:location "Gentilly" ;
#     rico:name "Matrices des propriétés bâties et non bâties" .
#
# source:94_Gentilly_MAT_NB_1836 a rico:RecordSet ;
#     src:hasCreationDate [ a add:CrispTimeInstant ;
#             add:timeCalendar time:Gregorian ;
#             add:timePrecision time:Year ;
#             add:timeStamp "1836"^^xsd:dateTimeStamp ] ;
#     src:hasSourceType srctype:MatriceCadastrale1822_1914_NonBati ;
#     src:hasValidTime [ a time:Interval ;
#             add:hasBeginning [ add:timeCalendar time:Gregorian ;
#                     add:timePrecision time:Year ;
#                     add:timeStamp "1836"^^xsd:dateTimeStamp ] ;
#             add:hasEnd [ add:timeCalendar time:Gregorian ;
#                     add:timePrecision time:Year ;
#                     add:timeStamp "1848"^^xsd:dateTimeStamp ] ] ;
#     rico:identifier "MAT_NB_1836" ;
#     rico:location "Gentilly" ;
#     rico:name "Matrice des propriétés foncières (1836-1848)" .
#
# source:94_Gentilly_MAT_NB_1848 a rico:RecordSet ;
#     src:hasCreationDate [ a add:CrispTimeInstant ;
#             add:timeCalendar time:Gregorian ;
#             add:timePrecision time:Year ;
#             add:timeStamp "1848"^^xsd:dateTimeStamp ] ;
#     src:hasSourceType srctype:MatriceCadastrale1822_1914_NonBati ;
#     src:hasValidTime [ a time:Interval ;
#             add:hasBeginning [ add:timeCalendar time:Gregorian ;
#                     add:timePrecision time:Year ;
#                     add:timeStamp "1848"^^xsd:dateTimeStamp ] ;
#             add:hasEnd [ add:timeCalendar time:Gregorian ;
#                     add:timePrecision time:Year ;
#                     add:timeStamp "1860"^^xsd:dateTimeStamp ] ] ;
#     rico:identifier "MAT_NB_1848" ;
#     rico:location "Gentilly" ;
#     rico:name "Matrice des propriétés foncières (1848-1860)" .
